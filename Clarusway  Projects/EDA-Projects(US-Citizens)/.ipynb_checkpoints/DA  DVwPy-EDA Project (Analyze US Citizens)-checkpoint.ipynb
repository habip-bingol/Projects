# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df = pd.read_csv("adult_eda.csv")

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
# Checked if the Dataset have any Duplicate

df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
# Dropped Duplicates

df.drop_duplicates(inplace=True)

# %%
# Check the shape of the Dataset

df.shape
# Out:
# (32537, 15)

# %%
df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %% [markdown]
# **Renamed the features of;**<br>
# **``"education-num"``**, **``"marital-status"``**, **``"capital-gain"``**, **``"capital-loss"``**, **``"hours-per-week"``**, **``"native-country"``** **as**<br>
# **``"education_num"``**, **``"marital_status"``**, **``"capital_gain"``**, **``"capital_loss"``**, **``"hours_per_week"``**, **``"native_country"``**

# %%
df.rename(columns={"education-num": "education_num", "marital-status": "marital_status", "capital-gain": "capital_gain", "capital-loss": "capital_loss", 
                    "hours-per-week": "hours_per_week", "native-country": "native_country"}, inplace=True)
df.head(1)
# Out:
#    age  workclass  fnlwgt  education  education_num marital_status  \
# 0   39  State-gov   77516  Bachelors         13.000  Never-married
#
#      occupation   relationship   race   sex  capital_gain  capital_loss  \
# 0  Adm-clerical  Not-in-family  White  Male          2174             0
#
#    hours_per_week native_country salary
# 0              40  United-States  <=50K

# %%
# Checked the sum of Missing Values per column

df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Checked the Percentage of Missing Values

df.isnull().sum()/df.shape[0]*100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# sex               0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
df.select_dtypes(include="O").columns
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %%
for i in df.select_dtypes(include="O"):
    print(i)
    print(df[i].value_counts(dropna=False))
    print("*"*30)
# Out:
# workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ******************************
# education
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ******************************
# marital_status
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# ...

# %%
df.describe(include="O").T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %%
# Checked if the Dataset has any Question Mark "?"

df.isin(["?"]).any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## Salary (Target Feature)

# %% [markdown]
# **Check the count of person in each "salary" levels and visualize it with a countplot**

# %%
df.salary.value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
plt.figure()
ax = sns.countplot(x=df.salary)
ax.bar_label(ax.containers[0]);

# %% [markdown]
# **Check the percentage of person in each "salary" levels and visualize it with a pieplot**

# %%
df.salary.value_counts()/df.shape[0]
# Out:
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
# Your Code is Here
labels = df.salary.value_counts().index
values = df.salary.value_counts().values
plt.pie(x=values, labels=labels, autopct="%.1f%%", colors=["cyan", "yellow"], explode=(0,0.1), shadow=True)
plt.title("Percentage of Income-Levels",  fontsize=18);

# %% [markdown]
# **Result : While 75% of the individuals in the data set are at the low-income level, 25% are at the high-income level.**

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ## age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
sns.boxplot(x="age", data=df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
sns.histplot(x="age", data=df,bins=20, kde=True);

# %% [markdown]
# **Check the statistical values**

# %%
df.age.describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
sns.boxplot(x="salary", y="age", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='age'>

# %%
sns.histplot(x="age", data=df, hue="salary", bins=20, kde=True);

# %%
sns.kdeplot(x="age", data=df, hue="salary", shade=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df.groupby("salary").age.describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# **Result :The mean and median age of the high-income group is higher than the low-income group. It means the older generation possesses more wealth than the young.**

# %% [markdown]
# ## fnlwgt

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
sns.boxplot(x="fnlwgt", data=df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
sns.kdeplot(x="fnlwgt", data=df, shade=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.fnlwgt.describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
sns.boxplot(x="salary", y="fnlwgt", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='fnlwgt'>

# %%
# Your Code is Here

sns.kdeplot(x="fnlwgt", data=df, shade=True, hue="salary")
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Density'>

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df.groupby("salary").fnlwgt.describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# **Result :There is no significant difference between high and low-income groups according to the "fnlwgt" feature**

# %% [markdown]
# ## capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
sns.boxplot(x="capital_gain", data=df)
# Out:
# <AxesSubplot:xlabel='capital_gain'>

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
sns.kdeplot(x="capital_gain", data=df, shade=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here
df.capital_gain.describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
sns.boxplot(x="salary", y="capital_gain", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='capital_gain'>

# %%
sns.kdeplot(x="capital_gain", data=df, hue="salary")
# Out:
# <AxesSubplot:xlabel='capital_gain', ylabel='Density'>

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df.groupby("salary").capital_gain.describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %%
df2=df[df["capital_gain"]!=0]
df2.groupby("salary").capital_gain.describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# **Result :The "capital-gain" feature has not provided very meaningful insights. Nevertheless, we can say that the more "capital-gain", the more "high-income".**

# %% [markdown]
# ## capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here
sns.boxplot(x="capital_loss",data=df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
sns.kdeplot(x="capital_loss", data=df, shade=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.capital_loss.describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
sns.boxplot(x="salary", y="capital_loss", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='capital_loss'>

# %%
# Your Code is Here

sns.kdeplot(x="capital_loss", data=df, shade=True, hue="salary");

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary").capital_gain.describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %%
# Your Code is Here

df3=df[df.capital_loss != 0]
df3.groupby("salary").capital_loss.describe()
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# **Result : There is no significant difference between high and low-income groups according to the "capital_loss" feature.**

# %% [markdown]
# ## hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(x="hours_per_week", data=df)
# Out:
# <AxesSubplot:xlabel='hours_per_week'>

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(x="hours_per_week", data=df, shade=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(x="salary", y="hours_per_week", data=df);

# %%
# Your Code is Here

sns.kdeplot(x="hours_per_week", data=df, shade=True, hue="salary");

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary").hours_per_week.describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# **Result :To be in a high-income group, almost at least 40 hours working per week is required. Most of those who work less than 40 hours per week are in the low-income group.**

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
sns.pairplot(data=df, hue="salary", corner=True, palette="viridis")

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

df.education.value_counts()

# %%
# Your Code is Here

df.education_num.value_counts()

# %%
# Your Code is Here
df.groupby(["education", "education_num"], dropna=False)["education"].count()

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
# Your Code is Here
sns.countplot(x="education", data=df)
plt.tick_params(rotation=90, axis="x")

# %%
# Your Code is Here

sns.countplot(x="education_num", data=df);

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
# Your Code is Here

df.groupby(["education", "salary"])["education"].count()

# %%
# Your Code is Here

sns.countplot(x="education", data=df, hue="salary")
plt.tick_params(rotation=90, axis="x")

# %%
# Your Code is Here

df.groupby(["education_num", "salary"])["education_num"].count()

# %%
# Your Code is Here

sns.countplot(x="education_num", data=df, hue="salary")
plt.tick_params(rotation=90, axis="x")

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
# Your Code is Here

sns.boxplot( x="salary" , y="education_num", data=df);

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
# By using "mapping_education" def function above, created a new column named "education_summary"

df["education_summary"] = df.education.apply(mapping_education)
df.education_summary.value_counts()

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %%
# Your Code is Here
sns.countplot(x="education_summary", data=df);

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %%
# Your Code is Here

df.groupby(["education_summary", "salary"])["salary"].count()

# %%
# Your Code is Here

sns.countplot(x="education_summary", data=df, hue="salary");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("education_summary")["salary"].value_counts(normalize=True)

# %%
df_perc = pd.DataFrame(df.groupby("education_summary")["salary"].value_counts(normalize=True))
df_perc.columns = ["Percentages"]
df_perc = df_perc.unstack(level=0)
df_perc

# %%
# Your Code is Here

fig, ax=plt.subplots(1,3, figsize=(12,5))
colors = ["#ffb3b3", "#99ceff"]
ax[0].pie(x=df_perc.Percentages.high_level_grade, labels=df.salary.value_counts().index, colors=colors, autopct="%.2f%%" )
ax[0].set_title("high_level_grade")

ax[1].pie(x=df_perc.Percentages.low_level_grade, labels=df.salary.value_counts().index,colors=colors, autopct="%.2f%%");
ax[1].set_title("low_level_grade")

ax[2].pie(x=df_perc.Percentages.medium_level_grade, labels=df.salary.value_counts().index, colors=colors, autopct="%.2f%%");
ax[2].set_title("medium_level_grade")
plt.show()

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby(["salary", "education_summary"])["education_summary"].count()

# %%
# Your Code is Here
sns.countplot(x="salary", data=df, hue="education_summary")

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby(["salary"])["education_summary"].value_counts(normalize=True)

# %%
df_perc_2 = pd.DataFrame(df.groupby(["salary"])["education_summary"].value_counts(normalize=True))
df_perc_2 = df_perc_2.unstack(level=0)
df_perc_2

# %%
# Your Code is Here
fig, ax = plt.subplots(1,2)
colors_2 = ["#99ceff", "#98e698", "#ffb3b3" ]
ax[0].pie(x=df_perc_2.education_summary["<=50K"], labels=df_perc_2.index, autopct="%.2f%%", colors=colors_2, startangle=240 )
ax[0].set_title("<=50K")
ax[0].set_ylabel("education_summary")

ax[1].pie(x=df_perc_2.education_summary[">50K"], labels=df_perc_2.index, autopct="%.2f%%", colors=colors_2, startangle=170 )
ax[1].set_title("<=50K")
ax[1].set_ylabel("education_summary")

# %%
df_perc

# %%
# Your Code is Here
new = df.groupby("salary")["education_summary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new

# %%
# Your Code is Here
percentages_1 = new[new.salary == "<=50K"]["percentage"]*100
percentages_2 = new[new.salary == ">50K"]["percentage"]*100
colors_2 = ["#98e698", "#ffb3b3", "#99ceff" ]
colors_3 = ["#ffb3b3", "#98e698", "#99ceff" ]
fig, ax = plt.subplots(1,2)
ax[0].pie(x=percentages_1, labels=["medium", "high", "low"], colors=colors_2, autopct="%.2f%%", startangle=120)
ax[0].set_title("<=50K")
ax[0].set_ylabel("percentage")

ax[1].pie(x=percentages_2, labels=["high", "medium", "low"], colors=colors_3, autopct="%.2f%%", startangle=0)
ax[1].set_title(">50K")
ax[1].set_ylabel("percentage")
plt.show()

# %% [markdown]
# **Result :We can easily say that the more education the more high income.**

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

df.marital_status.value_counts(dropna=False)

# %%
# Your Code is Here
df.relationship.value_counts(dropna=False)

# %%
df.isnull().sum()

# %%
# Fill missing values with "Unknown" in the column of "relationship"

# Your Code is Here
df.relationship.replace(np.nan, "Unknown", inplace=True)

# %%
# Your Code is Here

df.groupby(["relationship"])["marital_status"].value_counts()

# %% [markdown]
# **Assessment : These features have almost same info, but "relationship" feature has %15 of missing values. So I have decided to go my way with "marital_status" feature**

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
# Your Code is Here

ax=sns.countplot(x="marital_status", data=df);
ax.tick_params(rotation=45, axis="x")

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
# Your Code is Here

df.groupby(["marital_status", "salary"])["salary"].count()

# %%
# Your Code is Here

ax = sns.countplot(x="marital_status", hue="salary", data=df)
ax.tick_params(rotation=45, axis="x")

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"
# Your Code is Here
df["marital_status_summary"] = df.marital_status.apply(mapping_marital_status)
df["marital_status_summary"].value_counts()

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %%
# Your Code is Here

sns.countplot(x="marital_status_summary",data=df);

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %%
# Your Code is Here
df.groupby(["marital_status_summary", "salary"])["salary"].count()

# %%
# Your Code is Here
sns.countplot(x="marital_status_summary", data=df, hue="salary");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby(["marital_status_summary"])["salary"].value_counts(normalize=True)

# %%
# Your Code is Here
new_2 = df.groupby(["marital_status_summary"])["salary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_2

# %%
new_2[new_2.marital_status_summary == "married"]["percentage"]

# %%
percentages_3 = new_2[new_2.marital_status_summary == "married"]["percentage"]
percentages_4 = new_2[new_2.marital_status_summary == "unmarried"]["percentage"]

fig, ax = plt.subplots(1,2)
ax[0].pie(x=percentages_3, labels=new_2.salary.value_counts().index, autopct="%.2f%%", colors=colors)
ax[0].set_title("married")
ax[0].set_ylabel("salary")

ax[1].pie(x=percentages_4, labels=new_2.salary.value_counts().index, autopct="%.2f%%", colors=colors)
ax[1].set_title("unmarried")
ax[1].set_ylabel("salary")

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby(["salary", "marital_status_summary"])["marital_status_summary"].count()

# %%
# Your Code is Here

sns.countplot(x="salary", data=df, hue="marital_status_summary");

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)

# %%
# Your Code is Here

new_3=df.groupby("salary")["marital_status_summary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_3

# %%
# Your Code is Here
percentages_5 = new_3[new_3.salary == "<=50K"]["percentage"]
percentages_6 = new_3[new_3.salary == ">50K"]["percentage"]
fig, ax=plt.subplots(1,2)
ax[0].pie(x=percentages_5, labels=new_3.marital_status_summary.value_counts().index, autopct="%.2f%%", colors=colors)
ax[0].set_title("<=50K")
ax[0].set_ylabel("percentage")

ax[1].pie(x=percentages_6, labels=new_3.marital_status_summary.value_counts().index, autopct="%.2f%%", colors=colors)
ax[1].set_title(">50K")
ax[1].set_ylabel("percentage");
# Out:
# Text(0, 0.5, 'percentage')

# %% [markdown]
# **Result :We can easily say that married persons have earned more income than unmarried persons.
# Also, Married with Civilian Spouse to have higher amount of people with above 50k income. We found the proportions of the people with above 50 k income with respect to the total number of people in each category and found that Married with Armed Forces have a better proportion of people with income above 50k.**
#
# **There is a clear relationship between being married and how much money a person earns in a year. The majority of people who earn more than 50K are married (85.90%). Only 14.10% of higher income people are unmarried. On the contrary, majority of lower income group are unmarried (64.87%). Only 35.13% of lower income group is married. It looks like there is a positive relationship between being married and earning more money.**

# %% [markdown]
# ## workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.workclass.value_counts(dropna=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here
sns.countplot(x="workclass", data=df)
# Out:
# <AxesSubplot:xlabel='workclass', ylabel='count'>

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unkown"

# Your Code is Here
df.workclass.replace("?", "Unknown", inplace=True)
df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
# Your Code is Here

df.groupby(["workclass", "salary"])["salary"].count()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      <=50K       494
#                   >50K        622
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x="workclass", data=df, hue="salary")
plt.tick_params(rotation=90, axis="x");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby("workclass")["salary"].value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
# Your Code is Here

new_4 = df.groupby("workclass")["salary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_4
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13           Unknown  <=50K       0.896
# 14           Unknown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %%
# Your Code is Here

ax = sns.barplot(x="workclass", y="percentage", data=new_4, hue="salary")
for i in ax.containers:
    ax.bar_label(i, fmt="%.2f");
plt.tick_params(rotation=90, axis="x")

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby(["salary"])["workclass"].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
# Your Code is Here
sns.countplot(x="salary", data=df, hue="workclass")
plt.legend(loc=1)

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby(["salary"])["workclass"].value_counts(normalize=True)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
# Your Code is Here

new_5 = df.groupby(["salary"])["workclass"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_5
# Out:
#    salary         workclass  percentage
# 0   <=50K           Private       0.717
# 1   <=50K  Self-emp-not-inc       0.074
# 2   <=50K           Unknown       0.067
# 3   <=50K         Local-gov       0.060
# 4   <=50K         State-gov       0.038
# 5   <=50K       Federal-gov       0.024
# 6   <=50K      Self-emp-inc       0.020
# 7   <=50K       Without-pay       0.001
# 8   <=50K      Never-worked       0.000
# 9    >50K           Private       0.633
# 10   >50K  Self-emp-not-inc       0.092
# 11   >50K      Self-emp-inc       0.079
# 12   >50K         Local-gov       0.079
# 13   >50K       Federal-gov       0.047
# 14   >50K         State-gov       0.045
# 15   >50K           Unknown       0.024

# %%
# Your Code is Here

ax= sns.barplot(x="salary", y="percentage", data=new_5, hue="workclass")
for i in ax.containers:
    ax.bar_label(i, fmt="%.3f")
    
plt.legend(loc=1)

# %% [markdown]
# **Result :"Self-emp-inc" work-class has a high ratio in the self group about high-level income. "Private" work-class has a high ratio in the high-income group about high-level income.**

# %% [markdown]
# ## occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

sns.countplot(x="occupation", data=df)
plt.tick_params(rotation=90, axis="x");

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

df.occupation.replace("?", "Unknown", inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
# Your Code is Here
df.groupby(["occupation"])["salary"].value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
# ...

# %%
# Your Code is Here
sns.countplot(x="occupation", data=df, hue="salary")
plt.tick_params(rotation=90, axis="x")

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %%
# Your Code is Here
df.groupby(["occupation"])["salary"].value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
# ...

# %%
# Your Code is Here

new_6 = df.groupby(["occupation"])["salary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_6
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# ...

# %%
# Your Code is Here

ax = sns.barplot(x="occupation", y="percentage", data=new_6, hue="salary")
ax.tick_params(rotation=90, axis="x")
for i in ax.containers:
    ax.bar_label(i, fmt="%.2f")
sns.move_legend(ax, loc=(1.1,0.5))

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["occupation"].value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
# ...

# %%
# Your Code is Here

sns.countplot(x="salary", data=df, hue="occupation", palette="winter_r")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here
df.groupby("salary")["occupation"].value_counts(normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
# ...

# %%
# Your Code is Here

new_7 = df.groupby("salary")["occupation"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_7
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 1   <=50K       Craft-repair       0.128
# 2   <=50K      Other-service       0.128
# 3   <=50K              Sales       0.108
# 4   <=50K     Prof-specialty       0.092
# 5   <=50K    Exec-managerial       0.085
# 6   <=50K  Machine-op-inspct       0.071
# 7   <=50K            Unknown       0.067
# 8   <=50K  Handlers-cleaners       0.052
# 9   <=50K   Transport-moving       0.052
# 10  <=50K    Farming-fishing       0.036
# 11  <=50K       Tech-support       0.026
# 12  <=50K    Protective-serv       0.018
# 13  <=50K    Priv-house-serv       0.006
# 14  <=50K       Armed-Forces       0.000
# 15   >50K    Exec-managerial       0.251
# 16   >50K     Prof-specialty       0.237
# 17   >50K              Sales       0.125
# 18   >50K       Craft-repair       0.119
# 19   >50K       Adm-clerical       0.065
# 20   >50K   Transport-moving       0.041
# 21   >50K       Tech-support       0.036
# ...

# %%
# Your Code is Here

sns.barplot(x="salary", y="percentage", data=new_7, hue="occupation");

# %% [markdown]
# **Result : "Exec-managerial" and "Prof-specialty" occupations have a high ratio of high-level income both in the self group and in the high-income group.**

# %% [markdown]
# ## race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.race.value_counts(dropna=False)
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
# Your Code is Here

sns.countplot(x="race", data=df);

# %% [markdown]
# **Check the count of person in each "salary" levels by races and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("race")["salary"].value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
# Your Code is Here

ax = sns.countplot(x = "race", data=df, hue="salary")
ax.tick_params(rotation=45)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %%
# Your Code is Here
df.groupby("race")["salary"].value_counts(normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
# Your Code is Here
df_perc_3 = df.groupby("race")["salary"].value_counts(normalize=True).to_frame(name = "percentage").reset_index()
df_perc_3
# Out:
#                  race salary  percentage
# 0  Amer-Indian-Eskimo  <=50K       0.884
# 1  Amer-Indian-Eskimo   >50K       0.116
# 2  Asian-Pac-Islander  <=50K       0.734
# 3  Asian-Pac-Islander   >50K       0.266
# 4               Black  <=50K       0.876
# 5               Black   >50K       0.124
# 6               Other  <=50K       0.908
# 7               Other   >50K       0.092
# 8               White  <=50K       0.744
# 9               White   >50K       0.256

# %%
fig, ax = plt.subplots(nrows=2, ncols=3)

percentages_7 = df_perc_3[df_perc_3.race =="Amer-Indian-Eskimo"]["percentage"]
percentages_8 = df_perc_3[df_perc_3.race =="Asian-Pac-Islander"]["percentage"]
percentages_9 = df_perc_3[df_perc_3.race =="Black"]["percentage"]
percentages_10 = df_perc_3[df_perc_3.race =="Other"]["percentage"]
percentages_11 = df_perc_3[df_perc_3.race =="White"]["percentage"]

labels = ["<=50K", ">50K"]

ax[0,0].pie(x=percentages_7, labels=labels, autopct="%.2f%%", colors=colors)
ax[0,0].set_title("Amer-Indian-Eskimo")
ax[0,0].set_ylabel("salary")

ax[0,1].pie(x=percentages_8, labels=labels, autopct="%.2f%%", colors=colors)
ax[0,1].set_title("Asian-Pac-Islander")
ax[0,1].set_ylabel("salary")

ax[0,2].pie(x=percentages_9, labels=labels, autopct="%.2f%%", colors=colors)
ax[0,2].set_title("Black")
ax[0,2].set_ylabel("salary")

ax[1,0].pie(x=percentages_10, labels=labels, autopct="%.2f%%", colors=colors)
ax[1,0].set_title("Others")
ax[1,0].set_ylabel("salary")

ax[1,1].pie(x=percentages_11, labels=labels, autopct="%.2f%%", colors=colors)
ax[1,1].set_title("White")
ax[1,1].set_ylabel("salary")

ax[1,2].axis("off")

plt.axis
plt.show()

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["race"].value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
# Your Code is Here
sns.countplot(x="salary", data=df, hue="race");

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby("salary")["race"].value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
# Your Code is Here

new_8 = df.groupby("salary")["race"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_8
# Out:
#   salary                race  percentage
# 0  <=50K               White       0.837
# 1  <=50K               Black       0.111
# 2  <=50K  Asian-Pac-Islander       0.031
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 4  <=50K               Other       0.010
# 5   >50K               White       0.908
# 6   >50K               Black       0.049
# 7   >50K  Asian-Pac-Islander       0.035
# 8   >50K  Amer-Indian-Eskimo       0.005
# 9   >50K               Other       0.003

# %%
# Your Code is Here

ax = sns.barplot(x="salary", y="percentage", data=new_8, hue="race" )
for i in ax.containers:
    ax.bar_label(i, fmt="%.3f")

# %% [markdown]
# **Result :"Asian-Pac-Islander" and "White" races has a high ratio in the self group about high-level income. "White" race has a high ratio in the high-income group about high-level income.**

# %% [markdown]
# ## gender

# %% [markdown]
# **Check the count of person in each gender and visualize it with countplot**

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary', 'education_summary', 'marital_status_summary'],
#       dtype='object')

# %%
# Your Code is Here
df.sex.value_counts()
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
# Your Code is Here
sns.countplot(x="sex", data=df);

# %% [markdown]
# **Check the count of person in each "salary" levels by gender and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("sex")["salary"].value_counts()
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.countplot(x="sex", data=df, hue="salary")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot**

# %%
# Your Code is Here

df.groupby("sex")["salary"].value_counts(normalize=True)
# Out:
# sex     salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
new_9 = df.groupby("sex")["salary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_9
# Out:
#       sex salary  percentage
# 0  Female  <=50K       0.890
# 1  Female   >50K       0.110
# 2    Male  <=50K       0.694
# 3    Male   >50K       0.306

# %%
# Your Code is Here
percentages_12 = new_9[new_9.sex == "Female"]["percentage"]
percentages_13 = new_9[new_9.sex == "Male"]["percentage"]
labels=["<=50K",">50K"]
fig, ax = plt.subplots(1,2)

ax[0].pie(x=percentages_12, labels=labels, autopct="%.2f%%", colors=colors)
ax[0].set_title("Female")
ax[0].set_ylabel("salary")

ax[1].pie(x=percentages_13, labels=labels, autopct="%.2f%%", colors=colors)
ax[1].set_title("Male")
ax[1].set_ylabel("salary")
# Out:
# Text(0, 0.5, 'salary')

# %% [markdown]
# **Check the count of person in each gender by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

# %% [raw]
# salary  gender
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: gender, dtype: int64

# %%
# Your Code is Here

sns.countplot(x="salary", data=df, hue="sex")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %% [markdown]
# **Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot**

# %%
# Your Code is Here

df.groupby("salary")["sex"].value_counts(normalize=True)
# Out:
# salary  sex
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: sex, dtype: float64

# %%
new_10 = df.groupby("salary")["sex"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_10
# Out:
#   salary     sex  percentage
# 0  <=50K    Male       0.612
# 1  <=50K  Female       0.388
# 2   >50K    Male       0.850
# 3   >50K  Female       0.150

# %%
# Your Code is Here

fig, ax = plt.subplots(1,2)
percentages_14 = new_10[new_10.salary =="<=50K"]["percentage"]
percentages_15 = new_10[new_10.salary ==">50K"]["percentage"]
ax[0].pie(x=percentages_14, labels=new_10.sex.value_counts().index, autopct="%.2f%%", colors=colors)
ax[0].set_title("<=50K")
ax[0].set_ylabel("gender")

ax[1].pie(x=percentages_15, labels=new_10.sex.value_counts().index, autopct="%.2f%%", colors=colors)
ax[1].set_title(">50K")
ax[1].set_ylabel("gender")

plt.show()

# %% [markdown]
# **Result :We can easily say that males have earned more income than females.**

# %% [markdown]
# ## native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.native_country.value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
# Your Code is Here

ax = sns.countplot(x="native_country", data=df)
ax.tick_params(rotation=90)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

df.native_country.replace("?", "unknown", inplace=True)

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"
# Your Code is Here

df["native_country_summary"] = df.native_country.apply(mapping_native_country)
df.native_country_summary.value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country_summary, dtype: int64

# %%
df.native_country_summary
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %%
# Your Code is Here

sns.countplot(x="native_country_summary", data=df);

# %% [markdown]
# **Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("native_country_summary")["salary"].value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.countplot(x="native_country_summary", data=df, hue="salary")
# Out:
# <AxesSubplot:xlabel='native_country_summary', ylabel='count'>

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("native_country_summary")["salary"].value_counts(normalize=True)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
new_11 = df.groupby("native_country_summary")["salary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_11
# Out:
#   native_country_summary salary  percentage
# 0                 Others  <=50K       0.802
# 1                 Others   >50K       0.198
# 2                     US  <=50K       0.754
# 3                     US   >50K       0.246

# %%
new_11.salary.value_counts().index
# Out:
# Index(['<=50K', '>50K'], dtype='object')

# %%
# Your Code is Here
percentages_16 = new_11[new_11.native_country_summary =="Others"]["percentage"]
percentages_17 = new_11[new_11.native_country_summary =="US"]["percentage"]
fig, ax = plt.subplots(1,2)
ax[0].pie(x=percentages_16, labels=new_11.salary.value_counts().index,  autopct="%.2f%%", colors=colors)
ax[0].set_title("Others")
ax[0].set_ylabel("salary")

ax[1].pie(x=percentages_17, labels=new_11.salary.value_counts().index,  autopct="%.2f%%", colors=colors)
ax[1].set_title("US")
ax[1].set_ylabel("salary")

plt.show()

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["native_country_summary"].value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x = "salary", data=df, hue="native_country_summary")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("salary")["native_country_summary"].value_counts(normalize=True)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
new_12 = df.groupby("salary")["native_country_summary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_12
# Out:
#   salary native_country_summary  percentage
# 0  <=50K                     US       0.890
# 1  <=50K                 Others       0.110
# 2   >50K                     US       0.915
# 3   >50K                 Others       0.085

# %%
# Your Code is Here
percentages_18 = new_12[new_12.salary == "<=50K"]["percentage"]
percentages_19 = new_12[new_12.salary == ">50K"]["percentage"]
fig, ax = plt.subplots(1,2)
ax[0].pie(x=percentages_18, labels=new_12.native_country_summary.value_counts().index, autopct="%.2f%%", colors=colors)
ax[0].set_title("<=50K")
ax[0].set_ylabel("native_country_summary")

ax[1].pie(x=percentages_19, labels=new_12.native_country_summary.value_counts().index, autopct="%.2f%%", colors=colors)
ax[1].set_title(">50K")
ax[1].set_ylabel("native_country_summary")
plt.show()

# %%
new_12[new_12.salary == "<=50K"]["percentage"]
# Out:
# 0   0.890
# 1   0.110
# Name: percentage, dtype: float64

# %% [markdown]
# **Result : "United States" has a high ratio of high-level income both in the self group and in the high-income group**

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
# Your Code is Here
df.groupby(["salary", "sex"]).age.mean()
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
ax = df.groupby(["salary", "sex"])["age"].mean().plot(kind="bar")
for i in ax.containers:
    ax.bar_label(i, fmt="%.2f")

# %%
# Your Code is Here

new_13 = df.groupby(["salary", "sex"]).age.mean().to_frame(name="avg").reset_index()
new_13
# Out:
#   salary     sex    avg
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %%
# Your Code is Here

ax = sns.barplot(x="salary", y="avg", data=new_13, hue="sex")
for i in ax.containers:
    ax.bar_label(i, fmt="%.2f")

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
df.head(3)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
#
#        marital_status         occupation   relationship   race   sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White  Male
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
#
#     education_summary marital_status_summary native_country_summary
# 0    high_level_grade              unmarried                     US
# ...

# %%
# Your Code is Here

df[(df.native_country_summary == "US") & (df.salary == ">50K")]["workclass"].value_counts(normalize=True)*100
# Out:
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: workclass, dtype: float64

# %%
new_14 = (df[(df.native_country_summary == "US") & (df.salary == ">50K")]["workclass"].value_counts(normalize=True)*100).to_frame(name="percentage").reset_index()
new_14
# Out:
#               index  percentage
# 0           Private      63.314
# 1  Self-emp-not-inc       9.192
# 2         Local-gov       8.021
# 3      Self-emp-inc       7.784
# 4       Federal-gov       4.687
# 5         State-gov       4.547
# 6           Unknown       2.455

# %%
# Your Code is Here
ax = sns.barplot(x="index", y="percentage", data=new_14)
for i in ax.containers:
    ax.bar_label(i, fmt="%.2f")
ax.tick_params(rotation=45)

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
df.head(3)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
#
#        marital_status         occupation   relationship   race   sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White  Male
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
#
#     education_summary marital_status_summary native_country_summary
# 0    high_level_grade              unmarried                     US
# ...

# %%
# Your Code is Here

df[(df.native_country_summary == "US") & (df.workclass == "Private") & (df.salary == ">50K")]["occupation"].value_counts(normalize=True)*100
# Out:
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
# Your Code is Here


new_15 = (df[(df.native_country_summary == "US") & (df.workclass == "Private") & (df.salary == ">50K")]["occupation"].value_counts(normalize=True)*100).to_frame(name="percentage").reset_index()
new_15
# Out:
#                 index  percentage
# 0     Exec-managerial      26.438
# 1      Prof-specialty      19.476
# 2        Craft-repair      14.695
# 3               Sales      14.475
# 4        Adm-clerical       6.389
# 5    Transport-moving       5.442
# 6        Tech-support       4.428
# 7   Machine-op-inspct       4.428
# 8       Other-service       1.674
# 9   Handlers-cleaners       1.344
# 10    Farming-fishing       0.595
# 11    Protective-serv       0.595
# 12    Priv-house-serv       0.022

# %%
ax = sns.barplot(x="index", y="percentage", data=new_15)
for i in ax.containers:
    ax.bar_label(i, fmt="%.2f")
ax.tick_params(rotation=90)

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
df.head(3)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
#
#        marital_status         occupation   relationship   race   sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White  Male
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
#
#     education_summary marital_status_summary native_country_summary
# 0    high_level_grade              unmarried                     US
# ...

# %%
# Your Code is Here
df[(df.race == "Asian-Pac-Islander") & (df.salary == ">50K")]["education"].value_counts(normalize=True)*100
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
new_16 = (df[(df.race == "Asian-Pac-Islander") & (df.salary == ">50K")]["education"].value_counts(normalize=True)*100).to_frame(name="percentage").reset_index()
new_16
# Out:
#            index  percentage
# 0      Bachelors      35.145
# 1        Masters      15.580
# 2        HS-grad      12.319
# 3   Some-college      11.957
# 4    Prof-school       9.783
# 5      Doctorate       6.522
# 6      Assoc-voc       3.261
# 7     Assoc-acdm       2.899
# 8        5th-6th       1.087
# 9            9th       0.362
# 10          11th       0.362
# 11          10th       0.362
# 12          12th       0.362

# %%
# Your Code is Here
ax = sns.barplot(x="index", y="percentage", data=new_16)
for i in ax.containers:
    ax.bar_label(i, fmt="%.2f")
ax.tick_params(rotation=90)

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
# Your Code is Here

df[(df.race == "Asian-Pac-Islander") & (df.education == "Bachelors") & (df.salary == ">50K")]["occupation"].value_counts(normalize=True)*100
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
new_17 = (df[(df.race == "Asian-Pac-Islander") & (df.education == "Bachelors") & (df.salary == ">50K")]["occupation"].value_counts(normalize=True)*100).to_frame(name="percentage").reset_index()
new_17
# Out:
#                 index  percentage
# 0     Exec-managerial      27.835
# 1      Prof-specialty      25.773
# 2        Adm-clerical      12.371
# 3               Sales       9.278
# 4       Other-service       9.278
# 5        Craft-repair       7.216
# 6        Tech-support       3.093
# 7     Protective-serv       2.062
# 8    Transport-moving       1.031
# 9   Machine-op-inspct       1.031
# 10    Farming-fishing       1.031

# %%
# Your Code is Here

ax = sns.barplot(x="index", y="percentage", data=new_17)

for i in ax.containers:
    ax.bar_label(i, fmt="%.2f")
ax.tick_params(rotation=90)

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary', 'education_summary', 'marital_status_summary',
#        'native_country_summary'],
#       dtype='object')

# %%
plt.figure(figsize=(8,4))
g = sns.catplot(data=df, kind="bar", x="education_summary", y="hours_per_week",
            hue="sex",row="native_country_summary",
            col="marital_status_summary", ci=False,
            palette=sns.color_palette(['pink', 'skyblue']))
for ax in g.axes.ravel():
    for c in ax.containers:
        labels = [f'{(v.get_height()):.2f}' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
g.fig.suptitle("Working Hours Per Weel by Gender for Education Worklass and Marital Status",
               y=1.03)
plt.show()

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# Your Code is Here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   sex                     32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
# ...

# %%
df_new = df.copy()

# %%
# Drop the columns of "education", "education_num", "relationship", "marital_status", "native_country" permanently

# Your Code is Here

df.drop(["education", "education_num", "relationship", "marital_status", "native_country"], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   occupation              32537 non-null  object
#  4   race                    32537 non-null  object
#  5   sex                     32537 non-null  object
#  6   capital_gain            32537 non-null  int64
#  7   capital_loss            32537 non-null  int64
#  8   hours_per_week          32537 non-null  int64
#  9   salary                  32537 non-null  object
#  10  education_summary       32537 non-null  object
#  11  marital_status_summary  32537 non-null  object
#  12  native_country_summary  32537 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 4.5+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %%
# Your Code is Here

df.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
# Your Code is Here

df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here

df.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# Unknown         1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
# Replace "Unknown" values with NaN using numpy library

# Your Code is Here

df["workclass"].replace("Unknown", np.nan, inplace=True)

# %%
df.workclass.value_counts(dropna=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# NaN                  1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df["occupation"].replace("Unknown", np.nan, inplace=True)

# %%
df.occupation.value_counts(dropna=False)
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# NaN                  1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

df.isnull().sum()
# Out:
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# sex                          0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %%
# Drop missing values in df permanently

# Your Code is Here

df.dropna(inplace=True)

# %%
# Your Code is Here

df.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
# Your Code is Here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   sex                     30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### Boxplot and Histplot for all numeric features
#
# **Plot boxplots for each numeric features at the same figure as subplots**

# %%
# Your Code is Here
df.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
# Your Code is Here

fig, ax = plt.subplots(2,3, figsize=(20,10))

sns.boxplot(ax=ax[0,0],x="age", data=df)
sns.boxplot(ax=ax[0,1],x="fnlwgt", data=df)
sns.boxplot(ax=ax[0,2],x="capital_gain", data=df)
sns.boxplot(ax=ax[1,0],x="capital_loss", data=df)
sns.boxplot(ax=ax[1,1],x="hours_per_week", data=df)

ax[1,2].axis("off");

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(20,30))
sns.boxplot(ax=ax[0,0],x="age", data=df)
sns.boxplot(ax=ax[1,0],x="fnlwgt", data=df)
sns.boxplot(ax=ax[2,0],x="capital_gain", data=df)
sns.boxplot(ax=ax[3,0],x="capital_loss", data=df)
sns.boxplot(ax=ax[4,0],x="hours_per_week", data=df)

sns.histplot(ax=ax[0,1],x="age", data=df)
sns.histplot(ax=ax[1,1],x="fnlwgt", data=df)
sns.histplot(ax=ax[2,1],x="capital_gain", data=df)
sns.histplot(ax=ax[3,1],x="capital_loss", data=df)
sns.histplot(ax=ax[4,1],x="hours_per_week", data=df)
# Out:
# <AxesSubplot:xlabel='hours_per_week', ylabel='Count'>

# %% [markdown]
# **Check the statistical values for all numeric features**

# %%
# Your Code is Here
df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            30694.000     38.448     13.115    17.000     28.000
# fnlwgt         30694.000 189848.229 105465.126 13769.000 117828.500
# capital_gain   30694.000   1106.902   7500.730     0.000      0.000
# capital_loss   30694.000     88.980    405.808     0.000      0.000
# hours_per_week 30694.000     40.953     11.984     1.000     40.000
#
#                       50%        75%         max
# age                37.000     47.000      90.000
# fnlwgt         178513.500 237293.750 1484705.000
# capital_gain        0.000      0.000   99999.000
# capital_loss        0.000      0.000    4356.000
# hours_per_week     40.000     45.000      99.000

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
# Your Code is Here

fig, ax = plt.subplots(nrows=1, ncols=2)
sns.boxplot(ax=ax[0],y="age", data=df)
sns.histplot(ax=ax[1],x="age", data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

Q1 = df.age.quantile(0.25)

Q3 = df.age.quantile(0.75)

IQR = Q3-Q1
Q1, Q3, IQR
# Out:
# (28.0, 47.0, 19.0)

# %%
# Find lower and upper limit using IQR

# Your Code is Here

lower_lim = Q1 - 1.5*IQR
upper_lim = Q3 + 1.5*IQR

lower_lim, upper_lim
# Out:
# (-0.5, 75.5)

# %%
# Your Code is Here

df[df.age > upper_lim]["age"].value_counts()
# Out:
# 90    35
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
# Define the observations whose age is greater than upper limit and sort these observations by age in descending order

# Your Code is Here

df[df.age > upper_lim].sort_values(by="age", ascending=False)
# Out:
#        age         workclass  fnlwgt       occupation                race  \
# 8806    90           Private   87372   Prof-specialty               White
# 14159   90         Local-gov  187749     Adm-clerical  Asian-Pac-Islander
# 28463   90       Federal-gov  195433     Craft-repair               White
# 12975   90           Private  250832  Exec-managerial               White
# 11996   90           Private   40388  Exec-managerial               White
# ...    ...               ...     ...              ...                 ...
# 15102   76         Local-gov  169133     Adm-clerical               White
# 19085   76           Private  125784  Exec-managerial               White
# 23515   76           Private  142535     Adm-clerical               White
# 8240    76  Self-emp-not-inc  225964            Sales               White
# 23354   76           Private  199949     Adm-clerical               White
#
#           sex  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %% [markdown]
# ### hours_per_week

# %%
# Your Code is Here

fig, ax = plt.subplots(nrows=1, ncols=2)

sns.boxplot(ax=ax[0],y="hours_per_week", data=df)
sns.histplot(ax=ax[1],x="hours_per_week", data=df, bins=10)
# Out:
# <AxesSubplot:xlabel='hours_per_week', ylabel='Count'>

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here
Q1 = df.hours_per_week.quantile(0.25)

Q3 = df.hours_per_week.quantile(0.75)

IQR = Q3-Q1
Q1, Q3, IQR
# Out:
# (40.0, 45.0, 5.0)

# %%
# Find the lower and upper limit using IQR

# Your Code is Here

lower_lim = Q1 - 1.5*IQR
upper_lim = Q3 + 1.5*IQR

lower_lim, upper_lim
# Out:
# (32.5, 52.5)

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# Your Code is Here
df[df.hours_per_week > upper_lim]["hours_per_week"].value_counts().sort_index(ascending=False)
# Out:
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
df[df.hours_per_week > upper_lim]
# Out:
#        age         workclass  fnlwgt        occupation   race     sex  \
# 10      37           Private  280464   Exec-managerial  Black    Male
# 20      40           Private  193524    Prof-specialty  White    Male
# 28      39           Private  367260   Exec-managerial  White    Male
# 52      47           Private   51835    Prof-specialty  White  Female
# 53      50       Federal-gov  251585   Exec-managerial  White    Male
# ...    ...               ...     ...               ...    ...     ...
# 32520   27           Private  177398     Other-service  White  Female
# 32523   30           Private   77266  Transport-moving  White    Male
# 32532   34           Private  204461    Prof-specialty  White    Male
# 32536   34           Private  160216   Exec-managerial  White  Female
# 32548   65  Self-emp-not-inc   99359    Prof-specialty  White    Male
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %%
# Your Code is Here

df[df.hours_per_week < lower_lim]["hours_per_week"].value_counts().sort_index(ascending=True)
# Out:
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
# Your Code is Here
df[df.hours_per_week < lower_lim].groupby("salary").hours_per_week.describe()
# Out:
#           count   mean   std   min    25%    50%    75%    max
# salary
# <=50K  4372.000 21.548 7.343 1.000 16.000 20.000 30.000 32.000
# >50K    322.000 22.028 7.813 1.000 18.000 24.000 30.000 32.000

# %%
# Your Code is Here
df[df.hours_per_week < lower_lim].groupby("salary").age.describe()
# Out:
#           count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  4372.000 34.052 17.730 17.000 20.000 26.000 45.000 90.000
# >50K    322.000 49.484 13.894 22.000 39.000 48.000 60.000 90.000

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
# Create a condition according to your domain knowledge on age stated above and 
# sort the observations meeting this condition by age in ascending order

# Your Code is Here
df[(df.age < 17) | (df.age>80)]
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 222     90           Private   51744      Other-service  Black    Male
# 918     81  Self-emp-not-inc  136063    Exec-managerial  White    Male
# 1040    90           Private  137018      Other-service  White  Female
# 1168    88  Self-emp-not-inc  206291     Prof-specialty  White    Male
# 1935    90           Private  221832    Exec-managerial  White    Male
# ...    ...               ...     ...                ...    ...     ...
# 31030   90           Private   47929  Machine-op-inspct  White    Male
# 31855   82  Self-emp-not-inc   71438    Farming-fishing  White    Male
# 32277   90           Private  313749       Adm-clerical  White  Female
# 32367   90         Local-gov  214594    Protective-serv  White    Male
# 32459   85           Private   98611    Exec-managerial  White    Male
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %%
# Find the shape of the dataframe created by the condition defined above for age 

# Your Code is Here

df[(df.age < 17) | (df.age>80)].shape
# Out:
# (76, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for age

# Your Code is Here

df[(df.age < 17) | (df.age>80)].index
# Out:
# Int64Index([  222,   918,  1040,  1168,  1935,  2303,  2891,  2906,  3537,
#              4070,  4834,  5272,  5370,  5406,  6214,  6232,  6624,  6748,
#              7481,  7720,  8381,  8431,  8806,  8973,  9471, 10210, 10545,
#             11238, 11512, 11996, 12830, 12975, 13295, 13696, 13928, 14159,
#             14711, 14756, 15356, 15662, 15892, 16302, 18277, 18413, 18725,
#             18832, 19045, 19172, 19212, 19489, 19495, 19747, 20421, 20463,
#             20610, 21501, 21835, 22220, 22481, 22895, 23459, 24027, 24043,
#             24280, 24395, 24560, 26731, 27795, 28463, 28948, 29594, 31030,
#             31855, 32277, 32367, 32459],
#            dtype='int64')

# %%
# Drop these indices defined above for age

# Your Code is Here

df.drop(df[(df.age < 17) | (df.age>80)].index, axis=0, inplace=True)

# %%
df.shape
# Out:
# (30618, 13)

# %%
# Create a condition according to your domain knowledge on hours per week stated above and 
# sort the observations meeting this condition by hours per week in descending order

# Your Code is Here

df[(df.hours_per_week > 70) | (df.hours_per_week < 7)].sort_values(by="hours_per_week", ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 22216   45           Private   54260      Craft-repair               White
# 5432    44           Private   83508    Prof-specialty               White
# 19053   27           Private   40295  Transport-moving               White
# 19141   59           Private  106748     Other-service               White
# 19399   39      Self-emp-inc  163057      Craft-repair               White
# ...    ...               ...     ...               ...                 ...
# 20909   77  Self-emp-not-inc   71676      Adm-clerical               White
# 25078   74           Private  260669     Other-service               White
# 19750   23           Private   72887      Craft-repair  Asian-Pac-Islander
# 189     58         State-gov  109567    Prof-specialty               White
# 24284   57  Self-emp-not-inc   56480   Exec-managerial               White
#
#           sex  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %%
# Find the shape of the dataframe created by the condition defined above for hours per week 

# Your Code is Here

df[(df.hours_per_week > 70) | (df.hours_per_week < 7)].shape
# Out:
# (621, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for hours per week

# Your Code is Here
df[(df.hours_per_week > 70) | (df.hours_per_week < 7)].index
# Out:
# Int64Index([   10,    28,   157,   189,   265,   272,   299,   387,   427,
#               476,
#             ...
#             32271, 32320, 32332, 32359, 32364, 32391, 32402, 32432, 32469,
#             32476],
#            dtype='int64', length=621)

# %%
# Drop these indices defined above for hours per week

# Your Code is Here

df.drop(df[(df.hours_per_week > 70) | (df.hours_per_week < 7)].index, axis=0, inplace=True)

# %%
# Create a condition according to your domain knowledge on both age and hours per week stated above 

# Your Code is Here

df[(df.age > 60 )&(df.hours_per_week > 60)]
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 1541    62           Private  162245    Prof-specialty               White
# 2154    75           Private  101887   Priv-house-serv               White
# 2184    63      Self-emp-inc   54052             Sales               White
# 2665    70           Private   94692             Sales               White
# 3101    65      Self-emp-inc   81413   Farming-fishing               White
# 5417    67           Private  197816             Sales               White
# 6826    68           Private  284763  Transport-moving               White
# 8066    61  Self-emp-not-inc  133969             Sales  Asian-Pac-Islander
# 9646    62  Self-emp-not-inc   26911     Other-service               White
# 12624   63      Self-emp-inc  110890    Prof-specialty               White
# 16634   62  Self-emp-not-inc  115176   Farming-fishing               White
# ...

# %%
# Find the shape of the dataframe created by the condition defined above for both age and hours per week


# Your Code is Here
df[(df.age > 60 )&(df.hours_per_week > 60)].shape
# Out:
# (23, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for both age and hours per week

# Your Code is Here
df[(df.age > 60 )&(df.hours_per_week > 60)].index
# Out:
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
# Drop these indices defined above for both age and hours per week

# Your Code is Here
df.drop(df[(df.age > 60 )&(df.hours_per_week > 60)].index, axis=0, inplace=True)

# %%
# What is new shape of dataframe now

# Your Code is Here

df.shape
# Out:
# (29974, 13)

# %%
# Reset the indices and take the head of DataFrame now

# Your Code is Here
df.head()
# Out:
#    age         workclass  fnlwgt         occupation   race     sex  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
#
#    capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 0          2174             0              40  <=50K    high_level_grade
# 1             0             0              13  <=50K    high_level_grade
# 2             0             0              40  <=50K  medium_level_grade
# 3             0             0              40  <=50K     low_level_grade
# 4             0             0              40  <=50K    high_level_grade
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %%
# Your Code is Here
df["salary"] = df.salary.map({"<=50K":0, ">50K":1})
df.salary
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: salary, Length: 29974, dtype: int64

# %%
# Your Code is Here

df.salary.value_counts()
# Out:
# 0    22524
# 1     7450
# Name: salary, dtype: int64

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
df
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital_gain  capital_loss  hours_per_week  salary   education_summary  \
# ...

# %%
# Your Code is Here

df_final = pd.get_dummies(df, drop_first=True)
df_final
# Out:
#        age  fnlwgt  capital_gain  capital_loss  hours_per_week  salary  \
# 0       39   77516          2174             0              40       0
# 1       50   83311             0             0              13       0
# 2       38  215646             0             0              40       0
# 3       53  234721             0             0              40       0
# 4       28  338409             0             0              40       0
# ...    ...     ...           ...           ...             ...     ...
# 32556   27  257302             0             0              38       0
# 32557   40  154374             0             0              40       1
# 32558   58  151910             0             0              40       0
# 32559   22  201490             0             0              20       0
# 32560   52  287927         15024             0              40       1
#
#        workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# ...

# %%
# What's the shape of dataframe

# Your Code is Here

df.shape
# Out:
# (29974, 13)

# %%
# What's the shape of dataframe created by dummy operation

# Your Code is Here

df_final.shape
# Out:
# (29974, 34)

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
# Your Code is Here

df_final.corr()
# Out:
#                                         age  fnlwgt  capital_gain  \
# age                                   1.000  -0.074         0.082
# fnlwgt                               -0.074   1.000        -0.002
# capital_gain                          0.082  -0.002         1.000
# capital_loss                          0.059  -0.011        -0.032
# hours_per_week                        0.119  -0.019         0.086
# salary                                0.253  -0.010         0.222
# workclass_Local-gov                   0.070  -0.004        -0.010
# workclass_Private                    -0.211   0.045        -0.045
# workclass_Self-emp-inc                0.111  -0.025         0.093
# workclass_Self-emp-not-inc            0.146  -0.037         0.033
# workclass_State-gov                   0.020  -0.012        -0.013
# workclass_Without-pay                 0.016  -0.003        -0.002
# occupation_Armed-Forces              -0.011   0.004        -0.003
# ...

# %%
# Your Code is Here
plt.figure(figsize=(20,25))
sns.heatmap(df_final.corr(), annot=True, fmt=".3f", cmap="winter_r", annot_kws={"fontsize":10})
# Out:
# <AxesSubplot:>

# %%
# Your Code is Here


df_salary_corr = df_final.corr()[["salary"]].drop("salary", axis=0).sort_values(by="salary", ascending=False)
df_salary_corr
# Out:
#                                       salary
# age                                    0.253
# hours_per_week                         0.247
# capital_gain                           0.222
# sex_Male                               0.216
# occupation_Exec-managerial             0.215
# occupation_Prof-specialty              0.185
# capital_loss                           0.152
# workclass_Self-emp-inc                 0.138
# race_White                             0.086
# native_country_summary_US              0.035
# workclass_Self-emp-not-inc             0.030
# workclass_Local-gov                    0.029
# occupation_Protective-serv             0.026
# occupation_Tech-support                0.023
# occupation_Sales                       0.015
# race_Asian-Pac-Islander                0.012
# workclass_State-gov                    0.011
# occupation_Armed-Forces               -0.006
# fnlwgt                                -0.010
# workclass_Without-pay                 -0.012
# ...

# %%
# Your Code is Here
plt.figure(figsize=(3,15))
sns.heatmap(df_salary_corr, cmap="viridis", annot=True)
# Out:
# <AxesSubplot:>

# %%
# Your Code is Here
plt.figure(figsize=(10,15))
sns.barplot(x=df_salary_corr.salary, y=df_salary_corr.index)
# Out:
# <AxesSubplot:xlabel='salary'>

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
