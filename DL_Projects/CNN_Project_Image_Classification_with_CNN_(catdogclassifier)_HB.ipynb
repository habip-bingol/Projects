# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>

# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Image Classification with CNN<br><br>Cat-Dog Classification Project<br><h1>

# %% [markdown]
# # Dataset Info

# %% [markdown]
# The Dogs vs. Cats dataset is a common computer vision dataset in which pictures are classified as either including a dog or a cat.
#
# After the dataset is well studied, it can be used to understand and practice how to design, evaluate, and apply convolutional neural networks for image classification.
#
# You will build a classifier with images and try to detect dogs versus cats using CNN.
#
# Train set includes 12500 cat-5026 dog images, validation set includes 1219 cat-1071 dog images and test set includes 6897 cat and dogs images together.

# %% [markdown]
# # Import Libraries and Export Images from Zip_File

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf

tf.config.list_physical_devices("GPU")
# Out:
# []

# %%
import gdown
url = 'https://drive.google.com/u/0/uc?id=1Qm7Lp95C9E9mqUD1m8LNf_UkfctXvEGB&export=download'
output = '/content/drive/MyDrive/cat_dog_data.zip' # colab
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1Qm7Lp95C9E9mqUD1m8LNf_UkfctXvEGB&export=download
# To: /content/drive/MyDrive/cat_dog_data.zip
# 100%|██████████| 595M/595M [00:04<00:00, 125MB/s]
# '/content/drive/MyDrive/cat_dog_data.zip'

# %%
import zipfile

# Unzip the file
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/cat_dog_data.zip", "r")
zip_ref.extractall()
zip_ref.close()

# %%
my_data_dir = "data"

# %%
os.listdir(my_data_dir)
# Out:
# ['validation', 'train', 'test']

# %% [markdown]
# # Recognizing and Understanding Data

# %%
test_path = my_data_dir + '/test/'
train_path = my_data_dir + '/train/'
validation_path = my_data_dir + '/validation/'

# %%
print("test folder :", os.listdir(test_path))
print("train folder :", os.listdir(train_path))
print("validation folder :", os.listdir(validation_path))
# Out:
# test folder : ['4732.jpg', '6291.jpg', '4702.jpg', '11698.jpg', '4391.jpg', '4554.jpg', '5340.jpg', '3262.jpg', '5058.jpg', '12311.jpg', '12189.jpg', '11668.jpg', '5595.jpg', '12106.jpg', '6592.jpg', '11057.jpg', '3975.jpg', '4205.jpg', '4611.jpg', '4807.jpg', '2966.jpg', '3786.jpg', '10601.jpg', '11572.jpg', '6916.jpg', '10424.jpg', '5031.jpg', '10015.jpg', '5536.jpg', '5371.jpg', '4640.jpg', '12462.jpg', '10191.jpg', '10670.jpg', '4399.jpg', '12459.jpg', '6971.jpg', '4625.jpg', '4387.jpg', '12273.jpg', '10656.jpg', '5170.jpg', '5075.jpg', '12344.jpg', '3001.jpg', '5949.jpg', '5438.jpg', '5693.jpg', '5062.jpg', '5382.jpg', '6923.jpg', '11917.jpg', '7029.jpg', '4189.jpg', '4159.jpg', '11340.jpg', '7060.jpg', '11250.jpg', '10178.jpg', '4207.jpg', '3163.jpg', '11381.jpg', '10791.jpg', '3445.jpg', '6448.jpg', '12118.jpg', '11089.jpg', '4254.jpg', '3783.jpg', '6187.jpg', '10741.jpg', '4687.jpg', '11451.jpg', '3943.jpg', '3488.jpg', '6772.jpg', '4193.jpg', '4218.jpg', '11203.jpg', '3106.jpg', '10679.jpg', '3929.jpg', '11846.jpg', '2997.jpg', '11915.jpg', '6930.jpg', '5850.jpg', '3858.jpg', '5130.jpg', '10326.jpg', '11504.jpg', '3889.jpg', '5985.jpg', '6523.jpg', '3771.jpg', '10444.jpg', '6548.jpg', '12345.jpg', '12493.jpg', '4182.jpg', '11252.jpg', '10699.jpg', '5890.jpg', '4144.jpg', '6061.jpg', '12464.jpg', '7020.jpg', '6561.jpg', '12331.jpg', '4252.jpg', '10170.jpg', '11791.jpg', '5455.jpg', '6884.jpg', '11719.jpg', '2850.jpg', '5292.jpg', '12460.jpg', '6415.jpg', '10385.jpg', '6457.jpg', '3517.jpg', '3243.jpg', '5501.jpg', '11399.jpg', '5720.jpg', '10893.jpg', '4497.jpg', '3461.jpg', '3479.jpg', '3980.jpg', '6432.jpg', '3291.jpg', '5515.jpg', '2992.jpg', '3147.jpg', '10778.jpg', '6220.jpg', '10873.jpg', '11117.jpg', '4706.jpg', '3938.jpg', '5314.jpg', '11102.jpg', '10610.jpg', '11180.jpg', '10976.jpg', '7062.jpg', '5362.jpg', '11474.jpg', '3965.jpg', '12112.jpg', '4754.jpg', '4904.jpg', '6096.jpg', '11721.jpg', '3960.jpg', '10626.jpg', '5309.jpg', '3623.jpg', '6847.jpg', '6030.jpg', '11253.jpg', '10120.jpg', '10225.jpg', '6339.jpg', '11648.jpg', '3258.jpg', '11835.jpg', '10111.jpg', '11937.jpg', '11312.jpg', '12265.jpg', '12232.jpg', '5897.jpg', '3766.jpg', '6576.jpg', '6821.jpg', '11072.jpg', '3894.jpg', '4163.jpg', '5598.jpg', '4480.jpg', '10604.jpg', '4567.jpg', '3475.jpg', '10795.jpg', '12115.jpg', '5019.jpg', '6248.jpg', '10105.jpg', '10813.jpg', '10198.jpg', '3823.jpg', '12063.jpg', '10328.jpg', '5804.jpg', '4950.jpg', '5022.jpg', '12138.jpg', '3284.jpg', '12022.jpg', '5719.jpg', '11209.jpg', '6292.jpg', '7167.jpg', '12371.jpg', '4681.jpg', '12092.jpg', '10886.jpg', '5243.jpg', '4397.jpg', '10161.jpg', '10831.jpg', '5308.jpg', '2963.jpg', '11795.jpg', '5744.jpg', '5138.jpg', '11782.jpg', '5234.jpg', '3376.jpg', '3489.jpg', '10922.jpg', '5208.jpg', '3216.jpg', '4108.jpg', '11345.jpg', '4619.jpg', '12013.jpg', '5284.jpg', '11558.jpg', '10756.jpg', '11690.jpg', '11736.jpg', '3809.jpg', '3608.jpg', '5279.jpg', '3715.jpg', '5885.jpg', '3791.jpg', '11822.jpg', '11521.jpg', '4051.jpg', '6009.jpg', '12024.jpg', '10683.jpg', '4969.jpg', '12128.jpg', '10654.jpg', '6840.jpg', '3417.jpg', '4321.jpg', '3183.jpg', '11406.jpg', '6530.jpg', '3589.jpg', '3704.jpg', '6914.jpg', '6406.jpg', '5307.jpg', '5555.jpg', '10965.jpg', '11607.jpg', '12059.jpg', '11514.jpg', '11358.jpg', '5757.jpg', '11814.jpg', '10613.jpg', '4937.jpg', '12121.jpg', '12301.jpg', '5779.jpg', '4527.jpg', '4867.jpg', '7055.jpg', '10408.jpg', '4296.jpg', '5116.jpg', '11752.jpg', '12373.jpg', '4006.jpg', '5933.jpg', '10519.jpg', '5097.jpg', '12132.jpg', '5619.jpg', '6640.jpg', '3025.jpg', '10482.jpg', '4985.jpg', '12484.jpg', '4686.jpg', '11445.jpg', '3225.jpg', '3094.jpg', '7166.jpg', '3773.jpg', '4900.jpg', '6447.jpg', '11183.jpg', '10730.jpg', '6911.jpg', '4992.jpg', '10865.jpg', '11959.jpg', '3367.jpg', '5454.jpg', '4290.jpg', '11054.jpg', '6621.jpg', '5184.jpg', '6687.jpg', '5946.jpg', '11705.jpg', '12192.jpg', '12117.jpg', '10393.jpg', '3228.jpg', '10823.jpg', '1207 ...
# train folder : ['dog', 'cat']
# validation folder : ['dog', 'cat']

# %%
# os.listdir(test_path)

# %%
os.listdir(train_path)
# Out:
# ['dog', 'cat']

# %%
classes = os.listdir(train_path)
classes
# Out:
# ['dog', 'cat']

# %% [markdown]
# **Let's check how many images there are.**

# %%
len(os.listdir(train_path+'cat')), len(os.listdir(train_path+'dog'))
# Out:
# (12500, 5026)

# %%
for dirpath, dirnames,filenames in os.walk(my_data_dir):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}")
# Out:
# There are 3 directories and 0 images in data
# There are 2 directories and 0 images in data/validation
# There are 0 directories and 1071 images in data/validation/dog
# There are 0 directories and 1219 images in data/validation/cat
# There are 2 directories and 0 images in data/train
# There are 0 directories and 5026 images in data/train/dog
# There are 0 directories and 12500 images in data/train/cat
# There are 0 directories and 6897 images in data/test

# %% [markdown]
# **Let's take an example images from both train-cat and train-dog folders to observe process**

# %%
os.listdir(train_path+'cat')[:10]
# Out:
# ['cat.11796.jpg',
#  'cat.11440.jpg',
#  'cat.11868.jpg',
#  'cat.3340.jpg',
#  'cat.12282.jpg',
#  'cat.8613.jpg',
#  'cat.529.jpg',
#  'cat.9723.jpg',
#  'cat.10807.jpg',
#  'cat.10256.jpg']

# %%
os.listdir(train_path+'cat')[5]
# Out:
# 'cat.8613.jpg'

# %%
cat_path = train_path+'cat'+'/cat.7966.jpg'
cat_path
# Out:
# 'data/train/cat/cat.7966.jpg'

# %%
cat = imread(cat_path)
cat
# Out:
# array([[[111,  99, 101],
#         [115, 103, 105],
#         [120, 108, 110],
#         ...,
#         [ 74,  62,  62],
#         [ 71,  59,  59],
#         [ 69,  57,  57]],
#
#        [[114, 102, 104],
#         [118, 106, 108],
#         [123, 111, 113],
#         ...,
#         [ 75,  63,  63],
#         [ 72,  60,  60],
#         [ 70,  58,  58]],
#
#        [[119, 107, 107],
#         [123, 111, 113],
#         [128, 116, 118],
#         ...,
#         [ 75,  63,  63],
#         [ 73,  61,  61],
#         [ 70,  58,  58]],
#
#        ...,
#
#        [[ 37,  31,  17],
#         [ 36,  30,  16],
#         [ 36,  30,  16],
#         ...,
#         [126, 112, 101],
#         [130, 116, 105],
#         [135, 121, 110]],
#
#        [[ 36,  30,  16],
#         [ 36,  30,  16],
#         [ 35,  29,  15],
#         ...,
#         [177, 163, 154],
#         [177, 163, 154],
#         [176, 162, 153]],
#
#        [[ 36,  30,  16],
#         [ 35,  29,  15],
#         [ 35,  29,  15],
#         ...,
#         [192, 177, 172],
#         [190, 175, 170],
#         [187, 172, 167]]], dtype=uint8)

# %%
plt.imshow(cat)

# %%
os.listdir(train_path+'dog')[12]
# Out:
# 'dog.10683.jpg'

# %%
dog_path = train_path+'dog'+'/dog.2395.jpg'
dog_path
# Out:
# 'data/train/dog/dog.2395.jpg'

# %%
dog = imread(dog_path)
dog
# Out:
# array([[[153, 109, 134],
#         [146, 111, 133],
#         [138, 113, 132],
#         ...,
#         [196, 211, 232],
#         [196, 211, 232],
#         [196, 211, 232]],
#
#        [[151, 117, 134],
#         [147, 119, 134],
#         [139, 121, 133],
#         ...,
#         [196, 211, 232],
#         [196, 211, 232],
#         [196, 211, 232]],
#
#        [[142, 123, 129],
#         [139, 124, 129],
#         [133, 127, 129],
#         ...,
#         [196, 211, 232],
#         [196, 211, 232],
#         [196, 211, 232]],
#
#        ...,
#
#        [[230, 244, 245],
#         [225, 239, 240],
#         [228, 242, 243],
#         ...,
#         [249, 253, 254],
#         [250, 254, 255],
#         [251, 255, 255]],
#
#        [[232, 248, 248],
#         [227, 243, 243],
#         [230, 246, 246],
#         ...,
#         [249, 253, 254],
#         [250, 254, 255],
#         [251, 255, 255]],
#
#        [[234, 250, 250],
#         [229, 245, 245],
#         [232, 248, 248],
#         ...,
#         [249, 253, 254],
#         [250, 254, 255],
#         [251, 255, 255]]], dtype=uint8)

# %%
plt.imshow(dog)

# %%
cat.shape
# Out:
# (376, 499, 3)

# %%
dog.shape
# Out:
# (379, 499, 3)

# %%
def view_random_image(target_dir, target_class):
  # Setup target directory (we'll view images from here)
  target_folder = target_dir+target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)

  # Read in the image and plot it using matplotlib
  img = imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  print(f"Image shape: {img.shape}") # show the shape of the image

  return img

# %%
# View a random image from the training dataset
import random
img = view_random_image(target_dir=train_path,
                        target_class=random.choice(classes)) # get a random class name
# Out:
# Image shape: (248, 257, 3)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Defining Input Shape

# %% [markdown]
# **Let's decide on the final dimension of these images.**

# %%
cat.shape
# Out:
# (376, 499, 3)

# %%
dog.shape
# Out:
# (379, 499, 3)

# %%
cat_x = [imread(train_path+"cat/"+image).shape[0] for image in os.listdir(train_path+"cat")]
cat_y = [imread(train_path+"cat/"+image).shape[1] for image in os.listdir(train_path+"cat")]

# %%
sns.scatterplot(cat_x, cat_y);

# %%
np.mean(cat_x), np.median(cat_x)
# Out:
# (356.46712, 374.0)

# %%
np.mean(cat_y), np.median(cat_y)
# Out:
# (410.52264, 470.0)

# %%
image_shape = (374,470,3)

# %% [markdown]
# ## Scalling

# %% [markdown]
# **Let's check the images if they are needed to be scaled or not**

# %%
cat.max()
# Out:
# 255

# %%
cat[:10]
# Out:
# array([[[111,  99, 101],
#         [115, 103, 105],
#         [120, 108, 110],
#         ...,
#         [ 74,  62,  62],
#         [ 71,  59,  59],
#         [ 69,  57,  57]],
#
#        [[114, 102, 104],
#         [118, 106, 108],
#         [123, 111, 113],
#         ...,
#         [ 75,  63,  63],
#         [ 72,  60,  60],
#         [ 70,  58,  58]],
#
#        [[119, 107, 107],
#         [123, 111, 113],
#         [128, 116, 118],
#         ...,
#         [ 75,  63,  63],
#         [ 73,  61,  61],
#         [ 70,  58,  58]],
#
#        ...,
#
#        [[132, 116, 116],
#         [135, 119, 119],
#         [139, 123, 124],
#         ...,
#         [ 81,  69,  69],
#         [ 78,  66,  66],
#         [ 76,  64,  64]],
#
#        [[135, 119, 119],
#         [136, 120, 120],
#         [138, 122, 122],
#         ...,
#         [ 79,  67,  67],
#         [ 76,  64,  64],
#         [ 72,  60,  60]],
#
#        [[138, 120, 118],
#         [139, 121, 119],
#         [141, 123, 123],
#         ...,
#         [ 80,  68,  68],
#         [ 76,  64,  64],
#         [ 73,  61,  61]]], dtype=uint8)

# %%
dog.max()
# Out:
# 255

# %%
for i in os.listdir(train_path+'cat'):
  cat_path = train_path+"cat/"+i
  cat = imread(cat_path)
  cat = cat/255

# %%
cat.max()
# Out:
# 1.0

# %%
cat.min()
# Out:
# 0.0

# %%
for i in os.listdir(train_path+'dog'):
  dog_path = train_path+"dog/"+i
  dog = imread(dog_path)
  dog = dog/255

# %%
for i in os.listdir(test_path):
  path = test_path+"/"+i
  img = imread(path)
  img = img/255

# %%
for i in os.listdir(validation_path+'dog'):
  dog_path = validation_path+"dog/"+i
  dog = imread(dog_path)
  dog = dog/255

# %%
for i in os.listdir(validation_path+'cat'):
  cat_path = validation_path+"cat/"+i
  cat = imread(cat_path)
  cat = cat/255

# %% [markdown]
# ## Image Data Generator

# %% [markdown]
# **Image Manipulation**
#
# We can use the ImageDataGenerator to manipulate the images with rotation, resizing, and scaling so the model becomes more robust to different images that our data set doesn't have. ImageDataGenerator does the followings.
#
# * Accepts a batch of images used for training.
# * Applies a series of random transformations to each image in the batch.
# * Replaces the original batch with randomly transformed batch.
# * Training the CNN on this randomly transformed batch.
#
# The goal of applying data augmentation is to have a more generalized model.
#
# Data augmentation is a way to try and prevent a model overfitting. If your model is overfiting (e.g. the validation loss keeps increasing), you may want to try using data augmentation.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=15, 
                               width_shift_range=0.10, 
                               height_shift_range=0.10, 
                               #rescale=1/255, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest')

# %%
plt.imshow(cat)

# %%
plt.imshow(image_gen.random_transform(cat))

# %% [markdown]
# ### Taking the path to a directory & Generating batches of augmented data
#
# flow_from_directory function works with images organized in sub-directories. Your directories should include only one class of images, so one folder per class of images.

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 17526 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 0 images belonging to 0 classes.

# %%
image_gen.flow_from_directory(validation_path)
# Out:
# Found 2290 images belonging to 2 classes.

# %%
batch_size = 32

# %%
image_shape
# Out:
# (374, 470, 3)

# %%
train_image_gen = image_gen.flow_from_directory(directory=train_path,
                                                target_size=image_shape[:2],
                                                color_mode='rgb',
                                                batch_size=batch_size,
                                                class_mode='binary',
                                                shuffle=True)
# Out:
# Found 17526 images belonging to 2 classes.

# %%
validation_image_gen = image_gen.flow_from_directory(directory=validation_path,
                                               target_size=image_shape[:2],
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='binary',
                                               shuffle=False)
# Out:
# Found 2290 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
validation_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
# train_image_gen[0]

# %%
train_image_gen[0][0].shape
# Out:
# (32, 374, 470, 3)

# %%
train_image_gen[0][0][0].shape
# Out:
# (374, 470, 3)

# %%
len(train_image_gen), len(validation_image_gen)
# Out:
# (548, 72)

# %% [markdown]
# # Modelling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
model1 = Sequential()

model1.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=image_shape, activation="relu"))
model1.add(MaxPooling2D(pool_size=(2,2)))

model1.add(Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
model1.add(MaxPooling2D(pool_size=(2,2)))

model1.add(Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
model1.add(MaxPooling2D(pool_size=(2,2)))

model1.add(Flatten())

model1.add(Dense(128, activation="relu"))
model1.add(Dropout(0.2))

model1.add(Dense(1, activation="sigmoid"))

model1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
model1.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 372, 468, 32)      896
#
#  max_pooling2d_12 (MaxPoolin  (None, 186, 234, 32)     0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 184, 232, 64)      18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 92, 116, 64)      0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 90, 114, 64)       36928
#
#  max_pooling2d_14 (MaxPoolin  (None, 45, 57, 64)       0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 164160)            0
#
#  dense_5 (Dense)             (None, 128)               21012608
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 21,069,057
# Trainable params: 21,069,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor="val_accuracy", patience=3, restore_best_weights=True)

# %%
model1.fit(train_image_gen, 
           epochs=10,
           steps_per_epoch=len(train_image_gen),
           validation_data=validation_image_gen,
           validation_steps=len(validation_image_gen),
           callbacks=[early_stop])

# %% [markdown]
# # Evaluation on Test Data

# %% [markdown]
# # Prediction

# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>
