# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "RFM Customer Segmentation & Cohort Analysis Project". This is the first project of the Capstone Project Series, which consists of 3 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply RFM Analysis and Customer Segmentation using K-Means Clustering. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct Cohort Analysis.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# ## Tasks

# %% [markdown]
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*

# %% [markdown]
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*

# %% [markdown]
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments

# %% [markdown]
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*

# %% [markdown]
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# pd.set_option("display.float_format", lambda x : "%.3f" %x)
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 100)
pd.set_option('display.float_format','{:.2f}'.format)

# %%
df = pd.read_csv("Online Retail.xlsx - Online Retail.csv")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55    17850.00  United Kingdom
# 1  12/1/10 8:26       3.39    17850.00  United Kingdom
# 2  12/1/10 8:26       2.75    17850.00  United Kingdom
# 3  12/1/10 8:26       3.39    17850.00  United Kingdom
# 4  12/1/10 8:26       3.39    17850.00  United Kingdom

# %%
df_copy = df

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/11 12:50       0.85    12680.00  France
# 541905  12/9/11 12:50       2.10    12680.00  France
# 541906  12/9/11 12:50       4.15    12680.00  France
# 541907  12/9/11 12:50       4.15    12680.00  France
# 541908  12/9/11 12:50       4.95    12680.00  France

# %%
df.sample(10)
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 353186    567792     35970         ZINC FOLKART SLEIGH BELLS        12
# 353618    567818     22382        LUNCH BAG SPACEBOY DESIGN          1
# 132786    547695     21382    SET/4 SPRING FLOWER DECORATION        12
# 292656    562558     20717            STRAWBERRY SHOPPER BAG         3
# 448202    575039     23582      VINTAGE DOILY JUMBO BAG RED          4
# 356       536401     22068       BLACK PIRATE TREASURE CHEST         2
# 96981     544598    85099B           JUMBO BAG RED RETROSPOT         1
# 249480    558904     23250     VINTAGE RED TRIM ENAMEL BOWL          4
# 191568    553375     21468      BUTTERFLY CROCHET FOOD COVER         6
# 213737    555553     21249  WOODLAND  HEIGHT CHART STICKERS          6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 353186  9/22/11 11:40       1.69    17581.00  United Kingdom
# 353618  9/22/11 12:41       1.65    14395.00  United Kingdom
# ...

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.isna().sum()/len(df)*100
# Out:
# InvoiceNo      0.00
# StockCode      0.00
# Description    0.27
# Quantity       0.00
# InvoiceDate    0.00
# UnitPrice      0.00
# CustomerID    24.93
# Country        0.00
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 5268

# %%
df.drop_duplicates(inplace=True, ignore_index=True)

# %%
df.shape
# Out:
# (536641, 8)

# %%
df.describe()
# Out:
#        Quantity  UnitPrice  CustomerID
# count 536641.00  536641.00   401604.00
# mean       9.62       4.63    15281.16
# std      219.13      97.23     1714.01
# min   -80995.00  -11062.06    12346.00
# 25%        1.00       1.25    13939.00
# 50%        3.00       2.08    15145.00
# 75%       10.00       4.13    16784.00
# max    80995.00   38970.00    18287.00

# %%
df.describe(include="O")
# Out:
#        InvoiceNo StockCode                         Description  \
# count     536641    536641                              535187
# unique     25900      4070                                4223
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq        1114      2301                                2357
#
#            InvoiceDate         Country
# count           536641          536641
# unique           23260              38
# top     10/31/11 14:41  United Kingdom
# freq              1114          490300

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# InvoiceNo      0.00
# StockCode      0.00
# Description    0.27
# Quantity       0.00
# InvoiceDate    0.00
# UnitPrice      0.00
# CustomerID    25.16
# Country        0.00
# dtype: float64

# %%
def check_df(col):
  print('column name : ', col)
  print('--------------------------------')
  print('Per_of_Nulls           : ', '%', round(df[col].isnull().sum()*100/len(df), 2))
  print('Num_of_Nulls           : ', df[col].isnull().sum())
  print('Num_of_Unique_Values   : ', df[col].nunique())
  print(df[col].value_counts(dropna = False))
  print("*"*30)
  print("\n\n")


for col in df.columns :
  check_df(col)
# Out:
# column name :  InvoiceNo
# --------------------------------
# Per_of_Nulls           :  % 0.0
# Num_of_Nulls           :  0
# Num_of_Unique_Values   :  25900
# 573585     1114
# 581219      749
# 581492      731
# 580729      721
# 558475      705
#            ...
# 570518        1
# C550935       1
# 550937        1
# 550940        1
# C558901       1
# Name: InvoiceNo, Length: 25900, dtype: int64
# ******************************
#
#
#
# column name :  StockCode
# --------------------------------
# Per_of_Nulls           :  % 0.0
# Num_of_Nulls           :  0
# Num_of_Unique_Values   :  4070
# 85123A    2301
# 22423     2192
# 85099B    2156
# 47566     1720
# 20725     1626
#           ...
# 72781        1
# 35015        1
# 72793        1
# 72789        1
# 90091        1
# Name: StockCode, Length: 4070, dtype: int64
# ******************************
#
#
#
# column name :  Description
# --------------------------------
# Per_of_Nulls           :  % 0.27
# ...

# %%
df[df["CustomerID"].isnull()]["Country"].value_counts()
# Out:
# United Kingdom    133572
# EIRE                 709
# Hong Kong            284
# Unspecified          201
# Switzerland          117
# France                66
# Israel                47
# Portugal              39
# Bahrain                2
# Name: Country, dtype: int64

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %%
df.corr()
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity        1.00      -0.00       -0.00
# UnitPrice      -0.00       1.00       -0.00
# CustomerID     -0.00      -0.00        1.00

# %%
sns.heatmap(df.corr());

# %%
df[df.Quantity < 0].shape
# Out:
# (10587, 8)

# %%
df[df.Quantity < 0].sample(5)
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 130226    547559     72759           thrown away-can't sell.      -524
# 30580    C538889     22623     BOX OF VINTAGE JIGSAW BLOCKS         -3
# 504630   C579347     22163  HEART STRING MEMO HOLDER HANGING       -24
# 261119   C559952     23146    TRIPLE HOOK ANTIQUE IVORY ROSE        -3
# 417731   C572927     35970         ZINC FOLKART SLEIGH BELLS        -9
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 130226   3/23/11 17:27       0.00         NaN  United Kingdom
# 30580   12/14/10 16:24       4.95    12797.00        Portugal
# 504630  11/29/11 11:47       0.79    17658.00  United Kingdom
# 261119   7/14/11 10:57       3.29    17696.00  United Kingdom
# 417731   10/27/11 9:25       1.69    14233.00  United Kingdom

# %%
df[df.UnitPrice < 0].shape
# Out:
# (2, 8)

# %%
df[df.UnitPrice < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity    InvoiceDate  \
# 297646   A563186         B  Adjust bad debt         1  8/12/11 14:51
# 297647   A563187         B  Adjust bad debt         1  8/12/11 14:52
#
#         UnitPrice  CustomerID         Country
# 297646  -11062.06         NaN  United Kingdom
# 297647  -11062.06         NaN  United Kingdom

# %%
df[df.UnitPrice == 0].shape
# Out:
# (2510, 8)

# %%
df[df.UnitPrice <= 0].sample(5)
# Out:
#        InvoiceNo StockCode Description  Quantity    InvoiceDate  UnitPrice  \
# 530108    581213     22576       check       -30  12/7/11 18:38       0.00
# 148797    549343     72815         NaN        -3   4/8/11 11:07       0.00
# 74532     542573     85110         NaN        -1  1/28/11 14:55       0.00
# 271101    560819     21686         NaN         2  7/21/11 10:53       0.00
# 328469    565935     23064     Crushed        -8   9/8/11 10:46       0.00
#
#         CustomerID         Country
# 530108         NaN  United Kingdom
# 148797         NaN  United Kingdom
# 74532          NaN  United Kingdom
# 271101         NaN  United Kingdom
# 328469         NaN  United Kingdom

# %%
df[(df.UnitPrice <= 0) & (df.Quantity <= 0)]
# Out:
#        InvoiceNo StockCode Description  Quantity    InvoiceDate  UnitPrice  \
# 2362      536589     21777         NaN       -10  12/1/10 16:50       0.00
# 4286      536764    84952C         NaN       -38  12/2/10 14:42       0.00
# 7086      536996     22712         NaN       -20  12/3/10 15:30       0.00
# 7087      536997     22028         NaN       -20  12/3/10 15:30       0.00
# 7088      536998     85067         NaN        -6  12/3/10 15:30       0.00
# ...          ...       ...         ...       ...            ...        ...
# 530105    581210     23395       check       -26  12/7/11 18:36       0.00
# 530107    581212     22578        lost     -1050  12/7/11 18:38       0.00
# 530108    581213     22576       check       -30  12/7/11 18:38       0.00
# 531680    581226     23090     missing      -338   12/8/11 9:56       0.00
# 533665    581422     23169     smashed      -235  12/8/11 15:24       0.00
#
#         CustomerID         Country
# ...

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %% [markdown]
# hint: If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %%
df[df.InvoiceNo.str.startswith("C")]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 535188   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 536280   C581499         M                            Manual        -1
# 536447   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 536448   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 536449   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df.InvoiceNo.str.startswith("A")]
# Out:
#        InvoiceNo StockCode      Description  Quantity    InvoiceDate  \
# 297645   A563185         B  Adjust bad debt         1  8/12/11 14:50
# 297646   A563186         B  Adjust bad debt         1  8/12/11 14:51
# 297647   A563187         B  Adjust bad debt         1  8/12/11 14:52
#
#         UnitPrice  CustomerID         Country
# 297645   11062.06         NaN  United Kingdom
# 297646  -11062.06         NaN  United Kingdom
# 297647  -11062.06         NaN  United Kingdom

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %%
df[df.Quantity < 0].shape
# Out:
# (10587, 8)

# %%
df[df.Quantity < 0]["InvoiceNo"].nunique()
# Out:
# 5172

# %%
df.InvoiceNo.str[0].unique()
# Out:
# array(['5', 'C', 'A'], dtype=object)

# %%
df[df.Quantity < 0]["UnitPrice"].sort_values()
# Out:
# 261738       0.00
# 424908       0.00
# 425001       0.00
# 425003       0.00
# 425004       0.00
#            ...
# 16087    13541.33
# 43194    16453.71
# 43193    16888.02
# 519497   17836.46
# 220826   38970.00
# Name: UnitPrice, Length: 10587, dtype: float64

# %%
# !!!!!!!!!!!!!!!!!!!

df[~(df.InvoiceNo.str.startswith("C")) & (df.Quantity < 0)] # returned products
# Out:
#        InvoiceNo StockCode Description  Quantity    InvoiceDate  UnitPrice  \
# 2362      536589     21777         NaN       -10  12/1/10 16:50       0.00
# 4286      536764    84952C         NaN       -38  12/2/10 14:42       0.00
# 7086      536996     22712         NaN       -20  12/3/10 15:30       0.00
# 7087      536997     22028         NaN       -20  12/3/10 15:30       0.00
# 7088      536998     85067         NaN        -6  12/3/10 15:30       0.00
# ...          ...       ...         ...       ...            ...        ...
# 530105    581210     23395       check       -26  12/7/11 18:36       0.00
# 530107    581212     22578        lost     -1050  12/7/11 18:38       0.00
# 530108    581213     22576       check       -30  12/7/11 18:38       0.00
# 531680    581226     23090     missing      -338   12/8/11 9:56       0.00
# 533665    581422     23169     smashed      -235  12/8/11 15:24       0.00
#
#         CustomerID         Country
# ...

# %% [markdown]
# #### Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
df[(df.UnitPrice < 0)]
# Out:
#        InvoiceNo StockCode      Description  Quantity    InvoiceDate  \
# 297646   A563186         B  Adjust bad debt         1  8/12/11 14:51
# 297647   A563187         B  Adjust bad debt         1  8/12/11 14:52
#
#         UnitPrice  CustomerID         Country
# 297646  -11062.06         NaN  United Kingdom
# 297647  -11062.06         NaN  United Kingdom

# %% [markdown]
# ### iii. Handling Missing Values

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df.drop(columns="Description", inplace=True)

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (401604, 7)

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df[df.Quantity > 40000]
# Out:
#        InvoiceNo StockCode  Quantity    InvoiceDate  UnitPrice  CustomerID  \
# 37511     541431     23166     74215  1/18/11 10:01       1.04    12346.00
# 401131    581483     23843     80995   12/9/11 9:15       2.08    16446.00
#
#                Country
# 37511   United Kingdom
# 401131  United Kingdom

# %%
df[df.UnitPrice>20000]["StockCode"]
# Out:
# 157406    M
# Name: StockCode, dtype: object

# %%
df[df.StockCode == "M"]
# Out:
#        InvoiceNo StockCode  Quantity    InvoiceDate  UnitPrice  CustomerID  \
# 1654      536569         M         1  12/1/10 15:35       1.25    16274.00
# 1665      536569         M         1  12/1/10 15:35      18.95    16274.00
# 4606      536981         M         2  12/3/10 14:26       0.85    14723.00
# 5572      537077         M        12  12/5/10 11:59       0.42    17062.00
# 6115      537137         M        36  12/5/10 12:43       0.85    16327.00
# ...          ...       ...       ...            ...        ...         ...
# 395434    580956         M         4  12/6/11 14:23       1.25    17841.00
# 396440   C581009         M        -1   12/7/11 9:15     125.00    16971.00
# 397435   C581145         M        -1  12/7/11 13:48       9.95    17490.00
# 399698    581405         M         3  12/8/11 13:50       0.42    13521.00
# 401243   C581499         M        -1  12/9/11 10:28     224.69    15498.00
#
#                Country
# 1654    United Kingdom
# ...

# %%
sns.boxplot(x=df["Quantity"])
# Out:
# <AxesSubplot:xlabel='Quantity'>

# %%
sns.boxplot(data = df.loc[(df.Quantity<5000) & (df.Quantity > -5000)], x="Quantity")
# Out:
# <AxesSubplot:xlabel='Quantity'>

# %%
df.StockCode.str.len().value_counts()
# Out:
# 5     366179
# 6      33214
# 4       1216
# 1        537
# 7        296
# 2        134
# 3         16
# 12        12
# Name: StockCode, dtype: int64

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
df.groupby("CustomerID")["InvoiceNo"].nunique().sort_values(ascending=False)
# Out:
# CustomerID
# 14911.00    248
# 12748.00    224
# 17841.00    169
# 14606.00    128
# 13089.00    118
#            ...
# 13877.00      1
# 16400.00      1
# 13878.00      1
# 13886.00      1
# 13670.00      1
# Name: InvoiceNo, Length: 4372, dtype: int64

# %%
df.groupby("CustomerID")["InvoiceNo"].count().sort_values(ascending=False)
# Out:
# CustomerID
# 17841.00    7812
# 14911.00    5898
# 14096.00    5128
# 12748.00    4459
# 14606.00    2759
#             ...
# 16323.00       1
# 13302.00       1
# 16428.00       1
# 13270.00       1
# 13307.00       1
# Name: InvoiceNo, Length: 4372, dtype: int64

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
df.head()
# Out:
#   InvoiceNo StockCode  Quantity   InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6  12/1/10 8:26       2.55    17850.00
# 1    536365     71053         6  12/1/10 8:26       3.39    17850.00
# 2    536365    84406B         8  12/1/10 8:26       2.75    17850.00
# 3    536365    84029G         6  12/1/10 8:26       3.39    17850.00
# 4    536365    84029E         6  12/1/10 8:26       3.39    17850.00
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom

# %%
df.groupby("InvoiceNo")["StockCode"].nunique().mean()
# Out:
# 17.87656602073006

# %%
df.groupby("CustomerID")["StockCode"].nunique().mean()
# Out:
# 61.21111619396157

# %%
df.groupby("CustomerID")["InvoiceNo"].nunique().mean()
# Out:
# 5.07548032936871

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
df.groupby("CustomerID")["StockCode"].value_counts().sort_values(ascending=False)
# Out:
# CustomerID  StockCode
# 14911.00    C2           85
# 17841.00    79321        64
# 14911.00    22423        55
# 17841.00    21927        54
#             21975        51
#                          ..
# 14577.00    22190         1
#             22355         1
#             22372         1
#             22374         1
# 18287.00    85173         1
# Name: StockCode, Length: 267615, dtype: int64

# %% [markdown]
# ### vi. Explore Customers by Country

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df["Revenue"] = df["Quantity"] * df["UnitPrice"]
df["Revenue"]
# Out:
# 0        15.30
# 1        20.34
# 2        22.00
# 3        20.34
# 4        20.34
#           ...
# 401599   10.20
# 401600   12.60
# 401601   16.60
# 401602   16.60
# 401603   14.85
# Name: Revenue, Length: 401604, dtype: float64

# %%
revenue_per_country = df.groupby("Country")["Revenue"].sum().sort_values(ascending=False)
revenue_per_country
# Out:
# Country
# United Kingdom         6747156.15
# Netherlands             284661.54
# EIRE                    250001.78
# Germany                 221509.47
# France                  196626.05
# Australia               137009.77
# Switzerland              55739.40
# Spain                    54756.03
# Belgium                  40910.96
# Sweden                   36585.41
# Japan                    35340.62
# Norway                   35163.46
# Portugal                 28995.76
# Finland                  22326.74
# Channel Islands          20076.39
# Denmark                  18768.14
# Italy                    16890.51
# Cyprus                   12858.76
# Austria                  10154.32
# Singapore                 9120.39
# Poland                    7213.14
# Israel                    6988.40
# Greece                    4710.52
# Iceland                   4310.00
# Canada                    3666.38
# Unspecified               2660.77
# Malta                     2505.47
# ...

# %% [markdown]
# 2. Visualize number of customer per country

# %%
customer_per_country = df.groupby("Country")["CustomerID"].nunique().sort_values(ascending=False)
customer_per_country
# Out:
# Country
# United Kingdom          3950
# Germany                   95
# France                    87
# Spain                     31
# Belgium                   25
# Switzerland               21
# Portugal                  19
# Italy                     15
# Finland                   12
# Austria                   11
# Norway                    10
# Netherlands                9
# Australia                  9
# Denmark                    9
# Channel Islands            9
# Cyprus                     8
# Sweden                     8
# Japan                      8
# Poland                     6
# USA                        4
# Canada                     4
# Unspecified                4
# Israel                     4
# Greece                     4
# EIRE                       3
# Malta                      2
# United Arab Emirates       2
# Bahrain                    2
# Czech Republic             1
# Lithuania                  1
# Lebanon                    1
# ...

# %%
plt.figure(figsize=(8,8))
ax = sns.barplot(y=customer_per_country.index, x = customer_per_country.values)
plt.xticks(rotation=90);
ax.bar_label(ax.containers[0])
plt.tight_layout;

# %% [markdown]
# 3. Visualize total cost per country

# %%
plt.figure(figsize=(8,8))
ax = sns.barplot(y=revenue_per_country.index, x = revenue_per_country.values)
plt.xticks(rotation=90);
ax.bar_label(ax.containers[0])
plt.tight_layout;

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df_uk = df[df.Country == "United Kingdom"]
df_uk.head()
# Out:
#   InvoiceNo StockCode  Quantity   InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6  12/1/10 8:26       2.55    17850.00
# 1    536365     71053         6  12/1/10 8:26       3.39    17850.00
# 2    536365    84406B         8  12/1/10 8:26       2.75    17850.00
# 3    536365    84029G         6  12/1/10 8:26       3.39    17850.00
# 4    536365    84029E         6  12/1/10 8:26       3.39    17850.00
#
#           Country  Revenue
# 0  United Kingdom    15.30
# 1  United Kingdom    20.34
# 2  United Kingdom    22.00
# 3  United Kingdom    20.34
# 4  United Kingdom    20.34

# %%
df_uk.reset_index(drop=True,inplace=True)

# %%
df_uk.index
# Out:
# RangeIndex(start=0, stop=356728, step=1)

# %%
df_uk.shape
# Out:
# (356728, 8)

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
df_uk.groupby("StockCode")["StockCode"].count().sort_values(ascending=False)
# Out:
# StockCode
# 85123A    1976
# 22423     1564
# 85099B    1502
# 84879     1330
# 47566     1320
#           ...
# 20667        1
# 90152B       1
# 90152C       1
# 84773        1
# 37351        1
# Name: StockCode, Length: 3661, dtype: int64

# %%
df_uk.groupby("StockCode")["Quantity"].sum().sort_values(ascending=False)
# Out:
# StockCode
# 84077     47886
# 22197     45194
# 85099B    40777
# 84879     32580
# 85123A    32136
#           ...
# CRUK        -16
# POST        -21
# 21645       -24
# D         -1191
# 84347     -1868
# Name: Quantity, Length: 3661, dtype: int64

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk.head()
# Out:
#   InvoiceNo StockCode  Quantity   InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6  12/1/10 8:26       2.55    17850.00
# 1    536365     71053         6  12/1/10 8:26       3.39    17850.00
# 2    536365    84406B         8  12/1/10 8:26       2.75    17850.00
# 3    536365    84029G         6  12/1/10 8:26       3.39    17850.00
# 4    536365    84029E         6  12/1/10 8:26       3.39    17850.00
#
#           Country  Revenue
# 0  United Kingdom    15.30
# 1  United Kingdom    20.34
# 2  United Kingdom    22.00
# 3  United Kingdom    20.34
# 4  United Kingdom    20.34

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356728 entries, 0 to 356727
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    356728 non-null  object
#  1   StockCode    356728 non-null  object
#  2   Quantity     356728 non-null  int64
#  3   InvoiceDate  356728 non-null  object
#  4   UnitPrice    356728 non-null  float64
#  5   CustomerID   356728 non-null  float64
#  6   Country      356728 non-null  object
#  7   Revenue      356728 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 21.8+ MB

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
df_uk.InvoiceDate = pd.to_datetime(df_uk.InvoiceDate)
df_uk.InvoiceDate
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 356723   2011-12-09 12:31:00
# 356724   2011-12-09 12:49:00
# 356725   2011-12-09 12:49:00
# 356726   2011-12-09 12:49:00
# 356727   2011-12-09 12:49:00
# Name: InvoiceDate, Length: 356728, dtype: datetime64[ns]

# %%
df_uk.InvoiceDate.max()
# Out:
# Timestamp('2011-12-09 12:49:00')

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
df_uk["date"] = df_uk.InvoiceDate.dt.date
df_uk["date"]
# Out:
# 0         2010-12-01
# 1         2010-12-01
# 2         2010-12-01
# 3         2010-12-01
# 4         2010-12-01
#              ...
# 356723    2011-12-09
# 356724    2011-12-09
# 356725    2011-12-09
# 356726    2011-12-09
# 356727    2011-12-09
# Name: date, Length: 356728, dtype: object

# %%
# we decided that today's date is 2011-12-10 

current_time = df_uk.date.max() + datetime.timedelta(days=1) 
current_time
# Out:
# datetime.date(2011, 12, 10)

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
Recency = pd.DataFrame(df_uk.groupby("CustomerID")["date"].max())
Recency = Recency.reset_index()
Recency
# Out:
#       CustomerID        date
# 0       12346.00  2011-01-18
# 1       12747.00  2011-12-07
# 2       12748.00  2011-12-09
# 3       12749.00  2011-12-06
# 4       12820.00  2011-12-06
# ...          ...         ...
# 3945    18280.00  2011-03-07
# 3946    18281.00  2011-06-12
# 3947    18282.00  2011-12-02
# 3948    18283.00  2011-12-06
# 3949    18287.00  2011-10-28
#
# [3950 rows x 2 columns]

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
Recency["time_gap"] = current_time - Recency.date
Recency
# Out:
#       CustomerID        date time_gap
# 0       12346.00  2011-01-18 326 days
# 1       12747.00  2011-12-07   3 days
# 2       12748.00  2011-12-09   1 days
# 3       12749.00  2011-12-06   4 days
# 4       12820.00  2011-12-06   4 days
# ...          ...         ...      ...
# 3945    18280.00  2011-03-07 278 days
# 3946    18281.00  2011-06-12 181 days
# 3947    18282.00  2011-12-02   8 days
# 3948    18283.00  2011-12-06   4 days
# 3949    18287.00  2011-10-28  43 days
#
# [3950 rows x 3 columns]

# %%
Recency.time_gap = Recency.time_gap.astype("str").str.extract(r"(\d+)").astype("int")

# %%
Recency
# Out:
#       CustomerID        date  time_gap
# 0       12346.00  2011-01-18       326
# 1       12747.00  2011-12-07         3
# 2       12748.00  2011-12-09         1
# 3       12749.00  2011-12-06         4
# 4       12820.00  2011-12-06         4
# ...          ...         ...       ...
# 3945    18280.00  2011-03-07       278
# 3946    18281.00  2011-06-12       181
# 3947    18282.00  2011-12-02         8
# 3948    18283.00  2011-12-06         4
# 3949    18287.00  2011-10-28        43
#
# [3950 rows x 3 columns]

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %% [markdown]
# 6. Plot RFM distributions

# %%
sns.histplot(x=Recency.time_gap, kde=True);

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
df_uk_copy = df_uk

# %%
df_uk.duplicated().sum()
# Out:
# 2

# %%
df_uk.drop_duplicates(inplace=True, ignore_index=True)

# %%
df_uk.index
# Out:
# RangeIndex(start=0, stop=356726, step=1)

# %% [markdown]
# 2. Calculate the frequency of purchases

# %%
Frequency = pd.DataFrame(df_uk.groupby("CustomerID")["InvoiceNo"].nunique().sort_values(ascending=False))
Frequency = Frequency.reset_index()
Frequency.rename(columns={"InvoiceNo":"count_of_invoice"},inplace=True)
Frequency
# Out:
#       CustomerID  count_of_invoice
# 0       12748.00               224
# 1       17841.00               169
# 2       14606.00               128
# 3       13089.00               118
# 4       15311.00               118
# ...          ...               ...
# 3945    17030.00                 1
# 3946    14861.00                 1
# 3947    15986.00                 1
# 3948    13858.00                 1
# 3949    14055.00                 1
#
# [3950 rows x 2 columns]

# %% [markdown]
# 3. Plot RFM distributions

# %%
sns.histplot(x=Frequency.count_of_invoice, kde=True, bins=50);

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
Monetary = pd.DataFrame(df_uk.groupby("CustomerID")["Revenue"].sum())
Monetary = Monetary.reset_index()
Monetary.rename(columns={"Revenue":"total_spend"}, inplace=True)
Monetary
# Out:
#       CustomerID  total_spend
# 0       12346.00         0.00
# 1       12747.00      4196.01
# 2       12748.00     28405.56
# 3       12749.00      3868.20
# 4       12820.00       942.34
# ...          ...          ...
# 3945    18280.00       180.60
# 3946    18281.00        80.82
# 3947    18282.00       176.60
# 3948    18283.00      2045.53
# 3949    18287.00      1837.28
#
# [3950 rows x 2 columns]

# %% [markdown]
# 2. Plot RFM distributions

# %%
sns.histplot(x=Monetary.total_spend, kde=True, bins=100);

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
re_fr = pd.merge(Recency, Frequency, on="CustomerID")

# %%
df_rfm = pd.merge(re_fr, Monetary, on="CustomerID")
df_rfm
# Out:
#       CustomerID        date  time_gap  count_of_invoice  total_spend
# 0       12346.00  2011-01-18       326                 2         0.00
# 1       12747.00  2011-12-07         3                11      4196.01
# 2       12748.00  2011-12-09         1               224     28405.56
# 3       12749.00  2011-12-06         4                 8      3868.20
# 4       12820.00  2011-12-06         4                 4       942.34
# ...          ...         ...       ...               ...          ...
# 3945    18280.00  2011-03-07       278                 1       180.60
# 3946    18281.00  2011-06-12       181                 1        80.82
# 3947    18282.00  2011-12-02         8                 3       176.60
# 3948    18283.00  2011-12-06         4                16      2045.53
# 3949    18287.00  2011-10-28        43                 3      1837.28
#
# [3950 rows x 5 columns]

# %%
df_rfm.drop(columns="date", inplace=True)

# %%
df_rfm.rename(columns={"time_gap":"recency", "count_of_invoice":"frequency", "total_spend":"monetary"}, inplace=True)

# %%
df_rfm
# Out:
#       CustomerID  recency  frequency  monetary
# 0       12346.00      326          2      0.00
# 1       12747.00        3         11   4196.01
# 2       12748.00        1        224  28405.56
# 3       12749.00        4          8   3868.20
# 4       12820.00        4          4    942.34
# ...          ...      ...        ...       ...
# 3945    18280.00      278          1    180.60
# 3946    18281.00      181          1     80.82
# 3947    18282.00        8          3    176.60
# 3948    18283.00        4         16   2045.53
# 3949    18287.00       43          3   1837.28
#
# [3950 rows x 4 columns]

# %%
df_rfm_copy = df_rfm.copy()

# %%
df_rfm_copy
# Out:
#       CustomerID  recency  frequency  monetary
# 0       12346.00      326          2      0.00
# 1       12747.00        3         11   4196.01
# 2       12748.00        1        224  28405.56
# 3       12749.00        4          8   3868.20
# 4       12820.00        4          4    942.34
# ...          ...      ...        ...       ...
# 3945    18280.00      278          1    180.60
# 3946    18281.00      181          1     80.82
# 3947    18282.00        8          3    176.60
# 3948    18283.00        4         16   2045.53
# 3949    18287.00       43          3   1837.28
#
# [3950 rows x 4 columns]

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %%
df_rfm
# Out:
#       CustomerID  recency  frequency  monetary
# 0       12346.00      326          2      0.00
# 1       12747.00        3         11   4196.01
# 2       12748.00        1        224  28405.56
# 3       12749.00        4          8   3868.20
# 4       12820.00        4          4    942.34
# ...          ...      ...        ...       ...
# 3945    18280.00      278          1    180.60
# 3946    18281.00      181          1     80.82
# 3947    18282.00        8          3    176.60
# 3948    18283.00        4         16   2045.53
# 3949    18287.00       43          3   1837.28
#
# [3950 rows x 4 columns]

# %%
df_rfm.describe()
# Out:
#        CustomerID  recency  frequency  monetary
# count     3950.00  3950.00    3950.00   3950.00
# mean     15562.03    92.32       5.03   1708.00
# std       1576.85   100.24       8.72   6548.28
# min      12346.00     1.00       1.00  -4287.63
# 25%      14208.25    17.00       1.00    281.03
# 50%      15571.50    51.00       3.00    623.34
# 75%      16913.75   144.00       5.00   1517.80
# max      18287.00   374.00     224.00 256438.49

# %%
df_rfm.quantile(q = [0, 0.25,0.50,0.75, 1])
# Out:
#       CustomerID  recency  frequency  monetary
# 0.00    12346.00     1.00       1.00  -4287.63
# 0.25    14208.25    17.00       1.00    281.03
# 0.50    15571.50    51.00       3.00    623.34
# 0.75    16913.75   144.00       5.00   1517.80
# 1.00    18287.00   374.00     224.00 256438.49

# %%
df_rfm_copy = df_rfm

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %%
df_rfm[df_rfm["recency"] <= df_rfm["recency"].quantile(0.25)]["recency"]
# Out:
# 1       3
# 2       1
# 3       4
# 4       4
# 9       3
#        ..
# 3920    8
# 3939    3
# 3940    3
# 3947    8
# 3948    4
# Name: recency, Length: 989, dtype: int32

# %%
df_rfm
# Out:
#       CustomerID  recency  frequency  monetary
# 0       12346.00      326          2      0.00
# 1       12747.00        3         11   4196.01
# 2       12748.00        1        224  28405.56
# 3       12749.00        4          8   3868.20
# 4       12820.00        4          4    942.34
# ...          ...      ...        ...       ...
# 3945    18280.00      278          1    180.60
# 3946    18281.00      181          1     80.82
# 3947    18282.00        8          3    176.60
# 3948    18283.00        4         16   2045.53
# 3949    18287.00       43          3   1837.28
#
# [3950 rows x 4 columns]

# %%
df_rfm["re_score"] = pd.qcut(df_rfm["recency"], q=[0, 0.25, 0.5, 0.75, 1.], labels=[4,3,2,1])

# %%
df_rfm["fre_score"] = pd.qcut(df_rfm["frequency"], q=[0, 0.31, 0.5, 0.75, 1.], labels=[1,2,3,4], duplicates="drop")

# %%
df_rfm["mon_score"] = pd.qcut(df_rfm["monetary"], q=[0, 0.25, 0.5, 0.75, 1.], labels=[1,2,3,4])

# %%
df_rfm
# Out:
#       CustomerID  recency  frequency  monetary re_score fre_score mon_score
# 0       12346.00      326          2      0.00        1         1         1
# 1       12747.00        3         11   4196.01        4         4         4
# 2       12748.00        1        224  28405.56        4         4         4
# 3       12749.00        4          8   3868.20        4         4         4
# 4       12820.00        4          4    942.34        4         3         3
# ...          ...      ...        ...       ...      ...       ...       ...
# 3945    18280.00      278          1    180.60        1         1         1
# 3946    18281.00      181          1     80.82        1         1         1
# 3947    18282.00        8          3    176.60        4         2         1
# 3948    18283.00        4         16   2045.53        4         4         4
# 3949    18287.00       43          3   1837.28        3         2         4
#
# [3950 rows x 7 columns]

# %%
df_rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3950 entries, 0 to 3949
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  3950 non-null   float64
#  1   recency     3950 non-null   int32
#  2   frequency   3950 non-null   int64
#  3   monetary    3950 non-null   float64
#  4   re_score    3950 non-null   category
#  5   fre_score   3950 non-null   category
#  6   mon_score   3950 non-null   category
# dtypes: category(3), float64(2), int32(1), int64(1)
# memory usage: 151.0 KB

# %%
df_rfm.re_score = df_rfm.re_score.astype(int)
df_rfm.fre_score = df_rfm.fre_score.astype(int)
df_rfm.mon_score = df_rfm.mon_score.astype(int)

# %%
df_rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3950 entries, 0 to 3949
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  3950 non-null   float64
#  1   recency     3950 non-null   int32
#  2   frequency   3950 non-null   int64
#  3   monetary    3950 non-null   float64
#  4   re_score    3950 non-null   int32
#  5   fre_score   3950 non-null   int32
#  6   mon_score   3950 non-null   int32
# dtypes: float64(2), int32(4), int64(1)
# memory usage: 185.2 KB

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.

# %%
df_rfm["RFM_Score"] = (df_rfm.re_score+ df_rfm.fre_score+df_rfm.mon_score)/3

# %%
df_rfm
# Out:
#       CustomerID  recency  frequency  monetary  re_score  fre_score  \
# 0       12346.00      326          2      0.00         1          1
# 1       12747.00        3         11   4196.01         4          4
# 2       12748.00        1        224  28405.56         4          4
# 3       12749.00        4          8   3868.20         4          4
# 4       12820.00        4          4    942.34         4          3
# ...          ...      ...        ...       ...       ...        ...
# 3945    18280.00      278          1    180.60         1          1
# 3946    18281.00      181          1     80.82         1          1
# 3947    18282.00        8          3    176.60         4          2
# 3948    18283.00        4         16   2045.53         4          4
# 3949    18287.00       43          3   1837.28         3          2
#
#       mon_score  RFM_Score
# 0             1       1.00
# 1             4       4.00
# 2             4       4.00
# 3             4       4.00
# ...

# %%
df_rfm.RFM_Score.value_counts().sort_index()
# Out:
# 1.00    452
# 1.33    495
# 1.67    509
# 2.00    451
# 2.33    347
# 2.67    272
# 3.00    330
# 3.33    315
# 3.67    337
# 4.00    442
# Name: RFM_Score, dtype: int64

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %%
seg_map = {
    r'1[1-4]': 'Almost Lost',
    r'2[1-2]': 'Almost Lost',
    r'[3-4][1-2]': 'New Customer',
    r'[2-3][3-4]': 'Loyal',
    r'4[3-4]': 'Best',   
}

# %%
df_rfm['RFM_Level'] = df_rfm['re_score'].astype(str) + df_rfm['fre_score'].astype(str)
df_rfm['RFM_Level'] = df_rfm['RFM_Level'].replace(seg_map, regex=True)
df_rfm.head()
# Out:
#    CustomerID  recency  frequency  monetary  re_score  fre_score  mon_score  \
# 0    12346.00      326          2      0.00         1          1          1
# 1    12747.00        3         11   4196.01         4          4          4
# 2    12748.00        1        224  28405.56         4          4          4
# 3    12749.00        4          8   3868.20         4          4          4
# 4    12820.00        4          4    942.34         4          3          3
#
#    RFM_Score    RFM_Level
# 0       1.00  Almost Lost
# 1       4.00         Best
# 2       4.00         Best
# 3       4.00         Best
# 4       3.33         Best

# %%
df_rfm.RFM_Level.value_counts()
# Out:
# Almost Lost     1641
# New Customer     823
# Loyal            775
# Best             711
# Name: RFM_Level, dtype: int64

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %%
sns.countplot(x=df_rfm.RFM_Level);

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales). We can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %%
df_rfm.RFM_Level.value_counts()
# Out:
# Almost Lost     1641
# New Customer     823
# Loyal            775
# Best             711
# Name: RFM_Level, dtype: int64

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
scaler = StandardScaler()

# %%
df_uk.head(3)
# Out:
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55    17850.00
# 1    536365     71053         6 2010-12-01 08:26:00       3.39    17850.00
# 2    536365    84406B         8 2010-12-01 08:26:00       2.75    17850.00
#
#           Country  Revenue        date
# 0  United Kingdom    15.30  2010-12-01
# 1  United Kingdom    20.34  2010-12-01
# 2  United Kingdom    22.00  2010-12-01

# %%
df_rfm.head(3)
# Out:
#    CustomerID  recency  frequency  monetary  re_score  fre_score  mon_score  \
# 0    12346.00      326          2      0.00         1          1          1
# 1    12747.00        3         11   4196.01         4          4          4
# 2    12748.00        1        224  28405.56         4          4          4
#
#    RFM_Score    RFM_Level
# 0       1.00  Almost Lost
# 1       4.00         Best
# 2       4.00         Best

# %%
df_rfm_model = df_rfm[["CustomerID", "recency", "frequency", "monetary"]]

# %%
df_rfm_model
# Out:
#       CustomerID  recency  frequency  monetary
# 1       12747.00        3         11   4196.01
# 2       12748.00        1        224  28405.56
# 3       12749.00        4          8   3868.20
# 4       12820.00        4          4    942.34
# 5       12821.00      215          1     92.72
# ...          ...      ...        ...       ...
# 3945    18280.00      278          1    180.60
# 3946    18281.00      181          1     80.82
# 3947    18282.00        8          3    176.60
# 3948    18283.00        4         16   2045.53
# 3949    18287.00       43          3   1837.28
#
# [3902 rows x 4 columns]

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
df_rfm_model.corr()
# Out:
#             CustomerID  recency  frequency  monetary
# CustomerID        1.00     0.02      -0.03      0.01
# recency           0.02     1.00      -0.27     -0.15
# frequency        -0.03    -0.27       1.00      0.55
# monetary          0.01    -0.15       0.55      1.00

# %%
sns.heatmap(df_rfm_model.corr(), cmap="Reds")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %%
sns.pairplot(df_rfm_model)

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. Logarithmic Tranformation can be used to normalize the values in a column.
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %%
print("                ----------------- Distribution Plots for R,F,M -------------------------------")

# Checking the distribution of Recency, Frequency and MonetaryValue variables.
plt.figure(figsize=(12,10))
# Plot distribution of var1
plt.subplot(3, 1, 1); sns.distplot(df_rfm_model['recency'])
# Plot distribution of var2
plt.subplot(3, 1, 2); sns.distplot(df_rfm_model['frequency'])
# Plot distribution of var3
plt.subplot(3, 1, 3); sns.distplot(df_rfm_model['monetary'])
# Out:
#                 ----------------- Distribution Plots for R,F,M -------------------------------
# <AxesSubplot:xlabel='monetary', ylabel='Density'>

# %%
# df_rfm_model = df_rfm_model[df_rfm_model.monetary > 1]
# df_rfm_model
# Out:
#       recency  frequency  monetary
# 1           3         11   4196.01
# 2           1        224  28405.56
# 3           4          8   3868.20
# 4           4          4    942.34
# 5         215          1     92.72
# ...       ...        ...       ...
# 3945      278          1    180.60
# 3946      181          1     80.82
# 3947        8          3    176.60
# 3948        4         16   2045.53
# 3949       43          3   1837.28
#
# [3902 rows x 3 columns]

# %% [markdown]
# From the above figure, all the variables do not have a symmetrical distribution. All of them are skewed to the right. Since clustering algorithms require a normal distribution, normalization of the data is required.I am using Log transformation to deal with the skewness of data

# %%
# Taking Log of columns
df_rfm_model["log_R"] = np.log(df_rfm_model.recency)
df_rfm_model["log_F"] = np.log(df_rfm_model.frequency)
df_rfm_model["log_M"] = np.log(df_rfm_model.monetary)

# Checking the distribution of Recency, Frequency and Monetary variables after log transformation
print("                ----------------- Log Transformation Plots for R,F,M -------------------------------")
plt.figure(figsize=(12,10))
plt.subplot(3, 1, 1)
sns.distplot(df_rfm_model['log_R'])
plt.subplot(3, 1, 2)
sns.distplot(df_rfm_model['log_F'])
plt.subplot(3, 1, 3)
sns.distplot(df_rfm_model['log_M']);
# Out:
#                 ----------------- Log Transformation Plots for R,F,M -------------------------------

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %%
X1 = df_rfm_model[["CustomerID", "log_R","log_F","log_M"]]

# %%
df_rfm_model
# Out:
#       recency  frequency  monetary  log_R  log_F  log_M
# 1           3         11   4196.01   1.10   2.40   8.34
# 2           1        224  28405.56   0.00   5.41  10.25
# 3           4          8   3868.20   1.39   2.08   8.26
# 4           4          4    942.34   1.39   1.39   6.85
# 5         215          1     92.72   5.37   0.00   4.53
# ...       ...        ...       ...    ...    ...    ...
# 3945      278          1    180.60   5.63   0.00   5.20
# 3946      181          1     80.82   5.20   0.00   4.39
# 3947        8          3    176.60   2.08   1.10   5.17
# 3948        4         16   2045.53   1.39   2.77   7.62
# 3949       43          3   1837.28   3.76   1.10   7.52
#
# [3902 rows x 6 columns]

# %%
X = df_rfm_model[["log_R","log_F","log_M"]]

# %%
K_means_model = KMeans(n_clusters=5, random_state=42)

# %%
K_means_model.fit_predict(X)
# Out:
# array([0, 0, 0, ..., 4, 0, 1])

# %%
# Hopkins test

# %%
from pyclustertend import hopkins

# %%
hopkins(X, X.shape[0])
# Out:
# 0.06906146746457063

# %%
ssd = [] #sum squared distance

K = range(1,10)

for k in K:
    model = KMeans(n_clusters =k, random_state=42)
    model.fit(X)
    ssd.append(model.inertia_) # intertia: Distance from each sample to centroid of its cluster

# %%
plt.plot(K, ssd, "bo-")
plt.xlabel("Different k values")
plt.ylabel("inertia-error (ssd)") 
plt.title("elbow method")
# Out:
# Text(0.5, 1.0, 'elbow method')

# %%
from yellowbrick.cluster import KElbowVisualizer

model_ = KMeans(random_state=42)
visualizer = KElbowVisualizer(model_, k=(1,9))

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show();
# score: (default- distortion )(mean of sum squared distances to centers.)

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(X, K_means_model.labels_)
# Out:
# 0.3238189236767687

# %%
range_n_clusters = range(2,9)
for num_clusters in range_n_clusters:
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(X)
    cluster_labels = kmeans.labels_
    # silhouette score
    silhouette_avg = silhouette_score(X, cluster_labels)
    print(f"For n_clusters={num_clusters}, the silhouette score is {silhouette_avg}")
# Out:
# For n_clusters=2, the silhouette score is 0.4203424032060577
# For n_clusters=3, the silhouette score is 0.32872871963612077
# For n_clusters=4, the silhouette score is 0.3461052164963305
# For n_clusters=5, the silhouette score is 0.3238189236767687
# For n_clusters=6, the silhouette score is 0.3115170917610436
# For n_clusters=7, the silhouette score is 0.3043271866030196
# For n_clusters=8, the silhouette score is 0.30738578503745373

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer

model3 = KMeans(n_clusters=4, random_state=42)
visualizer = SilhouetteVisualizer(model3)

visualizer.fit(X)    # Fit the data to the visualizer
visualizer.poof();

# %%
# we decided that data has 4 clusters

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %%
X
# Out:
#       log_R  log_F  log_M
# 1      1.10   2.40   8.34
# 2      0.00   5.41  10.25
# 3      1.39   2.08   8.26
# 4      1.39   1.39   6.85
# 5      5.37   0.00   4.53
# ...     ...    ...    ...
# 3945   5.63   0.00   5.20
# 3946   5.20   0.00   4.39
# 3947   2.08   1.10   5.17
# 3948   1.39   2.77   7.62
# 3949   3.76   1.10   7.52
#
# [3902 rows x 3 columns]

# %%
n_clusters=4
model = KMeans(n_clusters =n_clusters, random_state=42)
model.fit_predict(X)
# Out:
# array([3, 3, 3, ..., 0, 3, 1])

# %%
model.labels_
# Out:
# array([3, 3, 3, ..., 0, 3, 1])

# %%
clusters = model.labels_

# %%
X["predicted_clusters"] = clusters

# %%
X
# Out:
#       log_R  log_F  log_M  predicted_clusters
# 1      1.10   2.40   8.34                   3
# 2      0.00   5.41  10.25                   3
# 3      1.39   2.08   8.26                   3
# 4      1.39   1.39   6.85                   3
# 5      5.37   0.00   4.53                   2
# ...     ...    ...    ...                 ...
# 3945   5.63   0.00   5.20                   2
# 3946   5.20   0.00   4.39                   2
# 3947   2.08   1.10   5.17                   0
# 3948   1.39   2.77   7.62                   3
# 3949   3.76   1.10   7.52                   1
#
# [3902 rows x 4 columns]

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %%
df_rfm = df_rfm[df_rfm.monetary > 1]

# %%
df_rfm
# Out:
#       CustomerID  recency  frequency  monetary  re_score  fre_score  \
# 1       12747.00        3         11   4196.01         4          4
# 2       12748.00        1        224  28405.56         4          4
# 3       12749.00        4          8   3868.20         4          4
# 4       12820.00        4          4    942.34         4          3
# 5       12821.00      215          1     92.72         1          1
# ...          ...      ...        ...       ...       ...        ...
# 3945    18280.00      278          1    180.60         1          1
# 3946    18281.00      181          1     80.82         1          1
# 3947    18282.00        8          3    176.60         4          2
# 3948    18283.00        4         16   2045.53         4          4
# 3949    18287.00       43          3   1837.28         3          2
#
#       mon_score  RFM_Score     RFM_Level
# 1             4       4.00          Best
# 2             4       4.00          Best
# ...

# %%
# we dropped observations which monetary less equal than 1 (in df_rfm_model = X)
# so we need to labels which monetary less equal than 1 (in below)

X["labels"] = df_rfm["RFM_Level"]

# %%
X
# Out:
#       log_R  log_F  log_M  predicted_clusters        labels
# 1      1.10   2.40   8.34                   3          Best
# 2      0.00   5.41  10.25                   3          Best
# 3      1.39   2.08   8.26                   3          Best
# 4      1.39   1.39   6.85                   3          Best
# 5      5.37   0.00   4.53                   2   Almost Lost
# ...     ...    ...    ...                 ...           ...
# 3945   5.63   0.00   5.20                   2   Almost Lost
# 3946   5.20   0.00   4.39                   2   Almost Lost
# 3947   2.08   1.10   5.17                   0  New Customer
# 3948   1.39   2.77   7.62                   3          Best
# 3949   3.76   1.10   7.52                   1  New Customer
#
# [3902 rows x 5 columns]

# %%
X.reset_index(inplace=True, drop=True)

# %%
X.labels.value_counts(dropna=False)
# Out:
# Almost Lost     1601
# New Customer     816
# Loyal            774
# Best             711
# Name: labels, dtype: int64

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %%
ct = pd.crosstab(X.predicted_clusters, X.labels)
ct
# Out:
# labels              Almost Lost  Best  Loyal  New Customer
# predicted_clusters
# 0                             7    83     27           663
# 1                           274    32    655           113
# 2                          1320     0     11            22
# 3                             0   596     81            18

# %%
df_rfm.head()
# Out:
#    CustomerID  recency  frequency  monetary  re_score  fre_score  mon_score  \
# 1    12747.00        3         11   4196.01         4          4          4
# 2    12748.00        1        224  28405.56         4          4          4
# 3    12749.00        4          8   3868.20         4          4          4
# 4    12820.00        4          4    942.34         4          3          3
# 5    12821.00      215          1     92.72         1          1          1
#
#    RFM_Score    RFM_Level
# 1       4.00         Best
# 2       4.00         Best
# 3       4.00         Best
# 4       3.33         Best
# 5       1.00  Almost Lost

# %%
import plotly.express as px
fig = px.scatter_3d(df_rfm, x='recency', y='frequency', z='monetary', color="RFM_Level")
fig.show()
# Out:
# <div>                            <div id="1765ccc5-1ef7-402d-aa76-92147bdbc0ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1765ccc5-1ef7-402d-aa76-92147bdbc0ea")) {                    Plotly.newPlot(                        "1765ccc5-1ef7-402d-aa76-92147bdbc0ea",                        [{"hovertemplate":"RFM_Level=Best<br>recency=%{x}<br>frequency=%{y}<br>monetary=%{z}<extra></extra>","legendgroup":"Best","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Best","scene":"scene","showlegend":true,"x":[3,1,4,4,3,3,3,5,8,4,9,12,3,5,9,4,3,16,17,9,6,2,5,9,4,8,4,4,5,5,12,10,2,3,17,5,2,15,10,13,1,2,2,5,2,3,9,2,2,4,3,1,9,5,11,17,11,15,9,9,8,15,12,11,4,10,10,4,5,13,12,2,12,3,2,16,8,5,8,9,2,6,4,4,2,2,9,12,1,11,6,15,17,8,2,2,8,4,9,2,3,2
# ...

# %%
from sklearn.metrics import adjusted_rand_score

# %%
adjusted_rand_score(X.labels, X.predicted_clusters)
# Out:
# 0.627169839530022

# %%
# feature selection

# %%
X2 = df_rfm_model[["log_R","log_F"]]

# %%
# Hopkins test

# %%
hopkins(X2, X2.shape[0])
# Out:
# 0.02856983041818978

# %%
ssd = [] #sum squared distance

K = range(1,10)

for k in K:
    model2 = KMeans(n_clusters =k, random_state=42)
    model2.fit(X2)
    ssd.append(model2.inertia_) # intertia: Distance from each sample to centroid of its cluster

# %%
plt.plot(K, ssd, "bo-")
plt.xlabel("Different k values")
plt.ylabel("inertia-error (ssd)") 
plt.title("elbow method")
# Out:
# Text(0.5, 1.0, 'elbow method')

# %%
from yellowbrick.cluster import KElbowVisualizer

model_ = KMeans(random_state=42)
visualizer = KElbowVisualizer(model_, k=(1,9))

visualizer.fit(X2)        # Fit the data to the visualizer
visualizer.show();
# score: (default- distortion )(mean of sum squared distances to centers.)

# %%
K_means_model2 = KMeans(n_clusters=4, random_state=42)

# %%
K_means_model2.fit_predict(X2)
# Out:
# array([1, 1, 1, ..., 1, 1, 2])

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
silhouette_score(X2, K_means_model2.labels_)
# Out:
# 0.4040763134654724

# %%
range_n_clusters = range(2,9)
for num_clusters in range_n_clusters:
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(X2)
    cluster_labels = kmeans.labels_
    # silhouette score
    silhouette_avg = silhouette_score(X2, cluster_labels)
    print(f"For n_clusters={num_clusters}, the silhouette score is {silhouette_avg}")
# Out:
# For n_clusters=2, the silhouette score is 0.4679356536034245
# For n_clusters=3, the silhouette score is 0.38990855391853335
# For n_clusters=4, the silhouette score is 0.4040763134654724
# For n_clusters=5, the silhouette score is 0.39195198314102014
# For n_clusters=6, the silhouette score is 0.39582045014430817
# For n_clusters=7, the silhouette score is 0.38665977967209014
# For n_clusters=8, the silhouette score is 0.3904957971191833

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer

model4 = KMeans(n_clusters=4, random_state=42)
visualizer = SilhouetteVisualizer(model4)

visualizer.fit(X2)    # Fit the data to the visualizer
visualizer.poof();

# %%
n_clusters=4
model2 = KMeans(n_clusters =n_clusters, random_state=42)
model2.fit_predict(X2)
# Out:
# array([1, 1, 1, ..., 1, 1, 2])

# %%
model2.labels_
# Out:
# array([1, 1, 1, ..., 1, 1, 2])

# %%
clusters = model2.labels_

# %%
X2["predicted_clusters"] = clusters

# %%
X2
# Out:
#       log_R  log_F  predicted_clusters
# 1      1.10   2.40                   1
# 2      0.00   5.41                   1
# 3      1.39   2.08                   1
# 4      1.39   1.39                   1
# 5      5.37   0.00                   0
# ...     ...    ...                 ...
# 3945   5.63   0.00                   0
# 3946   5.20   0.00                   0
# 3947   2.08   1.10                   1
# 3948   1.39   2.77                   1
# 3949   3.76   1.10                   2
#
# [3902 rows x 3 columns]

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %%
df_rfm
# Out:
#       CustomerID  recency  frequency  monetary  re_score  fre_score  \
# 1       12747.00        3         11   4196.01         4          4
# 2       12748.00        1        224  28405.56         4          4
# 3       12749.00        4          8   3868.20         4          4
# 4       12820.00        4          4    942.34         4          3
# 5       12821.00      215          1     92.72         1          1
# ...          ...      ...        ...       ...       ...        ...
# 3945    18280.00      278          1    180.60         1          1
# 3946    18281.00      181          1     80.82         1          1
# 3947    18282.00        8          3    176.60         4          2
# 3948    18283.00        4         16   2045.53         4          4
# 3949    18287.00       43          3   1837.28         3          2
#
#       mon_score  RFM_Score     RFM_Level
# 1             4       4.00          Best
# 2             4       4.00          Best
# ...

# %%
# we dropped observations which monetary less equal than 1 (in df_rfm_model = X)
# so we need to labels which monetary less equal than 1 (in below)

X2["labels"] = df_rfm["RFM_Level"]

# %%
X2
# Out:
#       log_R  log_F  predicted_clusters        labels
# 1      1.10   2.40                   1          Best
# 2      0.00   5.41                   1          Best
# 3      1.39   2.08                   1          Best
# 4      1.39   1.39                   1          Best
# 5      5.37   0.00                   0   Almost Lost
# ...     ...    ...                 ...           ...
# 3945   5.63   0.00                   0   Almost Lost
# 3946   5.20   0.00                   0   Almost Lost
# 3947   2.08   1.10                   1  New Customer
# 3948   1.39   2.77                   1          Best
# 3949   3.76   1.10                   2  New Customer
#
# [3902 rows x 4 columns]

# %%
X2.reset_index(inplace=True, drop=True)

# %%
X2.labels.value_counts(dropna=False)
# Out:
# Almost Lost     1601
# New Customer     816
# Loyal            774
# Best             711
# Name: labels, dtype: int64

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %%
ct = pd.crosstab(X2.predicted_clusters, X2.labels)
ct
# Out:
# labels              Almost Lost  Best  Loyal  New Customer
# predicted_clusters
# 0                          1242     0     11             0
# 1                             0   648      1           105
# 2                           106    63    762            58
# 3                           253     0      0           653

# %%
df_rfm.head()
# Out:
#    CustomerID  recency  frequency  monetary  re_score  fre_score  mon_score  \
# 1    12747.00        3         11   4196.01         4          4          4
# 2    12748.00        1        224  28405.56         4          4          4
# 3    12749.00        4          8   3868.20         4          4          4
# 4    12820.00        4          4    942.34         4          3          3
# 5    12821.00      215          1     92.72         1          1          1
#
#    RFM_Score    RFM_Level
# 1       4.00         Best
# 2       4.00         Best
# 3       4.00         Best
# 4       3.33         Best
# 5       1.00  Almost Lost

# %%
from sklearn.metrics import adjusted_rand_score

# %%
adjusted_rand_score(X2.labels, X2.predicted_clusters)
# Out:
# 0.6440749768290569

# %% [markdown]
# ### iv. Assign the Label

# %%
X["predicted_clusters"] = X["predicted_clusters"].map({0:"New Customer", 1:"Loyal", 2:"Almost Lost", 3:"Best"})

# %%
X.predicted_clusters.value_counts(dropna=False)
# Out:
# Almost Lost     1353
# Loyal           1074
# New Customer     780
# Best             695
# Name: predicted_clusters, dtype: int64

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the RFM Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# **Conclusion**
#
# * Write down your conclusions about clustering

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %% [markdown]
# Create Heatmap and evaluate the results

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
X1 = pd.merge(X, X1, on=["log_R","log_F","log_M"])
X1 = X1[["CustomerID", "predicted_clusters"]]

# %%
df_uk_merged = pd.merge(df_uk, X1, on="CustomerID" )
df_uk_merged.head()
# Out:
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55    17850.00
# 1    536365     71053         6 2010-12-01 08:26:00       3.39    17850.00
# 2    536365    84406B         8 2010-12-01 08:26:00       2.75    17850.00
# 3    536365    84029G         6 2010-12-01 08:26:00       3.39    17850.00
# 4    536365    84029E         6 2010-12-01 08:26:00       3.39    17850.00
#
#           Country  Revenue        date predicted_clusters
# 0  United Kingdom    15.30  2010-12-01              Loyal
# 1  United Kingdom    20.34  2010-12-01              Loyal
# 2  United Kingdom    22.00  2010-12-01              Loyal
# 3  United Kingdom    20.34  2010-12-01              Loyal
# 4  United Kingdom    20.34  2010-12-01              Loyal

# %%
from datetime import datetime

# %%
def extract_date(date):
    return date.replace(day=1)
# Out:
# datetime.datetime(2022, 10, 1, 11, 14, 24, 396406)

# %%
extract_date(datetime.now())
# Out:
# datetime.datetime(2022, 10, 1, 11, 16, 38, 707508)

# %%
df_uk_merged["first_day"] = df_uk_merged.InvoiceDate.apply(extract_date)
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 356389   2011-12-01 14:58:00
# 356390   2011-12-01 14:58:00
# 356391   2011-12-01 14:58:00
# 356392   2011-12-01 14:58:00
# 356393   2011-12-01 14:58:00
# Name: InvoiceDate, Length: 356394, dtype: datetime64[ns]

# %% [markdown]
# Now we will use the function created above to convert all the invoice dates into respective month date format.

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 separate series for each of the two columns

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
