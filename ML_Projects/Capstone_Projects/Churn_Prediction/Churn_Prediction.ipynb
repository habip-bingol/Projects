# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "***Employee Churn Analysis Project***". This is the second project of Capstone Project Series, which you will be able to build your own classification models for a variety of business settings.
#
# Also you will research what is Employee Churn?, How it is different from customer churn, Exploratory data analysis and visualization of employee churn dataset using ***matplotlib*** and ***seaborn***, model building and evaluation using python ***scikit-learn*** and ***Tensorflow-Keras*** packages.
#
# You will be able to implement classification techniques in Python. Using Scikit-Learn allowing you to successfully make predictions with Distance Based, Bagging, Boosting algorithms for this project. On the other hand, for Deep Learning you will use Tensorflow-Keras.
#
# At the end of the project, you will have the opportunity to deploy your model using *Streamlit*.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - NOTE: This project assumes that you already know the basics of coding in Python and are familiar with model deployement as well as the theory behind Distance Based, Bagging, Boosting algorithms, and Confusion Matrices. You can try more models and methods beside these to improve your model metrics.

# %% [markdown]
# # #Determines
# In this project you have HR data of a company. A study is requested from you to predict which employee will churn by using this data.
#
# The HR dataset has 14,999 samples. In the given dataset, you have two types of employee one who stayed and another who left the company.
#
# You can describe 10 attributes in detail as:
# - ***satisfaction_level:*** It is employee satisfaction point, which ranges from 0-1.
# - ***last_evaluation:*** It is evaluated performance by the employer, which also ranges from 0-1.
# - ***number_projects:*** How many of projects assigned to an employee?
# - ***average_monthly_hours:*** How many hours in averega an employee worked in a month?
# - **time_spent_company:** time_spent_company means employee experience. The number of years spent by an employee in the company.
# - ***work_accident:*** Whether an employee has had a work accident or not.
# - ***promotion_last_5years:*** Whether an employee has had a promotion in the last 5 years or not.
# - ***Departments:*** Employee's working department/division.
# - ***Salary:*** Salary level of the employee such as low, medium and high.
# - ***left:*** Whether the employee has left the company or not.
#
# First of all, to observe the structure of the data, outliers, missing values and features that affect the target variable, you must use exploratory data analysis and data visualization techniques.
#
# Then, you must perform data pre-processing operations such as ***Scaling*** and ***Encoding*** to increase the accuracy score of Gradient Descent Based or Distance-Based algorithms. you are asked to perform ***Cluster Analysis*** based on the information you obtain during exploratory data analysis and data visualization processes.
#
# The purpose of clustering analysis is to cluster data with similar characteristics. You are asked to use the ***K-means*** algorithm to make cluster analysis. However, you must provide the K-means algorithm with information about the number of clusters it will make predictions. Also, the data you apply to the K-means algorithm must be scaled. In order to find the optimal number of clusters, you are asked to use the ***Elbow method***. Briefly, try to predict the set to which individuals are related by using K-means and evaluate the estimation results.
#
# Once the data is ready to be applied to the model, you must ***split the data into train and test***. Then build a model to predict whether employees will churn or not. Train your models with your train set, test the success of your model with your test set.
#
# Try to make your predictions by using the algorithms ***Logistic Regression***, ***Random Forest Classifier***, ***XGBoost Classifier***, ***ANN***. You can use the related modules of the ***scikit-learn*** and ***Tensorflow-Keras*** library. You can use scikit-learn ***Classification Metrics*** module for accuracy calculation. You can use the ***Yellowbrick*** module for model selection and visualization.
#
# In the final step, you will deploy your model using Streamlit tool.

# %% [markdown]
# # #Tasks
#
# #### 1. Exploratory Data Analysis
# - Importing Modules
# - Loading Dataset
# - Data Insigts
#
# #### 2. Data Visualization
# - Employees Left
# - Determine Number of Projects
# - Determine Time Spent in Company
# - Subplots of Features
#
# #### 3. Data Pre-Processing
# - Scaling
# - Label Encoding
#
# #### 4. Cluster Analysis
# - Find the optimal number of clusters (k) using the elbow method for for K-means.
# - Determine the clusters by using K-Means then Evaluate predicted results.
#
# #### 5. Model Building
# - Split Data as Train and Test set
# - Built Distance Based and Evaluate Model Performance and Predict Test Data
# - Built Random Forest Classifier and Evaluate Model Performance and Predict Test Data
# - Built XGBoost Classifier, Evaluate Model Performance and Predict Test Data
# - Built ANN Classifier, Evaluate Model Performance and Predict Test Data
#
# #### 6. Model Deployement
#
# - Save and Export the Best Model
# - Save and Export Variables
# - Deploy best model via Streamlit

# %% [markdown]
# ## 1. Exploratory Data Analysis
#
# Exploratory Data Analysis is an initial process of analysis, in which you can summarize characteristics of data such as pattern, trends, outliers, and hypothesis testing using descriptive statistics and visualization.

# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff


import scipy.stats as stats
from scipy.cluster.hierarchy import linkage, dendrogram
import statsmodels.api as sm
import statsmodels.formula.api as smf
# import missingno as msno
import datetime as dt
from datetime import datetime
from pyclustertend import hopkins
# import optuna
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_classif, f_regression, mutual_info_regression
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, LogisticRegression
from sklearn.metrics import plot_confusion_matrix, r2_score, mean_absolute_error, mean_squared_error
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import make_scorer, precision_score, precision_recall_curve, plot_precision_recall_curve
from sklearn.metrics import plot_roc_curve, roc_auc_score, roc_curve, f1_score, accuracy_score, recall_score
from sklearn.metrics import silhouette_samples,silhouette_score
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold, KFold, cross_val_predict, train_test_split
from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_val_score, cross_validate
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import MinMaxScaler, scale, StandardScaler, RobustScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, PolynomialFeatures, PowerTransformer
from sklearn.svm import SVR, SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree
# from catboost import CatBoostClassifier
# from lightgbm import LGBMClassifier
from xgboost import XGBRegressor, XGBClassifier, plot_importance
# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
# Figure&Display options
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('max_colwidth',200)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Loading Dataset
#
# Let's first load the required HR dataset using pandas's "read_csv" function.

# %%
df = pd.read_csv("HR_Dataset.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.380            0.530               2                   157
# 1               0.800            0.860               5                   262
# 2               0.110            0.880               7                   272
# 3               0.720            0.870               5                   223
# 4               0.370            0.520               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0
#
#   Departments   salary
# 0        sales     low
# 1        sales  medium
# 2        sales  medium
# ...

# %%
df_copy = df

# %% [markdown]
# ### Data Insights
#
# In the given dataset, you have two types of employee one who stayed and another who left the company. So, you can divide data into two groups and compare their characteristics. Moreover, you can find the average of both the groups using groupby() and mean() function.

# %%
df.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994               0.400            0.570               2
# 14995               0.370            0.480               2
# 14996               0.370            0.530               2
# 14997               0.110            0.960               6
# 14998               0.370            0.520               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Departments  salary
# 14994                      0      support    low
# 14995                      0      support    low
# ...

# %%
df.sample(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 1207                0.810            0.980               5
# 10115               0.600            0.660               5
# 2472                0.970            0.630               3
# 7806                0.120            0.820               5
# 14413               0.760            1.000               5
# 14617               0.730            0.990               5
# 808                 0.710            1.000               4
# 5608                0.420            0.400               3
# 6910                0.880            1.000               3
# 5379                0.500            0.700               5
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 1207                    237                   5              0     1
# 10115                   143                   2              0     0
# 2472                    133                   3              0     0
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Departments            14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isna().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Departments              0
# salary                   0
# dtype: int64

# %%
df.isna().sum()/len(df)*100
# Out:
# satisfaction_level      0.000
# last_evaluation         0.000
# number_project          0.000
# average_montly_hours    0.000
# time_spend_company      0.000
# Work_accident           0.000
# left                    0.000
# promotion_last_5years   0.000
# Departments             0.000
# salary                  0.000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
# print("Shape before dropping duplicates", df.shape)
# df = df.drop_duplicates(ignore_index=True)
# print("Shape after dropping duplicates", df.shape)

# %%
df.describe().T
# Out:
#                           count    mean    std    min     25%     50%     75%  \
# satisfaction_level    14999.000   0.613  0.249  0.090   0.440   0.640   0.820
# last_evaluation       14999.000   0.716  0.171  0.360   0.560   0.720   0.870
# number_project        14999.000   3.803  1.233  2.000   3.000   4.000   5.000
# average_montly_hours  14999.000 201.050 49.943 96.000 156.000 200.000 245.000
# time_spend_company    14999.000   3.498  1.460  2.000   3.000   3.000   4.000
# Work_accident         14999.000   0.145  0.352  0.000   0.000   0.000   0.000
# left                  14999.000   0.238  0.426  0.000   0.000   0.000   0.000
# promotion_last_5years 14999.000   0.021  0.144  0.000   0.000   0.000   0.000
#
#                           max
# satisfaction_level      1.000
# last_evaluation         1.000
# number_project          7.000
# average_montly_hours  310.000
# time_spend_company     10.000
# Work_accident           1.000
# left                    1.000
# ...

# %%
df.describe(include="O")
# Out:
#        Departments  salary
# count         14999  14999
# unique           10      3
# top           sales    low
# freq           4140   7316

# %%
def check_df(col):
  print('column name : ', col)
  print('--------------------------------')
  print('Per_of_Nulls           : ', '%', round(df[col].isnull().sum()*100/len(df), 2))
  print('Num_of_Nulls           : ', df[col].isnull().sum())
  print('Num_of_Unique_Values   : ', df[col].nunique())
  print(df[col].value_counts(dropna = False))
  print("*"*30)
  print("\n\n")


for col in df.columns :
  check_df(col)
# Out:
# column name :  satisfaction_level
# --------------------------------
# Per_of_Nulls           :  % 0.0
# Num_of_Nulls           :  0
# Num_of_Unique_Values   :  92
# 0.100    358
# 0.110    335
# 0.740    257
# 0.770    252
# 0.840    247
# 0.730    246
# 0.780    241
# 0.370    241
# 0.820    241
# 0.890    237
# 0.830    234
# 0.760    234
# 0.720    230
# 0.500    229
# 0.660    228
# 0.750    226
# 0.870    225
# 0.910    224
# 0.430    224
# 0.800    222
# 0.810    220
# 0.900    220
# 0.590    219
# 0.790    217
# 0.440    211
# 0.570    210
# 0.400    209
# 0.630    209
# 0.490    209
# 0.690    209
# 0.610    208
# 0.850    207
# 0.700    205
# 0.450    203
# 0.960    203
# 0.860    200
# 0.650    199
# 0.920    198
# 0.520    196
# 0.090    195
# 0.600    193
# 0.380    189
# 0.620    188
# 0.510    187
# 0.880    187
# 0.640    187
# 0.560    187
# 0.540    185
# 0.980    183
# 0.580    182
# 0.950    181
# 0.550    179
# 0.530    179
# 0.670    177
# 0.970    176
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Departments ', 'salary'],
#       dtype='object')

# %%
import skimpy
from skimpy import clean_columns

df = clean_columns(df)
# Out:
# 2 column names have been cleaned

# %%
df.rename(columns={ "satisfaction_level":"satisfaction",
                    "time_spend_company":"experience",
                    "departments":"department"}, inplace=True)

# %%
df.columns
# Out:
# Index(['satisfaction', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'experience', 'work_accident', 'left',
#        'promotion_last_5years', 'department', 'salary'],
#       dtype='object')

# %%
# This data is collected from employees who works for this company 2 and more than 2 years
# There is a big difference between max and min values of avg_monthly_hours
# w/ %14,4 there is work accident
# 21 employee has been promoted for each 1000 employees.

# %%
index = df.columns.get_loc("left")
index
# Out:
# 6

# %%
df = df.iloc[:, [0, 1, 2, 3, 4, 5, 7, 8, 6,9]]
df.head()
# Out:
#    satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0         0.380            0.530               2                   157
# 1         0.800            0.860               5                   262
# 2         0.110            0.880               7                   272
# 3         0.720            0.870               5                   223
# 4         0.370            0.520               2                   159
#
#    experience  work_accident  promotion_last_5years department  left  salary
# 0           3              0                      0      sales     1     low
# 1           6              0                      0      sales     1  medium
# 2           4              0                      0      sales     1  medium
# 3           5              0                      0      sales     1     low
# 4           3              0                      0      sales     1     low

# %%
from skimpy import skim
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 14999  │ │ int32       │ 6     │                                                          │
# │ │ Number of columns │ 10     │ │ float64     │ 2     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 2     │                                                          │
# ...

# %% [markdown]
# - **Useful functions for Visualizations**

# %%
def categorical_column_investigaton(col_name):
    """First Plot: Pie chart for categorical column to see percentage of each value
       Secons Plot: Count plot for categorical column to see the number of count for each of the type
       Third Plot is Number of Count for separeted for Attribition"""

    f,ax = plt.subplots(1,3, figsize=(18,6))
    df[col_name].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True, cmap='Set3')
    df[col_name].value_counts().plot.bar(cmap='Set3',ax=ax[1])
    ax[1].set_title(f'Number of Employee by {col_name}')
    ax[1].set_ylabel('Count')
    ax[1].set_xlabel(f'{col_name}')
    sns.countplot(col_name, hue='left',data=df, ax=ax[2], palette='Set3')
    ax[2].set_title(f'Left by {col_name}')
    ax[2].set_xlabel(f'{col_name}')
    ax[2].set_ylabel('Count')
    plt.xticks(rotation=90)
    plt.tight_layout()

# %%
def cat_num_com(numerical_col, caterical_col1, caterical_col2):
    

    f,ax = plt.subplots(1,2, figsize=(18,6))
    
    g1= sns.swarmplot( caterical_col1, numerical_col,hue='left', data=df, dodge=True, ax=ax[0], palette='Set2')
    ax[0].set_title(f'{numerical_col} vs {caterical_col1} separated by left')
    g1.set_xticklabels(g1.get_xticklabels(), rotation=45) 

    
    g2 = sns.swarmplot( caterical_col2, numerical_col,hue='left', data=df, dodge=True, ax=ax[1], palette='Set2')
    ax[1].set_title(f'{numerical_col} vs {caterical_col1} separated by left')
    g2.set_xticklabels(g2.get_xticklabels(), rotation=45)

# %%
def num_col_investigaton(col_name):
    f,ax = plt.subplots(1,2, figsize=(18,6))
    sns.kdeplot(df[col_name], label='Employee who left',ax=ax[0], shade=True, color='palegreen')
    sns.kdeplot(df[col_name], label='Employee who stayed', ax=ax[0], shade=True, color='salmon')
    
    sns.boxplot(y=col_name, x='left',data=df, palette='Set2', ax=ax[1])

# %% [markdown]
# ## EDA & Data Visualization
#
# You can search for answers to the following questions using data visualization methods. Based on these responses, you can develop comments about the factors that cause churn.
# - How does the promotion status affect employee churn?
# - How does years of experience affect employee churn?
# - How does workload affect employee churn?
# - How does the salary level affect employee churn?
#
# *Feel free to add more visualization

# %%
correlations = df.corr()
fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(correlations, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.set()
# Let's see if we have any missing data, luckily we don't!
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='Blues');

# %% [markdown]
# ### Subplots of Features
#
# You can use the methods of the matplotlib.

# %%
# Visualization the distribution of the data for every feature
df.hist(bins=30, figsize=(20, 20), color="orange", alpha=0.6);

# %%
fig = plt.figure(figsize=(15,30))
for i, col in enumerate(df.iloc[:,:-3]):
        plt.subplot(10,2,i+1)
        sns.boxplot(x= "left", y=col, data=df)
plt.tight_layout();

# %% [markdown]
# #### satisfaction_level

# %%
df.satisfaction.describe()
# Out:
# count   14999.000
# mean        0.613
# std         0.249
# min         0.090
# 25%         0.440
# 50%         0.640
# 75%         0.820
# max         1.000
# Name: satisfaction, dtype: float64

# %%
sns.histplot(x=df.satisfaction, kde=True)
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='Count'>

# %%
num_col_investigaton("satisfaction")

# %%
df.corr()["left"][:-1].sort_values()
# Out:
# satisfaction            -0.388
# work_accident           -0.155
# promotion_last_5years   -0.062
# last_evaluation          0.007
# number_project           0.024
# average_montly_hours     0.071
# experience               0.145
# Name: left, dtype: float64

# %%
sns.scatterplot(x=df.satisfaction, y=df.last_evaluation, hue=df.left)
plt.legend(loc=(1,0.85),fontsize="x-large")

# %%
sns.scatterplot(x=df.satisfaction, y=df.average_montly_hours, hue=df.left)
plt.legend(loc=(1,0.85),fontsize="x-large")

# %%
df.groupby("promotion_last_5years")["satisfaction"].mean()
# Out:
# promotion_last_5years
# 0   0.612
# 1   0.656
# Name: satisfaction, dtype: float64

# %%
df.groupby("department")["satisfaction"].mean().sort_values()
# Out:
# department
# accounting    0.582
# hr            0.599
# technical     0.608
# sales         0.614
# IT            0.618
# support       0.618
# marketing     0.619
# product_mng   0.620
# RandD         0.620
# management    0.621
# Name: satisfaction, dtype: float64

# %% [markdown]
# #### last_evaluation

# %%
df.last_evaluation.describe()
# Out:
# count   14999.000
# mean        0.716
# std         0.171
# min         0.360
# 25%         0.560
# 50%         0.720
# 75%         0.870
# max         1.000
# Name: last_evaluation, dtype: float64

# %%
sns.histplot(df.last_evaluation, kde=True);

# %%
num_col_investigaton("last_evaluation")

# %%
sns.scatterplot(x=df.last_evaluation, y=df.average_montly_hours, hue=df.left)
plt.legend(loc=(1,0.85),fontsize="x-large")

# %%
df.groupby("number_project")["last_evaluation"].mean()
# Out:
# number_project
# 2   0.569
# 3   0.717
# 4   0.740
# 5   0.762
# 6   0.787
# 7   0.860
# Name: last_evaluation, dtype: float64

# %%
df.groupby(["number_project","salary"])["last_evaluation"].mean()
# Out:
# number_project  salary
# 2               high     0.617
#                 low      0.562
#                 medium   0.571
# 3               high     0.719
#                 low      0.717
#                 medium   0.716
# 4               high     0.705
#                 low      0.743
#                 medium   0.743
# 5               high     0.723
#                 low      0.778
#                 medium   0.752
# 6               high     0.719
#                 low      0.802
#                 medium   0.777
# 7               high     0.850
#                 low      0.861
#                 medium   0.858
# Name: last_evaluation, dtype: float64

# %%
df.groupby("department")["last_evaluation"].mean().sort_values()
# Out:
# department
# hr            0.709
# sales         0.710
# RandD         0.712
# product_mng   0.715
# marketing     0.716
# IT            0.717
# accounting    0.718
# technical     0.721
# support       0.723
# management    0.724
# Name: last_evaluation, dtype: float64

# %%
df.groupby(["department", "salary"])["last_evaluation"].mean().to_frame()
# Out:
#                     last_evaluation
# department  salary
# IT          high              0.717
#             low               0.716
#             medium            0.718
# RandD       high              0.701
#             low               0.714
#             medium            0.712
# accounting  high              0.725
#             low               0.714
#             medium            0.720
# hr          high              0.744
#             low               0.718
#             medium            0.696
# management  high              0.716
#             low               0.713
#             medium            0.741
# marketing   high              0.664
#             low               0.728
#             medium            0.714
# product_mng high              0.666
#             low               0.726
#             medium            0.710
# sales       high              0.700
#             low               0.709
#             medium            0.712
# ...

# %% [markdown]
# #### number_project

# %%
df.number_project.value_counts()
# Out:
# 4    4365
# 3    4055
# 5    2761
# 2    2388
# 6    1174
# 7     256
# Name: number_project, dtype: int64

# %%
df.number_project.value_counts(normalize=True)
# Out:
# 4   0.291
# 3   0.270
# 5   0.184
# 2   0.159
# 6   0.078
# 7   0.017
# Name: number_project, dtype: float64

# %%
categorical_column_investigaton("number_project")

# %%
ax = sns.countplot("number_project", data=df)
ax.bar_label(ax.containers[0]);

# %%
ax = sns.countplot(x="number_project", hue="left", palette="Set2", data=df);
for i in ax.containers:
    ax.bar_label(i);

# %%
df.groupby("number_project")["experience"].mean()
# Out:
# number_project
# 2   3.180
# 3   3.287
# 4   3.455
# 5   3.800
# 6   4.193
# 7   4.113
# Name: experience, dtype: float64

# %%
ax = sns.barplot(x="number_project", y="experience", data=df)
ax.bar_label(ax.containers[0]);

# %%
# we can conclude from this dataframe that after the 4 project employee's satisfaction level is decreasing
df1= df.groupby("number_project").agg({"left":["count", "sum"], "satisfaction":"mean"})
df1.rename(columns={"left":"Employees", "count":"total_employee", "sum":"left_employee", "mean":"average"}, inplace=True)
df1
# Out:
#                     Employees               satisfaction
#                total_employee left_employee      average
# number_project
# 2                        2388          1567        0.479
# 3                        4055            72        0.688
# 4                        4365           409        0.695
# 5                        2761           612        0.679
# 6                        1174           655        0.273
# 7                         256           256        0.119

# %%
ax = df1["Employees"].plot(kind="bar")
for i in ax.containers:
    ax.bar_label(i)
    
plt.legend(title="Count of Left Employee per Projects number", labels=["Total Emoloyee", "Left Employee"])   
plt.show()

# %%
df[df.number_project == 7]["left"].value_counts()
# Out:
# 1    256
# Name: left, dtype: int64

# %%
sns.scatterplot(x=df.last_evaluation, y=df.number_project, hue=df.left)
plt.legend(loc=(1,0.85),fontsize="x-large");

# %%
df.groupby("number_project")["average_montly_hours"].mean()
# Out:
# number_project
# 2   160.343
# 3   197.508
# 4   205.122
# 5   212.062
# 6   238.694
# 7   276.078
# Name: average_montly_hours, dtype: float64

# %%
df.groupby(["number_project", "promotion_last_5years"])["satisfaction"].mean()
# Out:
# number_project  promotion_last_5years
# 2               0                       0.478
#                 1                       0.533
# 3               0                       0.688
#                 1                       0.657
# 4               0                       0.695
#                 1                       0.714
# 5               0                       0.678
#                 1                       0.726
# 6               0                       0.272
#                 1                       0.367
# 7               0                       0.119
# Name: satisfaction, dtype: float64

# %% [markdown]
# #### average_montly_hours

# %%
df.average_montly_hours.describe()
# Out:
# count   14999.000
# mean      201.050
# std        49.943
# min        96.000
# 25%       156.000
# 50%       200.000
# 75%       245.000
# max       310.000
# Name: average_montly_hours, dtype: float64

# %%
sns.histplot(x=df.average_montly_hours, hue=df.left, kde=True)
# Out:
# <AxesSubplot:xlabel='average_montly_hours', ylabel='Count'>

# %%
sns.boxplot(y="average_montly_hours", x="left", data=df)
# Out:
# <AxesSubplot:xlabel='left', ylabel='average_montly_hours'>

# %%
num_col_investigaton("average_montly_hours")

# %%
# There is no insight from here
df.groupby("experience")["average_montly_hours"].mean()
# Out:
# experience
# 2    200.133
# 3    186.633
# 4    223.455
# 5    222.979
# 6    212.052
# 7    200.745
# 8    193.802
# 10   199.224
# Name: average_montly_hours, dtype: float64

# %%
# The average of each department's working hours are nearly same
df.groupby("department")["average_montly_hours"].mean().sort_values()
# Out:
# department
# hr            198.685
# marketing     199.386
# product_mng   199.966
# support       200.758
# RandD         200.801
# sales         200.911
# accounting    201.163
# management    201.249
# IT            202.216
# technical     202.497
# Name: average_montly_hours, dtype: float64

# %% [markdown]
# #### experience

# %%
df.experience.value_counts()
# Out:
# 3     6443
# 2     3244
# 4     2557
# 5     1473
# 6      718
# 10     214
# 7      188
# 8      162
# Name: experience, dtype: int64

# %%
categorical_column_investigaton("experience")

# %%
ax = sns.countplot("experience",data=df)
ax.bar_label(ax.containers[0]);

# %%
ax = sns.countplot(df.experience, hue="left", palette="Set2", data=df)
for i in ax.containers:
    ax.bar_label(i);

# %%
# sum of the people who has work accident per each working years
df.groupby("experience")["work_accident"].mean()
# Out:
# experience
# 2    0.172
# 3    0.139
# 4    0.124
# 5    0.116
# 6    0.149
# 7    0.138
# 8    0.272
# 10   0.234
# Name: work_accident, dtype: float64

# %% [markdown]
# #### work_accident

# %%
df.work_accident.value_counts()
# Out:
# 0    12830
# 1     2169
# Name: work_accident, dtype: int64

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(x=df.work_accident)
ax.bar_label(ax.containers[0]);

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(x=df.work_accident, hue="left", data=df)
for i in ax.containers:
    ax.bar_label(i)

# %%
df.groupby("work_accident").mean()
# Out:
#                satisfaction  last_evaluation  number_project  \
# work_accident
# 0                     0.607            0.717           3.805
# 1                     0.648            0.713           3.789
#
#                average_montly_hours  experience  promotion_last_5years  left
# work_accident
# 0                           201.259       3.497                  0.019 0.265
# 1                           199.818       3.506                  0.035 0.078

# %%
# Employees who has work accident per Department
df.groupby("work_accident")["department"].value_counts()[1,:]
# Out:
# department
# sales          587
# technical      381
# support        345
# IT             164
# marketing      138
# RandD          134
# product_mng    132
# management     103
# accounting      96
# hr              89
# Name: department, dtype: int64

# %% [markdown]
# #### promotion_last_5years

# %%
df.promotion_last_5years.value_counts()
# Out:
# 0    14680
# 1      319
# Name: promotion_last_5years, dtype: int64

# %%
df.groupby("promotion_last_5years").mean()
# Out:
#                        satisfaction  last_evaluation  number_project  \
# promotion_last_5years
# 0                             0.612            0.716           3.804
# 1                             0.656            0.706           3.752
#
#                        average_montly_hours  experience  work_accident  left
# promotion_last_5years
# 0                                   201.076       3.484          0.143 0.242
# 1                                   199.850       4.166          0.238 0.060

# %%
df.groupby("promotion_last_5years")["salary"].value_counts()
# Out:
# promotion_last_5years  salary
# 0                      low       7250
#                        medium    6265
#                        high      1165
# 1                      medium     181
#                        high        72
#                        low         66
# Name: salary, dtype: int64

# %%
df.groupby(["promotion_last_5years", "left"])["salary"].value_counts()
# Out:
# promotion_last_5years  left  salary
# 0                      0     low       5092
#                              medium    4953
#                              high      1083
#                        1     low       2158
#                              medium    1312
#                              high        82
# 1                      0     medium     176
#                              high        72
#                              low         52
#                        1     low         14
#                              medium       5
# Name: salary, dtype: int64

# %%
categorical_column_investigaton("promotion_last_5years")

# %%
ax = sns.countplot(x = "promotion_last_5years", hue="left", data=df)
for i in ax.containers:
    ax.bar_label(i);

# %% [markdown]
# #### departments

# %%
df["department"].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: Int64

# %%
ax = sns.countplot(x=df["department"], hue=df.left)
for i in ax.containers:
    ax.bar_label(i)

# %%
ax = sns.countplot(x=df["department"], hue=df.salary)
for i in ax.containers:
    ax.bar_label(i)

# %%
categorical_column_investigaton("department")

# %%
df.groupby("department").mean()
# Out:
#              satisfaction  last_evaluation  number_project  \
# department
# IT                  0.618            0.717           3.817
# RandD               0.620            0.712           3.854
# accounting          0.582            0.718           3.825
# hr                  0.599            0.709           3.655
# management          0.621            0.724           3.860
# marketing           0.619            0.716           3.688
# product_mng         0.620            0.715           3.807
# sales               0.614            0.710           3.776
# support             0.618            0.723           3.804
# technical           0.608            0.721           3.878
#
#              average_montly_hours  experience  work_accident  \
# department
# IT                        202.216       3.469          0.134
# RandD                     200.801       3.367          0.170
# accounting                201.163       3.523          0.125
# ...

# %% [markdown]
# #### salary

# %%
ax = sns.countplot(x = "salary", hue="left", data=df);
for i in ax.containers:
    ax.bar_label(i)

# %%
categorical_column_investigaton("salary")

# %%
df.groupby("salary").mean()
# Out:
#         satisfaction  last_evaluation  number_project  average_montly_hours  \
# salary
# high           0.637            0.704           3.767               199.867
# low            0.601            0.717           3.800               200.997
# medium         0.622            0.717           3.814               201.338
#
#         experience  work_accident  promotion_last_5years  left
# salary
# high         3.693          0.155                  0.058 0.066
# low          3.438          0.142                  0.009 0.297
# medium       3.529          0.145                  0.028 0.204

# %%
df1 = df.groupby("salary")["left"].value_counts().to_frame().rename(columns={"left":"count_of_employee"}).reset_index()
df1
# Out:
#    salary  left  count_of_employee
# 0    high     0               1155
# 1    high     1                 82
# 2     low     0               5144
# 3     low     1               2172
# 4  medium     0               5129
# 5  medium     1               1317

# %%
plt.figure(figsize=(8,4))
ax = sns.barplot(x="salary", y="count_of_employee", data=df1, hue="left");
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# ### Employees Left
#
# Let's check how many employees were left?
# Here, you can plot a bar graph using Matplotlib. The bar graph is suitable for showing discrete variable counts.

# %%
df.left.value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
df.left.value_counts(normalize=True)
# Out:
# 0   0.762
# 1   0.238
# Name: left, dtype: float64

# %%
plt.pie(df.left.value_counts(normalize=True),explode=(0,0.1), 
       labels=["Retention", "Left"], autopct="%.1f%%", shadow=True, startangle=90, colors=["#F08080", "#DAA520"]);

# %%
df.left.describe()
# Out:
# count   14999.000
# mean        0.238
# std         0.426
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max         1.000
# Name: left, dtype: float64

# %%
df.groupby("left").describe()
# Out:
#      satisfaction                                           last_evaluation  \
#             count  mean   std   min   25%   50%   75%   max           count
# left
# 0       11428.000 0.667 0.217 0.120 0.540 0.690 0.840 1.000       11428.000
# 1        3571.000 0.440 0.264 0.090 0.130 0.410 0.730 0.920        3571.000
#
#                                                number_project              \
#       mean   std   min   25%   50%   75%   max          count  mean   std
# left
# 0    0.715 0.162 0.360 0.580 0.710 0.850 1.000      11428.000 3.787 0.980
# 1    0.718 0.198 0.450 0.520 0.790 0.900 1.000       3571.000 3.856 1.818
#
#                                    average_montly_hours                 \
#        min   25%   50%   75%   max                count    mean    std
# left
# 0    2.000 3.000 4.000 4.000 6.000            11428.000 199.060 45.683
# 1    2.000 2.000 4.000 6.000 7.000             3571.000 207.419 61.203
#
# ...

# %%
ax = sns.countplot(df.left);
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '11428'), Text(0, 0, '3571')]

# %%
sns.barplot(data=df, x="department", y="left", palette="viridis");

# %% [markdown]
# ## 3. Data Pre-Processing

# %% [markdown]
# #### Scaling
#
# Some machine learning algorithms are sensitive to feature scaling while others are virtually invariant to it. Machine learning algorithms like linear regression, logistic regression, neural network, etc. that use gradient descent as an optimization technique require data to be scaled. Also distance algorithms like KNN, K-means, and SVM are most affected by the range of features. This is because behind the scenes they are using distances between data points to determine their similarity.
#
# Scaling Types:
# - Normalization: Normalization is a scaling technique in which values are shifted and rescaled so that they end up ranging between 0 and 1. It is also known as Min-Max scaling.
#
# - Standardization: Standardization is another scaling technique where the values are centered around the mean with a unit standard deviation. This means that the mean of the attribute becomes zero and the resultant distribution has a unit standard deviation.

# %% [markdown]
# #### Encoding
#
# Lots of machine learning algorithms require numerical input data, so you need to represent categorical columns in a numerical column. In order to encode this data, you could map each value to a number. e.g. Salary column's value can be represented as low:0, medium:1, and high:2. This process is known as label encoding, and sklearn conveniently will do this for you using LabelEncoder.

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, LabelEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
X = df.drop(columns="left") 
y = df["left"]

# %%
column_trans = make_column_transformer(
    (OneHotEncoder(handle_unknown="ignore", sparse=False), ["department"]),
    (OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ["salary"]), 
    remainder=MinMaxScaler()
)
X = pd.DataFrame(data=column_trans.fit_transform(X), columns=column_trans.get_feature_names_out())

# %%
X.head()
# Out:
#    onehotencoder__department_IT  onehotencoder__department_RandD  \
# 0                         0.000                            0.000
# 1                         0.000                            0.000
# 2                         0.000                            0.000
# 3                         0.000                            0.000
# 4                         0.000                            0.000
#
#    onehotencoder__department_accounting  onehotencoder__department_hr  \
# 0                                 0.000                         0.000
# 1                                 0.000                         0.000
# 2                                 0.000                         0.000
# 3                                 0.000                         0.000
# 4                                 0.000                         0.000
#
#    onehotencoder__department_management  onehotencoder__department_marketing  \
# ...

# %% [markdown]
# ## 4. Cluster Analysis
#
# - Cluster analysis or clustering is the task of grouping a set of objects in such a way that objects in the same group (called a cluster) are more similar (in some sense) to each other than to those in other groups (clusters). It is a main task of exploratory data mining, and a common technique for statistical data analysis, used in many fields, including pattern recognition, image analysis, information retrieval, bioinformatics, data compression, computer graphics and machine learning.
#
#     [Cluster Analysis](https://en.wikipedia.org/wiki/Cluster_analysis)
#
#     [Cluster Analysis2](https://realpython.com/k-means-clustering-python/)

# %%
from sklearn.cluster import KMeans

# %%
from pyclustertend import hopkins
hopkins(X, X.shape[0])
# Out:
# 0.05283205558256859

# %%
model = KMeans(n_clusters=2, random_state=42)
y_pred = model.fit_predict(X)
y_pred
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
X["cluster"] = model.labels_

# %%
# counter = 1
# scalers = [MinMaxScaler(),StandardScaler(), RobustScaler()]
# scal_str = ["MinMaxScaling","StandardScaling", "RobustScaling" ]
# for i in scalers:
#     X_scaled = i.fit_transform(X)
#     print(f"{scal_str[counter-1]}: {hopkins(X_scaled, X_scaled.shape[0])}")
#     counter += 1

# %% [markdown]
# #### The Elbow Method
#
# - "Elbow Method" can be used to find the optimum number of clusters in cluster analysis. The elbow method is used to determine the optimal number of clusters in k-means clustering. The elbow method plots the value of the cost function produced by different values of k. If k increases, average distortion will decrease, each cluster will have fewer constituent instances, and the instances will be closer to their respective centroids. However, the improvements in average distortion will decline as k increases. The value of k at which improvement in distortion declines the most is called the elbow, at which we should stop dividing the data into further clusters.
#
#     [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)
#
#     [The Elbow Method2](https://medium.com/@mudgalvivek2911/machine-learning-clustering-elbow-method-4e8c2b404a5d)
#
#     [KMeans](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1)
#
# Let's find out the groups of employees who left. You can observe that the most important factor for any employee to stay or leave is satisfaction and performance in the company. So let's bunch them in the group of people using cluster analysis.

# %%
ssd = []

K = range(2,10)

for k in K:
    model = KMeans(n_clusters=k, random_state=42)
    model.fit(X)
    ssd.append(model.inertia_)

# %%
plt.plot(K, ssd, "bo-")
plt.xlabel("Different k values")
plt.ylabel("inertia-error (ssd)") 
plt.title("elbow method")
# Out:
# Text(0.5, 1.0, 'elbow method')

# %%
from yellowbrick.cluster import KElbowVisualizer

model_ = KMeans(random_state=42)
visualizer = KElbowVisualizer(model_, k=(2,12))
visualizer.fit(X)
visualizer.show();

# %%
from sklearn.metrics import silhouette_score

# %%
range_n_clusters = range(2,9)
for num_clusters in range_n_clusters:
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(X)
    cluster_labels = kmeans.labels_
    # silhouette score
    silhouette_avg = silhouette_score(X, cluster_labels)
    print(f"For n_clusters={num_clusters}, the silhouette score is {silhouette_avg}")
# Out:
# For n_clusters=2, the silhouette score is 0.2750323121576187
# For n_clusters=3, the silhouette score is 0.20521251939709603
# For n_clusters=4, the silhouette score is 0.17591111071119964
# For n_clusters=5, the silhouette score is 0.21151540053734622
# For n_clusters=6, the silhouette score is 0.24801971258001604
# For n_clusters=7, the silhouette score is 0.27777000724314754
# For n_clusters=8, the silhouette score is 0.26916232214888786

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer

model = KMeans(n_clusters=7, random_state=42)
visualizer = SilhouetteVisualizer(model)

visualizer.fit(X)    # Fit the data to the visualizer
visualizer.poof();

# %%
model = KMeans(n_clusters = 7, random_state=42)
y_pred = model.fit_predict(X)
y_pred
# Out:
# array([0, 6, 6, ..., 5, 5, 5])

# %%
predicted_label=model.labels_
predicted_label
# Out:
# array([0, 6, 6, ..., 5, 5, 5])

# %%
X["pred_cluster"] = predicted_label
X.head()
# Out:
#    onehotencoder__department_IT  onehotencoder__department_RandD  \
# 0                         0.000                            0.000
# 1                         0.000                            0.000
# 2                         0.000                            0.000
# 3                         0.000                            0.000
# 4                         0.000                            0.000
#
#    onehotencoder__department_accounting  onehotencoder__department_hr  \
# 0                                 0.000                         0.000
# 1                                 0.000                         0.000
# 2                                 0.000                         0.000
# 3                                 0.000                         0.000
# 4                                 0.000                         0.000
#
#    onehotencoder__department_management  onehotencoder__department_marketing  \
# ...

# %%
from sklearn.metrics import adjusted_rand_score

adjusted_rand_score(X.cluster, X.pred_cluster)
# Out:
# 0.32412020010861164

# %%
ct = pd.crosstab(X.pred_cluster, X.cluster)
ct
# Out:
# cluster          0     1
# pred_cluster
# 0             2368     0
# 1                0  3527
# 2             3325     0
# 3                0  1147
# 4             1573     0
# 5             1287     0
# 6                0  1772

# %%
# evaluation function

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    print("TEST REPORT")
    print(classification_report(y_test, y_pred_test))
    plot_confusion_matrix(model, X_test, y_test);

    print("\n"*3, "-*"*30)
    print("TRAIN REPORT")
    print(classification_report(y_train, y_pred_train))
    plot_confusion_matrix(model, X_train, y_train);

# %% [markdown]
# ## 5. Model Building

# %% [markdown]
# ### Split Data as Train and Test Set

# %%
df.head()
# Out:
#    satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0         0.380            0.530               2                   157
# 1         0.800            0.860               5                   262
# 2         0.110            0.880               7                   272
# 3         0.720            0.870               5                   223
# 4         0.370            0.520               2                   159
#
#    experience  work_accident  promotion_last_5years department  left  salary
# 0           3              0                      0      sales     1     low
# 1           6              0                      0      sales     1  medium
# 2           4              0                      0      sales     1  medium
# 3           5              0                      0      sales     1     low
# 4           3              0                      0      sales     1     low

# %%
X = df.drop('left', axis = 1)
y = df['left']

# %%
column_trans = make_column_transformer(
    (OneHotEncoder(handle_unknown="ignore", sparse=False), ["department"]),
    (OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ["salary"]), 
    remainder=MinMaxScaler()
)
X = pd.DataFrame(data=column_trans.fit_transform(X), columns=column_trans.get_feature_names_out())

# %% [markdown]
# ### #Distance Based(?) Algorithm

# %% [markdown]
# #### Logistic Regression

# %% [markdown]
# ##### Model Building

# %%
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
log_model=LogisticRegression()
log_model.fit(X_train, y_train)

y_pred=log_model.predict(X_test)
y_pred_proba = log_model.predict_proba(X_test)

# %% [markdown]
# ##### Evaluating Model Performance and Tuning

# %%
eval_metric(log_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85      2262
#            1       0.53      0.25      0.34       738
#
#     accuracy                           0.76      3000
#    macro avg       0.66      0.59      0.60      3000
# weighted avg       0.73      0.76      0.73      3000
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86      9166
#            1       0.52      0.25      0.34      2833
#
#     accuracy                           0.77     11999
#    macro avg       0.66      0.59      0.60     11999
# weighted avg       0.74      0.77      0.74     11999

# %%
test_data = pd.concat([X_test, y_test], axis=1)
test_data.head()
# Out:
#        onehotencoder__department_IT  onehotencoder__department_RandD  \
# 2786                          0.000                            0.000
# 9619                          0.000                            0.000
# 10356                         0.000                            0.000
# 2169                          0.000                            0.000
# 1139                          0.000                            0.000
#
#        onehotencoder__department_accounting  onehotencoder__department_hr  \
# 2786                                  0.000                         0.000
# 9619                                  0.000                         0.000
# 10356                                 0.000                         0.000
# 2169                                  0.000                         1.000
# 1139                                  0.000                         0.000
#
#        onehotencoder__department_management  \
# 2786                                  0.000
# ...

# %%
test_data["pred_proba"] = y_pred_proba[:,1]
test_data.head()
# Out:
#        onehotencoder__department_IT  onehotencoder__department_RandD  \
# 2786                          0.000                            0.000
# 9619                          0.000                            0.000
# 10356                         0.000                            0.000
# 2169                          0.000                            0.000
# 1139                          0.000                            0.000
#
#        onehotencoder__department_accounting  onehotencoder__department_hr  \
# 2786                                  0.000                         0.000
# 9619                                  0.000                         0.000
# 10356                                 0.000                         0.000
# 2169                                  0.000                         1.000
# 1139                                  0.000                         0.000
#
#        onehotencoder__department_management  \
# 2786                                  0.000
# ...

# %%
test_data["pred"] = y_pred
test_data.sample(7)
# Out:
#        onehotencoder__department_IT  onehotencoder__department_RandD  \
# 6399                          1.000                            0.000
# 12463                         0.000                            0.000
# 11634                         0.000                            0.000
# 12058                         0.000                            0.000
# 9364                          0.000                            0.000
# 13959                         1.000                            0.000
# 8234                          0.000                            0.000
#
#        onehotencoder__department_accounting  onehotencoder__department_hr  \
# 6399                                  0.000                         0.000
# 12463                                 0.000                         0.000
# 11634                                 0.000                         0.000
# 12058                                 0.000                         0.000
# ...

# %%
# Cross Validate

# %%
from sklearn.model_selection import cross_validate

# %%
import sklearn
sklearn.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'matthews_corrcoef', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'top_k_accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard
# ...

# %%
model = LogisticRegression()

scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision','recall','f1'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores
# Out:
#     fit_time  score_time  test_accuracy  test_precision  test_recall  test_f1
# 1      0.049       0.008          0.757           0.469        0.216    0.295
# 2      0.062       0.013          0.763           0.496        0.244    0.327
# 3      0.070       0.010          0.762           0.493        0.233    0.317
# 4      0.080       0.016          0.777           0.555        0.269    0.362
# 5      0.058       0.012          0.759           0.478        0.226    0.307
# 6      0.066       0.007          0.791           0.611        0.311    0.412
# 7      0.059       0.007          0.767           0.517        0.264    0.350
# 8      0.051       0.015          0.774           0.547        0.264    0.356
# 9      0.059       0.009          0.758           0.478        0.232    0.313
# 10     0.062       0.012          0.778           0.563        0.269    0.364

# %%
df_scores.mean()[2:]
# Out:
# test_accuracy    0.769
# test_precision   0.521
# test_recall      0.253
# test_f1          0.340
# dtype: float64

# %%
print("Test Set")
print(classification_report(y_test,y_pred))
print("Train Set\n")
y_train_pred = log_model.predict(X_train)
print(classification_report(y_train,y_train_pred))
# Out:
# Test Set
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85      2262
#            1       0.53      0.25      0.34       738
#
#     accuracy                           0.76      3000
#    macro avg       0.66      0.59      0.60      3000
# weighted avg       0.73      0.76      0.73      3000
#
# Train Set
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86      9166
#            1       0.52      0.25      0.34      2833
#
#     accuracy                           0.77     11999
#    macro avg       0.66      0.59      0.60     11999
# weighted avg       0.74      0.77      0.74     11999

# %%
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, roc_auc_score, auc, roc_curve

# %%
plot_roc_curve(log_model, X_test, y_test);

# %%
# GridSearchCV

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.model_selection import GridSearchCV

model = LogisticRegression()

penalty = ["l1", "l2"]
C = np.logspace(-1, 5, 20)
class_weight= ["balanced", None] 
# The "balanced" mode uses the values of y to automatically adjust weights inversely proportional to class frequencies 
# in the input data
solver = ["lbfgs", "liblinear", "sag", "saga"]

param_grid = {"penalty" : penalty,
              "C" : C,
              "class_weight":class_weight,
              "solver":solver}


grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          cv=10,
                          scoring = "recall",   #f1_0 = make_scorer(f1_score, pos_label =0)
                          n_jobs = -1)

# %%
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': array([1.00000000e-01, 2.06913808e-01, 4.28133240e-01, 8.85866790e-01,
#        1.83298071e+00, 3.79269019e+00, 7.84759970e+00, 1.62377674e+01,
#        3.35981829e+01, 6.95192796e+01, 1.43844989e+02, 2.97635144e+02,
#        6.15848211e+02, 1.27427499e+03, 2.63665090e+03, 5.45559478e+03,
#        1.12883789e+04, 2.33572147e+04, 4.83293024e+04, 1.00000000e+05]),
#                          'class_weight': ['balanced', None],
#                          'penalty': ['l1', 'l2'],
#                          'solver': ['lbfgs', 'liblinear', 'sag', 'saga']},
#              scoring='recall')

# %%
eval_metric(grid_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81      2262
#            1       0.48      0.75      0.59       738
#
#     accuracy                           0.74      3000
#    macro avg       0.69      0.74      0.70      3000
# weighted avg       0.80      0.74      0.76      3000
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            0       0.92      0.75      0.82      9166
#            1       0.49      0.78      0.60      2833
#
#     accuracy                           0.76     11999
#    macro avg       0.70      0.76      0.71     11999
# weighted avg       0.82      0.76      0.77     11999

# %%
plot_precision_recall_curve(grid_model, X_test, y_test);

# %%
y_pred=grid_model.predict(X_test)
y_pred_proba = grid_model.predict_proba(X_test)

log_f1 = f1_score(y_test, y_pred)
log_recall = recall_score(y_test, y_pred)
log_auc = roc_auc_score(y_test, y_pred_proba[:,1])

# %%
log_recall
# Out:
# 0.7520325203252033

# %% [markdown]
# - Confusion Matrix : You can use scikit-learn metrics module for accuracy calculation. A Confusion matrix is an N x N matrix used for evaluating the performance of a classification model, where N is the number of target classes. The matrix compares the actual target values with those predicted by the machine learning model. This gives us a holistic view of how well our classification model is performing and what kinds of errors it is making.
#
#     [Confusion Matrix](https://www.analyticsvidhya.com/blog/2020/04/confusion-matrix-machine-learning/)

# %% [markdown]
# - Yellowbrick: Yellowbrick is a suite of visualization and diagnostic tools that will enable quicker model selection. It’s a Python package that combines scikit-learn and matplotlib. Some of the more popular visualization tools include model selection, feature visualization, classification and regression visualization
#
#     [Yellowbrick](https://www.analyticsvidhya.com/blog/2018/05/yellowbrick-a-set-of-visualization-tools-to-accelerate-your-model-selection-process/)

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)

y_pred = knn_model.predict(X_test)
y_pred_proba = knn_model.predict_proba(X_test)

knn_f1 = f1_score(y_test, y_pred)
knn_recall = recall_score(y_test, y_pred)
knn_auc = roc_auc_score(y_test, y_pred_proba[:,1])

eval_metric(knn_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      2262
#            1       0.86      0.90      0.88       738
#
#     accuracy                           0.94      3000
#    macro avg       0.92      0.93      0.92      3000
# weighted avg       0.94      0.94      0.94      3000
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      9166
#            1       0.90      0.93      0.92      2833
#
#     accuracy                           0.96     11999
#    macro avg       0.94      0.95      0.95     11999
# weighted avg       0.96      0.96      0.96     11999

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[2158,  104],
#        [  76,  662]], dtype=int64)

# %%
# Elbow Method for Choosing Reasonable K Values

# %%
test_error_rates = []


for k in range(1,30):
    knn_model = KNeighborsClassifier(n_neighbors=k)  
    knn_model.fit(X_train,y_train) 
   
    y_pred_test = knn_model.predict(X_test)
    
    
    test_error = 1 - accuracy_score(y_test,y_pred_test)
    
    test_error_rates.append(test_error)

# %%
plt.figure(figsize=(15,8))
plt.plot(range(1,30), test_error_rates, color='blue', linestyle='--', marker='o',
         markerfacecolor='red', markersize=10)

plt.title('Error Rate vs. K Value')
plt.xlabel('K_values')
plt.ylabel('Error Rate')
plt.hlines(y=0.050, xmin = 0, xmax = 30, colors= 'r', linestyles="--")
plt.hlines(y=0.057, xmin = 0, xmax = 30, colors= 'r', linestyles="--")

# %%
# Overfiting and underfiting control for k values

# %%
test_error_rates = []
train_error_rates = []


for k in range(1,30):
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train,y_train) 
   
    y_pred_test = knn_model.predict(X_test)
    y_pred_train = knn_model.predict(X_train)
    
    test_error = 1 - accuracy_score(y_test,y_pred_test)
    train_error = 1 - accuracy_score(y_train,y_pred_train)
    test_error_rates.append(test_error)
    train_error_rates.append(train_error)

# %%
plt.figure(figsize=(15,8))
plt.plot(range(1,30), test_error_rates, color='blue', linestyle='--', marker='o',
         markerfacecolor='red', markersize=10)
plt.plot(range(1,30), train_error_rates, color='green', linestyle='--', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K_values')
plt.ylabel('Error Rate')
plt.hlines(y=0.050, xmin = 0, xmax = 30, colors= 'r', linestyles="--")
plt.hlines(y=0.057, xmin = 0, xmax = 30, colors= 'r', linestyles="--")

# %%
# Scores by Various K Values

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set\n")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set\n")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(X_train,y_train)
print('WITH K=1\n')
eval_metric(knn, X_train, y_train, X_test, y_test)
# Out:
# WITH K=1
#
# Test_Set
#
# [[2196   66]
#  [  29  709]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      2262
#            1       0.91      0.96      0.94       738
#
#     accuracy                           0.97      3000
#    macro avg       0.95      0.97      0.96      3000
# weighted avg       0.97      0.97      0.97      3000
#
#
# Train_Set
#
# [[9166    0]
#  [   0 2833]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9166
#            1       1.00      1.00      1.00      2833
#
#     accuracy                           1.00     11999
#    macro avg       1.00      1.00      1.00     11999
# weighted avg       1.00      1.00      1.00     11999

# %%
knn = KNeighborsClassifier(n_neighbors=22)

knn.fit(X_train,y_train)
print('WITH K=22\n')
eval_metric(knn, X_train, y_train, X_test, y_test)
# Out:
# WITH K=22
#
# Test_Set
#
# [[2159  103]
#  [ 118  620]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      2262
#            1       0.86      0.84      0.85       738
#
#     accuracy                           0.93      3000
#    macro avg       0.90      0.90      0.90      3000
# weighted avg       0.93      0.93      0.93      3000
#
#
# Train_Set
#
# [[8764  402]
#  [ 465 2368]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      9166
#            1       0.85      0.84      0.85      2833
#
#     accuracy                           0.93     11999
#    macro avg       0.90      0.90      0.90     11999
# weighted avg       0.93      0.93      0.93     11999

# %%
knn = KNeighborsClassifier(n_neighbors=9)                   # n_neighbors=9, test_accuracy : 94  (with 52 error)

knn.fit(X_train,y_train)
print('WITH K=9\n')
eval_metric(knn, X_train, y_train, X_test, y_test)
# Out:
# WITH K=9
#
# Test_Set
#
# [[2172   90]
#  [  79  659]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      2262
#            1       0.88      0.89      0.89       738
#
#     accuracy                           0.94      3000
#    macro avg       0.92      0.93      0.92      3000
# weighted avg       0.94      0.94      0.94      3000
#
#
# Train_Set
#
# [[8841  325]
#  [ 318 2515]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      9166
#            1       0.89      0.89      0.89      2833
#
#     accuracy                           0.95     11999
#    macro avg       0.93      0.93      0.93     11999
# weighted avg       0.95      0.95      0.95     11999

# %%
knn = KNeighborsClassifier(n_neighbors=15)

knn.fit(X_train,y_train)
print('WITH K=15\n')
eval_metric(knn, X_train, y_train, X_test, y_test)
# Out:
# WITH K=15
#
# Test_Set
#
# [[2168   94]
#  [ 100  638]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      2262
#            1       0.87      0.86      0.87       738
#
#     accuracy                           0.94      3000
#    macro avg       0.91      0.91      0.91      3000
# weighted avg       0.94      0.94      0.94      3000
#
#
# Train_Set
#
# [[8778  388]
#  [ 406 2427]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      9166
#            1       0.86      0.86      0.86      2833
#
#     accuracy                           0.93     11999
#    macro avg       0.91      0.91      0.91     11999
# weighted avg       0.93      0.93      0.93     11999

# %% [markdown]
# ##### Cross Validate For Optimal K Value

# %%
from sklearn.model_selection import cross_val_score, cross_validate

# %%
model = KNeighborsClassifier(n_neighbors=1)

scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision','recall',
                                                                   'f1'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores
# Out:
#     fit_time  score_time  test_accuracy  test_precision  test_recall  test_f1
# 1      0.007       0.104          0.965           0.893        0.968    0.929
# 2      0.004       0.107          0.959           0.885        0.951    0.917
# 3      0.005       0.093          0.967           0.896        0.972    0.932
# 4      0.004       0.090          0.957           0.889        0.933    0.910
# 5      0.003       0.085          0.963           0.900        0.951    0.924
# 6      0.003       0.097          0.963           0.905        0.940    0.922
# 7      0.004       0.114          0.967           0.921        0.940    0.930
# 8      0.004       0.089          0.966           0.906        0.954    0.930
# 9      0.004       0.094          0.965           0.893        0.968    0.929
# 10     0.003       0.114          0.966           0.898        0.965    0.930

# %%
df_scores.mean()[2:]
# Out:
# test_accuracy    0.964
# test_precision   0.898
# test_recall      0.954
# test_f1          0.925
# dtype: float64

# %%
# Gridsearch Method for Choosing Reasonable K Values

# %%
from sklearn.model_selection import GridSearchCV

# %%
knn_grid = KNeighborsClassifier()

# %%
k_values= range(1,30)

# %%
param_grid = {"n_neighbors":k_values, "p": [1,2], "weights": ['uniform', "distance"]}

# %%
knn_grid_model = GridSearchCV(knn_grid, param_grid, cv=10, scoring= 'recall')

# %%
knn_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(1, 30), 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              scoring='recall')

# %%
knn_grid_model.best_params_
# Out:
# {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}

# %%
print('WITH K=9\n')
eval_metric(knn_grid_model, X_train, y_train, X_test, y_test)

# n_neighbors=9,      test_recall: 96  with 106 error
# Out:
# WITH K=9
#
# Test_Set
#
# [[2184   78]
#  [  28  710]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      2262
#            1       0.90      0.96      0.93       738
#
#     accuracy                           0.96      3000
#    macro avg       0.94      0.96      0.95      3000
# weighted avg       0.97      0.96      0.97      3000
#
#
# Train_Set
#
# [[9166    0]
#  [   0 2833]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9166
#            1       1.00      1.00      1.00      2833
#
#     accuracy                           1.00     11999
#    macro avg       1.00      1.00      1.00     11999
# weighted avg       1.00      1.00      1.00     11999

# %%
# Evaluating ROC Curves and AUC

# %%
from sklearn.metrics import precision_recall_curve, plot_precision_recall_curve, plot_roc_curve, roc_auc_score, roc_curve

# %%
knn_model = KNeighborsClassifier(n_neighbors=9).fit(X_train, y_train)

# %%
plot_roc_curve(knn_grid_model, X_test, y_test)

# %%
y_pred = knn_grid_model.predict(X_test)
y_pred_proba = knn_grid_model.predict_proba(X_test)

knn_f1 = f1_score(y_test, y_pred)
knn_recall = recall_score(y_test, y_pred)
knn_auc = roc_auc_score(y_test, y_pred_proba[:,1])

knn_recall
# Out:
# 0.962059620596206

# %% [markdown]
# ##### Prediction

# %%
observations = {"satisfaction": [0.6, 0.1], "last_evaluation":[0.7, 0.8], "number_project":[4, 7],
               "average_montly_hours":[180, 300], "experience":[3, 4], "work_accident":[0, 0],
                "promotion_last_5years":[1, 0], "department":["sales", "marketing"], "salary":["low", "medium"]}

obs = pd.DataFrame(observations)
obs
# Out:
#    satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0         0.600            0.700               4                   180
# 1         0.100            0.800               7                   300
#
#    experience  work_accident  promotion_last_5years department  salary
# 0           3              0                      1      sales     low
# 1           4              0                      0  marketing  medium

# %%
X = df.drop('left', axis = 1)
y = df['left']

# %%
column_trans = make_column_transformer(
    (OneHotEncoder(handle_unknown="ignore", sparse=False), ["department"]),
    (OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ["salary"]), 
    remainder=MinMaxScaler()
)
X = pd.DataFrame(data=column_trans.fit_transform(X), columns=column_trans.get_feature_names_out())

# %%
obs = pd.DataFrame(data=column_trans.transform(obs), columns=column_trans.get_feature_names_out())
obs
# Out:
#    onehotencoder__department_IT  onehotencoder__department_RandD  \
# 0                         0.000                            0.000
# 1                         0.000                            0.000
#
#    onehotencoder__department_accounting  onehotencoder__department_hr  \
# 0                                 0.000                         0.000
# 1                                 0.000                         0.000
#
#    onehotencoder__department_management  onehotencoder__department_marketing  \
# 0                                 0.000                                0.000
# 1                                 0.000                                1.000
#
#    onehotencoder__department_product_mng  onehotencoder__department_sales  \
# 0                                  0.000                            1.000
# 1                                  0.000                            0.000
#
#    onehotencoder__department_support  onehotencoder__department_technical  \
# ...

# %%
knn_grid_model.predict(obs)
# Out:
# array([0, 1])

# %%
df.sample()
# Out:
#       satisfaction  last_evaluation  number_project  average_montly_hours  \
# 7702         0.910            0.670               4                   206
#
#       experience  work_accident  promotion_last_5years department  left salary
# 7702           3              0                      0         IT     0    low

# %%
df1 = df.iloc[6817].to_frame().T
df1
# Out:
#      satisfaction last_evaluation number_project average_montly_hours  \
# 6817        0.260           0.450              5                  187
#
#      experience work_accident promotion_last_5years department left salary
# 6817          2             0                     0      sales    0    low

# %%
df1 = pd.DataFrame(data=column_trans.transform(df1), columns=column_trans.get_feature_names_out())
df1
# Out:
#    onehotencoder__department_IT  onehotencoder__department_RandD  \
# 0                         0.000                            0.000
#
#    onehotencoder__department_accounting  onehotencoder__department_hr  \
# 0                                 0.000                         0.000
#
#    onehotencoder__department_management  onehotencoder__department_marketing  \
# 0                                 0.000                                0.000
#
#    onehotencoder__department_product_mng  onehotencoder__department_sales  \
# 0                                  0.000                            1.000
#
#    onehotencoder__department_support  onehotencoder__department_technical  \
# 0                              0.000                                0.000
#
#    ordinalencoder__salary  remainder__satisfaction  \
# 0                   1.000                    0.187
#
#    remainder__last_evaluation  remainder__number_project  \
# 0                       0.141                      0.600
#
# ...

# %%
knn_grid_model.predict(df1)
# Out:
# array([0])

# %%
df[df["left"]==1]
# Out:
#        satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0             0.380            0.530               2                   157
# 1             0.800            0.860               5                   262
# 2             0.110            0.880               7                   272
# 3             0.720            0.870               5                   223
# 4             0.370            0.520               2                   159
# ...             ...              ...             ...                   ...
# 14994         0.400            0.570               2                   151
# 14995         0.370            0.480               2                   160
# 14996         0.370            0.530               2                   143
# 14997         0.110            0.960               6                   280
# 14998         0.370            0.520               2                   158
#
# ...

# %%
df1 = X.iloc[14994].to_frame().T
df1
# Out:
#        onehotencoder__department_IT  onehotencoder__department_RandD  \
# 14994                         0.000                            0.000
#
#        onehotencoder__department_accounting  onehotencoder__department_hr  \
# 14994                                 0.000                         0.000
#
#        onehotencoder__department_management  \
# 14994                                 0.000
#
#        onehotencoder__department_marketing  \
# 14994                                0.000
#
#        onehotencoder__department_product_mng  onehotencoder__department_sales  \
# 14994                                  0.000                            0.000
#
#        onehotencoder__department_support  onehotencoder__department_technical  \
# 14994                              1.000                                0.000
#
#        ordinalencoder__salary  remainder__satisfaction  \
# 14994                   1.000                    0.341
#
# ...

# %%
knn_grid_model.predict(df1)
# Out:
# array([1])

# %% [markdown]
# ### Random Forest Classifier

# %% [markdown]
# #### Model Building

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_validate, cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
X = df.drop('left', axis = 1)
y = df['left']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size = 0.3, random_state = 101)

# %%
cat = X_train.select_dtypes("string").columns
cat
# Out:
# Index(['department', 'salary'], dtype='object')

# %%
ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1) 

column_trans = make_column_transformer((ord_enc, cat), remainder='passthrough')

# %%
operations = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", random_state=101))]

RF_pipe_model = Pipeline(steps=operations)

# %%
RF_pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['department', 'salary'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced',
#                                         random_state=101))])

# %% [markdown]
# #### Evaluating Model Performance and Tuning

# %%
eval_metric(RF_pipe_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
#
# [[3423    6]
#  [  43 1028]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3429
#            1       0.99      0.96      0.98      1071
#
#     accuracy                           0.99      4500
#    macro avg       0.99      0.98      0.98      4500
# weighted avg       0.99      0.99      0.99      4500
#
#
# Train_Set
#
# [[7999    0]
#  [   0 2500]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7999
#            1       1.00      1.00      1.00      2500
#
#     accuracy                           1.00     10499
#    macro avg       1.00      1.00      1.00     10499
# weighted avg       1.00      1.00      1.00     10499

# %% [markdown]
# #### Random Forest Model Cross Validation

# %%
model = Pipeline(operations)
scores = cross_validate(model, X_train, y_train, 
                        scoring=['precision','recall','f1','accuracy'], cv=10 )
scores = pd.DataFrame(scores, index = range(1, 11))
scores.mean()[2:]
# Out:
# test_precision   0.993
# test_recall      0.970
# test_f1          0.982
# test_accuracy    0.991
# dtype: float64

# %%
from yellowbrick.classifier import ClassPredictionError
visualizer = ClassPredictionError(RF_pipe_model)
# Fit the training data to the visualizer
visualizer.fit(X_train, y_train)
# Evaluate the model on the test data
visualizer.score(X_test, y_test)
# Draw visualization
visualizer.poof();

# %%
model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = ['precision','recall','f1','accuracy'], cv = 10)

df_scores = pd.DataFrame(scores, index = range(1, 11))

df_scores.mean()[2:]
# Out:
# test_precision   0.993
# test_recall      0.970
# test_f1          0.982
# test_accuracy    0.991
# dtype: float64

# %%
from yellowbrick.classifier import ROCAUC

model = RF_pipe_model
visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();                       # Finalize and render the figure

# %%
RF_pipe_model["RF_model"].feature_importances_ # rf_model.feature_importances_
# Out:
# array([0.01612614, 0.0096284 , 0.28835352, 0.12780673, 0.14470102,
#        0.14624213, 0.25631586, 0.00955177, 0.00127445])

# %%
features = list(X_train.select_dtypes("object").columns) + list(X_train.select_dtypes("number").columns)
features
# Out:
# ['satisfaction',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'experience',
#  'work_accident',
#  'promotion_last_5years']

# %%
rf_feature_imp = pd.DataFrame(data = RF_pipe_model["RF_model"].feature_importances_, index = X.columns, #index=X.columns
                              columns = ["Feature Importance"]).sort_values("Feature Importance", ascending = False)
rf_feature_imp
# Out:
#                        Feature Importance
# number_project                      0.288
# promotion_last_5years               0.256
# work_accident                       0.146
# experience                          0.145
# average_montly_hours                0.128
# satisfaction                        0.016
# last_evaluation                     0.010
# department                          0.010
# salary                              0.001

# %%
ax = sns.barplot(x=rf_feature_imp["Feature Importance"], y=rf_feature_imp.index)
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.title("Feature Importance for Random Forest")
plt.show()

# %%
## Understanding Hyperparameters

# %%
param_grid = {"RF_model__n_estimators":[3, 5, 8],
             "RF_model__criterion":["entropy","gini"],
              "RF_model__max_features":['auto',"log2", "sqrt"],
              "RF_model__max_depth": [3, 7, 9],
             "RF_model__min_samples_split": [2, 5],
             "RF_model__min_samples_leaf" : [1, 5]}

# %%
RF_grid = Pipeline(steps=operations)
RF_grid_model = GridSearchCV(estimator = RF_grid,
                             cv = 10,
                             param_grid = param_grid, 
                             scoring = "recall", 
                             n_jobs = -1, verbose = 2)

# %%
RF_grid_model.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 216 candidates, totalling 2160 fits
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          Index(['department', 'salary'], dtype='object'))])),
#                                        ('RF_model',
#                                         RandomForestClassifier(class_weight='balanced',
#                                                                random_state=101))]),
#              n_jobs=-1,
# ...

# %%
RF_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['department', 'salary'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced', max_depth=9,
#                                         max_features='auto',
#                                         min_samples_split=5, n_estimators=5,
#                                         random_state=101))])

# %%
RF_grid_model.best_score_
# Out:
# 0.9364000000000001

# %%
RF_grid_model.best_params_
# Out:
# {'RF_model__criterion': 'gini',
#  'RF_model__max_depth': 9,
#  'RF_model__max_features': 'auto',
#  'RF_model__min_samples_leaf': 1,
#  'RF_model__min_samples_split': 5,
#  'RF_model__n_estimators': 5}

# %%
ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1) 

column_trans = make_column_transformer((ord_enc, cat), remainder='passthrough')

operations = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight = 'balanced',
                                  max_depth = 9,
                                  max_features = 'auto',
                                  n_estimators = 3,
                                  min_samples_split = 2,
                                  random_state = 101))]

RF_tuned = Pipeline(steps=operations)

RF_tuned.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['department', 'salary'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced', max_depth=9,
#                                         max_features='auto', n_estimators=3,
#                                         random_state=101))])

# %%
y_pred = RF_tuned.predict(X_test)
y_train_pred = RF_tuned.predict(X_train)

RF_tuned_f1 = f1_score(y_test, y_pred)
RF_tuned_acc = accuracy_score(y_test, y_pred)
RF_tuned_recall = recall_score(y_test, y_pred)
RF_tuned_auc = roc_auc_score(y_test, y_pred)

# %%
RF_tuned_auc
# Out:
# 0.9570837958980617

# %%
print("RF_tuned")
print ("------------------")
eval_metric(RF_tuned, X_train, y_train, X_test, y_test)
# Out:
# RF_tuned
# ------------------
# Test_Set
#
# [[3362   67]
#  [  71 1000]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      3429
#            1       0.94      0.93      0.94      1071
#
#     accuracy                           0.97      4500
#    macro avg       0.96      0.96      0.96      4500
# weighted avg       0.97      0.97      0.97      4500
#
#
# Train_Set
#
# [[7892  107]
#  [ 118 2382]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7999
#            1       0.96      0.95      0.95      2500
#
#     accuracy                           0.98     10499
#    macro avg       0.97      0.97      0.97     10499
# weighted avg       0.98      0.98      0.98     10499

# %%
from yellowbrick.classifier import ClassPredictionError
visualizer = ClassPredictionError(RF_tuned)
# Fit the training data to the visualizer
visualizer.fit(X_train, y_train)
# Evaluate the model on the test data
visualizer.score(X_test, y_test)
# Draw visualization
visualizer.poof();

# %% [markdown]
# #### Prediction

# %%
X = df.drop(columns=["left"])
y = df['left']

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder


ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

column_trans = make_column_transformer((ord_enc, cat), remainder=MinMaxScaler())

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import Pipeline

operations = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight = 'balanced',
                                  max_depth = 9,
                                  max_features = 'auto',
                                  n_estimators = 3,
                                  min_samples_split = 2,
                                  random_state = 101))]

RF_final_pipe_model = Pipeline(steps=operations)
RF_final_pipe_model.fit(X, y)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['department', 'salary'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced', max_depth=9,
#                                         max_features='auto', n_estimators=3,
#                                         random_state=101))])

# %%
X.head()
# Out:
#    satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0         0.380            0.530               2                   157
# 1         0.800            0.860               5                   262
# 2         0.110            0.880               7                   272
# 3         0.720            0.870               5                   223
# 4         0.370            0.520               2                   159
#
#    experience  work_accident  promotion_last_5years department  salary
# 0           3              0                      0      sales     low
# 1           6              0                      0      sales  medium
# 2           4              0                      0      sales  medium
# 3           5              0                      0      sales     low
# 4           3              0                      0      sales     low

# %%
df.describe().T
# Out:
#                           count    mean    std    min     25%     50%     75%  \
# satisfaction          14999.000   0.613  0.249  0.090   0.440   0.640   0.820
# last_evaluation       14999.000   0.716  0.171  0.360   0.560   0.720   0.870
# number_project        14999.000   3.803  1.233  2.000   3.000   4.000   5.000
# average_montly_hours  14999.000 201.050 49.943 96.000 156.000 200.000 245.000
# experience            14999.000   3.498  1.460  2.000   3.000   3.000   4.000
# work_accident         14999.000   0.145  0.352  0.000   0.000   0.000   0.000
# promotion_last_5years 14999.000   0.021  0.144  0.000   0.000   0.000   0.000
# left                  14999.000   0.238  0.426  0.000   0.000   0.000   0.000
#
#                           max
# satisfaction            1.000
# last_evaluation         1.000
# number_project          7.000
# average_montly_hours  310.000
# experience             10.000
# work_accident           1.000
# promotion_last_5years   1.000
# ...

# %%
df.columns
# Out:
# Index(['satisfaction', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'experience', 'work_accident',
#        'promotion_last_5years', 'department', 'left', 'salary'],
#       dtype='object')

# %%
observations = {"satisfaction": [0.6, 0.1], "last_evaluation":[0.7, 0.8], "number_project":[4, 7],
               "average_montly_hours":[180, 300], "experience":[3, 4], "work_accident":[0, 0],
                "promotion_last_5years":[1, 0], "department":["sales", "marketing"], "salary":["low", "medium"]}

obs = pd.DataFrame(observations)
obs
# Out:
#    satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0         0.600            0.700               4                   180
# 1         0.100            0.800               7                   300
#
#    experience  work_accident  promotion_last_5years department  salary
# 0           3              0                      1      sales     low
# 1           4              0                      0  marketing  medium

# %%
RF_final_pipe_model.predict(obs)
# Out:
# array([0, 1])

# %% [markdown]
# ### #XGBoost Classifier

# %% [markdown]
# #### Model Building

# %%
# XG Boosting Modelling and Model Performance

# %%
# pip install xgboost==0.90
import xgboost as xgb

xgb.__version__
# Out:
# '0.90'

# %%
from xgboost import XGBClassifier

# %%
X = df.drop('left', axis = 1)
y = df['left']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction           14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int32
#  3   average_montly_hours   14999 non-null  int32
#  4   experience             14999 non-null  int32
#  5   work_accident          14999 non-null  int32
#  6   promotion_last_5years  14999 non-null  int32
#  7   department             14999 non-null  string
#  8   left                   14999 non-null  int32
#  9   salary                 14999 non-null  string
# dtypes: float64(2), int32(6), string(2)
# memory usage: 820.4 KB

# %%
cat = X_train.select_dtypes("string").columns
cat
# Out:
# Index(['department', 'salary'], dtype='object')

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1) 

column_trans = make_column_transformer((ord_enc, cat), remainder=MinMaxScaler())

# %%
operations = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101))]

XGB_pipe_model = Pipeline(steps=operations)

# %%
XGB_pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['department', 'salary'], dtype='object'))])),
#                 ('XGB_model', XGBClassifier(random_state=101))])

# %% [markdown]
# #### Evaluating Model Performance and Tuning

# %%
eval_metric(XGB_pipe_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
#
# [[2240   22]
#  [  48  690]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      2262
#            1       0.97      0.93      0.95       738
#
#     accuracy                           0.98      3000
#    macro avg       0.97      0.96      0.97      3000
# weighted avg       0.98      0.98      0.98      3000
#
#
# Train_Set
#
# [[9077   89]
#  [ 213 2620]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      9166
#            1       0.97      0.92      0.95      2833
#
#     accuracy                           0.97     11999
#    macro avg       0.97      0.96      0.96     11999
# weighted avg       0.97      0.97      0.97     11999

# %%
model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision','recall',
                                                                   'f1', 'roc_auc'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy    0.974
# test_precision   0.967
# test_recall      0.923
# test_f1          0.944
# test_roc_auc     0.988
# dtype: float64

# %%
param_grid = {"XGB_model__n_estimators":[110, 150, 200],
              'XGB_model__max_depth':[14,15,18,25], 
              "XGB_model__learning_rate": [0.1, 0.15, 0.2]}

# %%
xgb_model = Pipeline(steps=operations)

# %%
xgb_grid = GridSearchCV(xgb_model, param_grid, scoring = "recall", verbose=2, n_jobs = -1).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %%
xgb_grid.best_params_
# Out:
# {'XGB_model__learning_rate': 0.2,
#  'XGB_model__max_depth': 25,
#  'XGB_model__n_estimators': 110}

# %%
xgb_grid.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['department', 'salary'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(learning_rate=0.2, max_depth=25,
#                                n_estimators=110, random_state=101))])

# %%
xgb_grid.best_score_
# Out:
# 0.9647054424439583

# %%
y_pred = xgb_grid.predict(X_test)
y_pred_proba = xgb_grid.predict_proba(X_test)

xgb_f1 = f1_score(y_test, y_pred)
xgb_recall = recall_score(y_test, y_pred)
xgb_auc = roc_auc_score(y_test, y_pred_proba[:,1])

eval_metric(xgb_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
#
# [[2257    5]
#  [  15  723]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2262
#            1       0.99      0.98      0.99       738
#
#     accuracy                           0.99      3000
#    macro avg       0.99      0.99      0.99      3000
# weighted avg       0.99      0.99      0.99      3000
#
#
# Train_Set
#
# [[9166    0]
#  [   0 2833]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9166
#            1       1.00      1.00      1.00      2833
#
#     accuracy                           1.00     11999
#    macro avg       1.00      1.00      1.00     11999
# weighted avg       1.00      1.00      1.00     11999

# %%
# Feature importances

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1) 

column_trans = make_column_transformer((ord_enc, cat), remainder=MinMaxScaler())
operations = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101,
                                                                            colsample_bytree = 1,
                                                                            subsample= 1,
                                                                            learning_rate= 0.2,
                                                                            max_depth= 25,
                                                                            n_estimators= 110                                                                                                                                                                                                                           
                                                                           ))]


model = Pipeline(steps=operations)
model.fit(X_train, y_train)


feats = pd.DataFrame(index=X.columns, data=model["XGB_model"].feature_importances_, columns=['xgb_importance'])
xgb_imp_feats = feats.sort_values("xgb_importance", ascending=False)
xgb_imp_feats
# Out:
#                        xgb_importance
# promotion_last_5years           0.285
# number_project                  0.269
# experience                      0.183
# average_montly_hours            0.084
# salary                          0.062
# work_accident                   0.048
# department                      0.027
# last_evaluation                 0.023
# satisfaction                    0.019

# %%
ax = sns.barplot(data=xgb_imp_feats, x=xgb_imp_feats.index,y='xgb_importance')
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.xticks(rotation=90);

# %%
X = df.drop(columns=['left', "satisfaction", "last_evaluation", "department"], axis = 1)
y = df['left']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
cat = X_train.select_dtypes("string").columns
cat
# Out:
# Index(['salary'], dtype='object')

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1) 

column_trans = make_column_transformer((ord_enc, cat), remainder=MinMaxScaler())

# %%
operations = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101))]

XGB_pipe_model = Pipeline(steps=operations)

# %%
XGB_pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['salary'], dtype='object'))])),
#                 ('XGB_model', XGBClassifier(random_state=101))])

# %%
eval_metric(XGB_pipe_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
#
# [[2183   79]
#  [  55  683]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      2262
#            1       0.90      0.93      0.91       738
#
#     accuracy                           0.96      3000
#    macro avg       0.94      0.95      0.94      3000
# weighted avg       0.96      0.96      0.96      3000
#
#
# Train_Set
#
# [[8891  275]
#  [ 258 2575]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      9166
#            1       0.90      0.91      0.91      2833
#
#     accuracy                           0.96     11999
#    macro avg       0.94      0.94      0.94     11999
# weighted avg       0.96      0.96      0.96     11999

# %%
param_grid = {"XGB_model__n_estimators":[110, 150, 200],
              'XGB_model__max_depth':[14,15,18,25], 
              "XGB_model__learning_rate": [0.1, 0.15, 0.2]}

# %%
xgb_imp_fea_model = Pipeline(steps=operations)

# %%
xgb_fea_grid = GridSearchCV(xgb_imp_fea_model, param_grid, scoring = "recall", verbose=2, n_jobs = -1).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %%
xgb_fea_grid.best_params_
# Out:
# {'XGB_model__learning_rate': 0.2,
#  'XGB_model__max_depth': 18,
#  'XGB_model__n_estimators': 200}

# %%
eval_metric(xgb_fea_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
#
# [[2196   66]
#  [  45  693]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      2262
#            1       0.91      0.94      0.93       738
#
#     accuracy                           0.96      3000
#    macro avg       0.95      0.95      0.95      3000
# weighted avg       0.96      0.96      0.96      3000
#
#
# Train_Set
#
# [[9048  118]
#  [  74 2759]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9166
#            1       0.96      0.97      0.97      2833
#
#     accuracy                           0.98     11999
#    macro avg       0.98      0.98      0.98     11999
# weighted avg       0.98      0.98      0.98     11999

# %% [markdown]
# #### Prediction

# %%
observations = {"satisfaction": [0.6, 0.1], "last_evaluation":[0.7, 0.8], "number_project":[4, 7],
               "average_montly_hours":[180, 300], "experience":[3, 4], "work_accident":[0, 0],
                "promotion_last_5years":[1, 0], "department":["sales", "marketing"], "salary":["low", "medium"]}

obs = pd.DataFrame(observations)
obs
# Out:
#    satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0         0.600            0.700               4                   180
# 1         0.100            0.800               7                   300
#
#    experience  work_accident  promotion_last_5years department  salary
# 0           3              0                      1      sales     low
# 1           4              0                      0  marketing  medium

# %%
xgb_grid.predict(obs)
# Out:
# array([0, 1])

# %% [markdown]
# ### #ANN Classifier

# %% [markdown]
# #### Layer Architecture Building and Compiling

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, LabelEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X = df.drop('left', axis = 1)
y = df['left']

# %%
column_trans = make_column_transformer(
    (OneHotEncoder(handle_unknown="ignore", sparse=False), ["department"]),
    (OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ["salary"]), 
    remainder=MinMaxScaler()
)
X = pd.DataFrame(data=column_trans.fit_transform(X), columns=column_trans.get_feature_names_out())

# %%
seed = 42

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size = 0.10, random_state = seed)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_roc_curve, roc_auc_score, roc_curve
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV

# %%
X_train.shape
# Out:
# (13499, 18)

# %%
X_test.shape
# Out:
# (1500, 18)

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(27, activation = "relu", input_dim = X_train.shape[1]))
model.add(Dense(18, activation = "relu"))
model.add(Dense(9, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["Recall"])

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 100, verbose=1)
# Out:
# Epoch 1/100
# 380/380 [==============================] - 2s 2ms/step - loss: 0.5120 - recall: 0.0689 - val_loss: 0.3806 - val_recall: 0.2633
# Epoch 2/100
# 380/380 [==============================] - 1s 1ms/step - loss: 0.3274 - recall: 0.5895 - val_loss: 0.2338 - val_recall: 0.7616
# Epoch 3/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.2103 - recall: 0.8418 - val_loss: 0.1886 - val_recall: 0.8114
# Epoch 4/100
# 380/380 [==============================] - 0s 1ms/step - loss: 0.1765 - recall: 0.8858 - val_loss: 0.1744 - val_recall: 0.8577
# Epoch 5/100
# 380/380 [==============================] - 1s 1ms/step - loss: 0.1653 - recall: 0.8970 - val_loss: 0.1640 - val_recall: 0.8754
# Epoch 6/100
# 380/380 [==============================] - 0s 1ms/step - loss: 0.1572 - recall: 0.9015 - val_loss: 0.1576 - val_recall: 0.8897
# Epoch 7/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 27)                513
#
#  dense_1 (Dense)             (None, 18)                504
#
#  dense_2 (Dense)             (None, 9)                 171
#
#  dense_3 (Dense)             (None, 1)                 10
#
# ...
# Total params: 1,198
# Trainable params: 1,198
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#    loss  recall  val_loss  val_recall
# 0 0.512   0.069     0.381       0.263
# 1 0.327   0.589     0.234       0.762
# 2 0.210   0.842     0.189       0.811
# 3 0.176   0.886     0.174       0.858
# 4 0.165   0.897     0.164       0.875

# %%
loss_df.plot();

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.1163085326552391, 0.9159663915634155]

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("recall : ", recall)
# Out:
# loss :  0.1163085326552391
# recall :  0.9159663915634155

# %% [raw]
# # If we choose accuracy as a metric;
# loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
# print("loss : ", loss)
# print("accuracy : ", accuracy)

# %%
y_pred = model.predict(X_test) > 0.5
#y_pred = model.predict_classes(X_test) for tf 2.5.0
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 47/47 [==============================] - 0s 858us/step
# [[1119   24]
#  [  30  327]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1143
#            1       0.93      0.92      0.92       357
#
#     accuracy                           0.96      1500
#    macro avg       0.95      0.95      0.95      1500
# weighted avg       0.96      0.96      0.96      1500

# %%
# EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(27, activation = "relu", input_dim = X_train.shape[1]))
model.add(Dense(18, activation = "relu"))
model.add(Dense(9, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["Recall"])

# %%
early_stop = EarlyStopping(monitor = "val_recall", mode = "max", verbose = 1, patience = 25, restore_best_weights = True)

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 100, verbose = 1,
          callbacks = [early_stop])
# Out:
# Epoch 1/100
# 380/380 [==============================] - 2s 2ms/step - loss: 0.4878 - recall: 0.1558 - val_loss: 0.3402 - val_recall: 0.4733
# Epoch 2/100
# 380/380 [==============================] - 0s 1ms/step - loss: 0.2915 - recall: 0.6723 - val_loss: 0.2266 - val_recall: 0.7616
# Epoch 3/100
# 380/380 [==============================] - 0s 1ms/step - loss: 0.2142 - recall: 0.8418 - val_loss: 0.1899 - val_recall: 0.8221
# Epoch 4/100
# 380/380 [==============================] - 1s 1ms/step - loss: 0.1855 - recall: 0.8776 - val_loss: 0.1763 - val_recall: 0.8612
# Epoch 5/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.1735 - recall: 0.8926 - val_loss: 0.1723 - val_recall: 0.8719
# Epoch 6/100
# 380/380 [==============================] - 0s 1ms/step - loss: 0.1673 - recall: 0.8950 - val_loss: 0.1637 - val_recall: 0.8790
# Epoch 7/100
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot();

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("recall : ", recall)
# Out:
# loss :  0.1240282729268074
# recall :  0.9159663915634155

# %% [raw]
# # With lr=0.005, our scores better than before...
# loss :  0.14802241325378418
# recall :  0.9551820755004883

# %%
y_pred = model.predict(X_test) > 0.5
#y_pred = model.predict_classes(X_test) for tf 2.5.0
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 47/47 [==============================] - 0s 841us/step
# [[1106   37]
#  [  26  331]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      1143
#            1       0.90      0.93      0.91       357
#
#     accuracy                           0.96      1500
#    macro avg       0.94      0.95      0.94      1500
# weighted avg       0.96      0.96      0.96      1500

# %%
# Learning Rate
from tensorflow.keras.optimizers import Adam

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(27, activation = "relu", input_dim = X_train.shape[1]))
model.add(Dense(18, activation = "relu"))
model.add(Dense(9, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

opt = Adam(lr = 0.005)
model.compile(optimizer = opt, loss = "binary_crossentropy", metrics = ["Recall"])

# %%
early_stop = EarlyStopping(monitor = "val_recall", mode = "max", verbose = 1, patience = 50, restore_best_weights = True)

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 500, verbose = 1,
          callbacks = [early_stop])
# Out:
# Epoch 1/500
# 380/380 [==============================] - 2s 3ms/step - loss: 0.3730 - recall: 0.4678 - val_loss: 0.2018 - val_recall: 0.8078
# Epoch 2/500
# 380/380 [==============================] - 1s 2ms/step - loss: 0.1918 - recall: 0.8691 - val_loss: 0.1822 - val_recall: 0.8541
# Epoch 3/500
# 380/380 [==============================] - 1s 2ms/step - loss: 0.1643 - recall: 0.8885 - val_loss: 0.1443 - val_recall: 0.8790
# Epoch 4/500
# 380/380 [==============================] - 1s 2ms/step - loss: 0.1547 - recall: 0.8967 - val_loss: 0.1523 - val_recall: 0.8577
# Epoch 5/500
# 380/380 [==============================] - 1s 2ms/step - loss: 0.1468 - recall: 0.8970 - val_loss: 0.1594 - val_recall: 0.8861
# Epoch 6/500
# 380/380 [==============================] - 1s 2ms/step - loss: 0.1405 - recall: 0.8981 - val_loss: 0.1294 - val_recall: 0.8861
# Epoch 7/500
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("recall : ", recall)
# Out:
# loss :  0.10230900347232819
# recall :  0.9523809552192688

# %%
y_pred = model.predict(X_test) > 0.5
#y_pred = model.predict_classes(X_test) for tf 2.5.0
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 47/47 [==============================] - 0s 859us/step
# [[1118   25]
#  [  17  340]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      1143
#            1       0.93      0.95      0.94       357
#
#     accuracy                           0.97      1500
#    macro avg       0.96      0.97      0.96      1500
# weighted avg       0.97      0.97      0.97      1500

# %%
# We know there is no need to use dropout but we want to try...
from tensorflow.keras.layers import Dropout

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(27, activation="relu", input_dim = X_train.shape[1]))
model.add(Dropout(0.5))

model.add(Dense(18, activation="relu"))
model.add(Dropout(0.5))

model.add(Dense(9, activation="relu"))
model.add(Dropout(0.5))

model.add(Dense(1, activation="sigmoid"))

opt = Adam(lr = 0.005)
model.compile(optimizer = opt, loss = "binary_crossentropy", metrics = ["Recall"])

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 380/380 [==============================] - 2s 3ms/step - loss: 0.5475 - recall: 0.0167 - val_loss: 0.4008 - val_recall: 0.0000e+00
# Epoch 2/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.4476 - recall: 0.1418 - val_loss: 0.3054 - val_recall: 0.3488
# Epoch 3/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.3901 - recall: 0.4299 - val_loss: 0.2272 - val_recall: 0.6655
# Epoch 4/100
# 380/380 [==============================] - 0s 1ms/step - loss: 0.3433 - recall: 0.5888 - val_loss: 0.1949 - val_recall: 0.8363
# Epoch 5/100
# 380/380 [==============================] - 1s 1ms/step - loss: 0.3263 - recall: 0.6277 - val_loss: 0.1978 - val_recall: 0.8541
# Epoch 6/100
# 380/380 [==============================] - 1s 2ms/step - loss: 0.3080 - recall: 0.6369 - val_loss: 0.1768 - val_recall: 0.8612
# Epoch 7/100
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("recall : ", recall)
# Out:
# loss :  0.1365298181772232
# recall :  0.9047619104385376

# %%
y_pred = model.predict(X_test) > 0.5
#y_pred = model.predict_classes(X_test) for tf 2.5.0
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 47/47 [==============================] - 0s 734us/step
# [[1123   20]
#  [  34  323]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1143
#            1       0.94      0.90      0.92       357
#
#     accuracy                           0.96      1500
#    macro avg       0.96      0.94      0.95      1500
# weighted avg       0.96      0.96      0.96      1500

# %%
# Cross Validation
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
def build_classifier():
    tf.random.set_seed(seed)
    classifier = Sequential()
    classifier.add(Dense(units = 27, activation = 'relu'))
    classifier.add(Dense(units = 18, activation = 'relu'))
    classifier.add(Dense(units = 9, activation = 'relu'))
    classifier.add(Dense(units = 1, activation = 'sigmoid'))
    classifier.compile(optimizer = "adam", loss = 'binary_crossentropy', metrics = ['Recall'])
    return classifier

# %%
classifier_model = KerasClassifier(build_fn = build_classifier, batch_size = 32, epochs = 100, verbose=0)

scores = cross_validate(estimator = classifier_model, X = X_train, y = y_train,
                        scoring = ['accuracy', 'precision', 'recall', 'f1'], cv = 10)

df_scores = pd.DataFrame(scores, index = range(1, 11)).iloc[:, 2:]

df_scores
# Out:
# ...
# 43/43 [==============================] - 0s 999us/step
#     test_accuracy  test_precision  test_recall  test_f1
# 1           0.961           0.957        0.892    0.923
# 2           0.963           0.943        0.903    0.923
# 3           0.956           0.921        0.892    0.906
# 4           0.957           0.938        0.888    0.912
# 5           0.973           0.960        0.924    0.942
# 6           0.962           0.937        0.905    0.921
# 7           0.970           0.960        0.909    0.934
# 8           0.975           0.959        0.935    0.947
# 9           0.977           0.953        0.944    0.949
# 10          0.966           0.940        0.893    0.916

# %%
df_scores_summary = pd.DataFrame({"score_mean" : df_scores.mean().values, "score_std" : df_scores.std().values},
                                 index = ["acc", "pre", "rec", "f1"])

df_scores_summary
# Out:
#      score_mean  score_std
# acc       0.966      0.007
# pre       0.947      0.013
# rec       0.909      0.020
# f1        0.927      0.015

# %%
# GridSearchCV
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam

# %%
early_stop = EarlyStopping(monitor = "val_recall", mode = "max", verbose = 1, patience = 5, restore_best_weights = True)

# %%
def build_classifier(optimizer, learn_rate):
    tf.random.set_seed(seed)
    classifier = Sequential()
    classifier.add(Dense(units = 27, activation = 'relu'))
    classifier.add(Dense(units = 18, activation = 'relu'))
    classifier.add(Dense(units = 9, activation = 'relu'))
    classifier.add(Dense(units = 1, activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer(learn_rate), loss = 'binary_crossentropy', metrics = ['Recall'])
    return classifier

# %%
# %%time
classifier_model = KerasClassifier(build_fn = build_classifier, validation_split = 0.1, epochs = 200)

parameters = {'batch_size': [32, 64],
              'optimizer': [Adam, RMSprop],
              'learn_rate': [0.001, 0.003, 0.005]}

grid_model = GridSearchCV(estimator = classifier_model,
                          param_grid = parameters,
                          scoring = 'recall',
                          cv = 5,
                          n_jobs = -1,
                          verbose = 1)

grid_model.fit(X_train, y_train, callbacks = [early_stop])
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Epoch 1/200
# 380/380 [==============================] - 2s 2ms/step - loss: 0.4058 - recall: 0.3137 - val_loss: 0.2271 - val_recall: 0.7580
# Epoch 2/200
# 380/380 [==============================] - 1s 1ms/step - loss: 0.2058 - recall: 0.8561 - val_loss: 0.1930 - val_recall: 0.8114
# Epoch 3/200
# 380/380 [==============================] - 0s 1ms/step - loss: 0.1821 - recall: 0.8762 - val_loss: 0.1618 - val_recall: 0.8363
# Epoch 4/200
# 380/380 [==============================] - 1s 2ms/step - loss: 0.1634 - recall: 0.8929 - val_loss: 0.1562 - val_recall: 0.8470
# Epoch 5/200
# 380/380 [==============================] - 0s 1ms/step - loss: 0.1529 - recall: 0.8960 - val_loss: 0.1622 - val_recall: 0.8648
# Epoch 6/200
# 380/380 [==============================] - 1s 1ms/step - loss: 0.1453 - recall: 0.8984 - val_loss: 0.1428 - val_recall: 0.8826
# Epoch 7/200
# ...

# %%
grid_model.best_params_
# Out:
# {'batch_size': 32,
#  'learn_rate': 0.003,
#  'optimizer': keras.optimizers.optimizer_v2.adam.Adam}

# %%
y_pred = grid_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 47/47 [==============================] - 0s 1ms/step
# [[1123   20]
#  [  32  325]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1143
#            1       0.94      0.91      0.93       357
#
#     accuracy                           0.97      1500
#    macro avg       0.96      0.95      0.95      1500
# weighted avg       0.97      0.97      0.97      1500

# %% [markdown]
# #### Evaluating Model Performance

# %%
# We wil choose best ANN model and Evaluate it's performance...
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(27, activation = "relu", input_dim = X_train.shape[1]))
model.add(Dense(18, activation = "relu"))
model.add(Dense(9, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

opt = Adam(lr = 0.003)
model.compile(optimizer = opt, loss = "binary_crossentropy", metrics = ["Recall"])

# %%
early_stop = EarlyStopping(monitor = "val_recall", mode = "max", verbose = 1, patience = 15, restore_best_weights = True)

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 500, verbose = 1,
          callbacks = [early_stop])
# Out:
# Epoch 1/500
# 380/380 [==============================] - 3s 2ms/step - loss: 0.3507 - recall: 0.5196 - val_loss: 0.2083 - val_recall: 0.7758
# Epoch 2/500
# 380/380 [==============================] - 1s 1ms/step - loss: 0.1951 - recall: 0.8609 - val_loss: 0.1966 - val_recall: 0.7544
# Epoch 3/500
# 380/380 [==============================] - 1s 1ms/step - loss: 0.1696 - recall: 0.8793 - val_loss: 0.1534 - val_recall: 0.8363
# Epoch 4/500
# 380/380 [==============================] - 1s 1ms/step - loss: 0.1538 - recall: 0.8912 - val_loss: 0.1437 - val_recall: 0.8683
# Epoch 5/500
# 380/380 [==============================] - 0s 1ms/step - loss: 0.1434 - recall: 0.8957 - val_loss: 0.1704 - val_recall: 0.9039
# Epoch 6/500
# 380/380 [==============================] - 0s 1ms/step - loss: 0.1350 - recall: 0.8974 - val_loss: 0.1347 - val_recall: 0.8861
# Epoch 7/500
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = model.predict(X_test) > 0.5
#y_pred = model.predict_classes(X_test) for tf 2.5.0
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 47/47 [==============================] - 0s 1ms/step
# [[1097   46]
#  [  25  332]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      1143
#            1       0.88      0.93      0.90       357
#
#     accuracy                           0.95      1500
#    macro avg       0.93      0.94      0.94      1500
# weighted avg       0.95      0.95      0.95      1500

# %%
ann_f1 = 0.90
ann_recall = 0.91
ann_auc = 0.955

# %% [markdown]
# #### Prediction

# %%
from tensorflow.keras.models import load_model

# %%
X = df.drop('left', axis = 1)
y = df['left']

# %%
observations = {"satisfaction": [0.6, 0.1], "last_eval":[0.7, 0.8], "num_of_projects":[4, 7],
               "avg_monthly_hours":[180, 300], "experience":[3, 4], "work_accident":[0, 0],
                "promotion":[1, 0], "department":["sales", "marketing"], "salary":["low", "medium"]}

obs = pd.DataFrame(observations)
obs
# Out:
#    satisfaction  last_eval  num_of_projects  avg_monthly_hours  experience  \
# 0         0.600      0.700                4                180           3
# 1         0.100      0.800                7                300           4
#
#    work_accident  promotion department  salary
# 0              0          1      sales     low
# 1              0          0  marketing  medium

# %%
X.head(1)
# Out:
#    satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0         0.380            0.530               2                   157
#
#    experience  work_accident  promotion_last_5years department salary
# 0           3              0                      0      sales    low

# %%
column_trans = make_column_transformer(
    (OneHotEncoder(handle_unknown="ignore", sparse=False), ["department"]),
    (OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ["salary"]), 
    remainder=MinMaxScaler()
)
X = pd.DataFrame(data=column_trans.fit_transform(X), columns=column_trans.get_feature_names_out())

obs = pd.DataFrame(data=column_trans.transform(obs), columns=column_trans.get_feature_names_out())

# %%
(model.predict(obs) > 0.5).astype("int32")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [352], in <cell line: 1>()
# ----> 1 (model.predict(obs) > 0.5).astype("int32")
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ...

# %% [markdown]
# # Comparing Models

# %%
compare = pd.DataFrame({"Model": ["Logistic Regression", "KNN", "Random Forest", "XGBoost", "ANN"],
                        "F1": [log_f1, knn_f1, RF_tuned_f1, xgb_f1, ann_f1],
                        "Recall": [log_recall, knn_recall, RF_tuned_recall, xgb_recall, ann_recall],
                        "ROC_AUC": [log_auc, knn_auc, RF_tuned_auc, xgb_auc, ann_auc]})

def labels(ax):
    ax.bar_label(ax.containers[0],fmt="%.3f")
    
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="ROC_AUC", ascending=False)
ax=sns.barplot(x="ROC_AUC", y="Model", data=compare, palette="Blues_d")
labels(ax)
plt.show()

# %% [markdown]
# ## 6. Model Deployement
#
# You cooked the food in the kitchen and moved on to the serving stage. The question is how do you showcase your work to others? Model Deployement helps you showcase your work to the world and make better decisions with it. But, deploying a model can get a little tricky at times. Before deploying the model, many things such as data storage, preprocessing, model building and monitoring need to be studied. Streamlit is a popular open source framework used by data scientists for model distribution.
#
# Deployment of machine learning models, means making your models available to your other business systems. By deploying models, other systems can send data to them and get their predictions, which are in turn populated back into the company systems. Through machine learning model deployment, can begin to take full advantage of the model you built.
#
# Data science is concerned with how to build machine learning models, which algorithm is more predictive, how to design features, and what variables to use to make the models more accurate. However, how these models are actually used is often neglected. And yet this is the most important step in the machine learning pipline. Only when a model is fully integrated with the business systems, real values ​​can be extract from its predictions.
#
# After doing the following operations in this notebook, jump to new .py file and create your web app with Streamlit.

# %% [markdown]
# ### Save and Export the Model

# %%
from xgboost import XGBClassifier

# %%
X = df.drop('left', axis = 1)
y = df['left']

# %%
cat = X.select_dtypes("string").columns
cat
# Out:
# Index(['department', 'salary'], dtype='object')

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1) 

column_trans = make_column_transformer((ord_enc, cat), remainder=MinMaxScaler())
operations = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101,
                                                                            colsample_bytree = 1,
                                                                            subsample= 1,
                                                                            learning_rate= 0.2,
                                                                            max_depth= 25,
                                                                            n_estimators= 110                                                                                                                                                                                                                           
                                                                           ))]


xgb_model = Pipeline(steps=operations)
xgb_model.fit(X, y)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['department', 'salary'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(learning_rate=0.2, max_depth=25,
#                                n_estimators=110, random_state=101))])

# %%
# import joblib
# joblib.dump(xgb_model, open('xgb_model_final.pkl', 'wb'))

import pickle
pickle.dump(xgb_model, open("xgb_model_final", 'wb'))

# %% [markdown]
# ### Save and Export Variables

# %%
# final_model = joblib.load(open('xgb_model_final.pkl', 'rb'))
final_model = pickle.load(open("xgb_model_final", "rb"))

# %%
sample = pd.DataFrame({
        'satisfaction': 0.38,
        'last_evaluation': 0.53,
        'number_project': 2,
        'average_montly_hours': 157,
        'experience': 3,
        'work_accident': 0,
        'promotion_last_5years': 0,
        'department': 'sales',
        'salary': 'low'
}, index=[0])

sample
# Out:
#    satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0         0.380            0.530               2                   157
#
#    experience  work_accident  promotion_last_5years department salary
# 0           3              0                      0      sales    low

# %%
final_model.predict(sample)
# Out:
# array([1])

# %%
df["department"].unique()
# Out:
# <StringArray>
# [      'sales',  'accounting',          'hr',   'technical',     'support',
#   'management',          'IT', 'product_mng',   'marketing',       'RandD']
# Length: 10, dtype: string

# %%
df["salary"].unique()
# Out:
# <StringArray>
# ['low', 'medium', 'high']
# Length: 3, dtype: string

# %%
df.head()
# Out:
#    satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0         0.380            0.530               2                   157
# 1         0.800            0.860               5                   262
# 2         0.110            0.880               7                   272
# 3         0.720            0.870               5                   223
# 4         0.370            0.520               2                   159
#
#    experience  work_accident  promotion_last_5years department  left  salary
# 0           3              0                      0      sales     1     low
# 1           6              0                      0      sales     1  medium
# 2           4              0                      0      sales     1  medium
# 3           5              0                      0      sales     1     low
# 4           3              0                      0      sales     1     low

# %%
df.columns
# Out:
# Index(['satisfaction', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'experience', 'work_accident',
#        'promotion_last_5years', 'department', 'left', 'salary'],
#       dtype='object')

# %%
observations = {"satisfaction": [0.6, 0.1], "last_evaluation":[0.7, 0.8], "number_project":[4, 7],
               "average_montly_hours":[180, 300], "experience":[3, 4], "work_accident":[0, 0],
                "promotion_last_5years":[1, 0], "department":["sales", "marketing"], "salary":["low", "medium"]}

obs = pd.DataFrame(observations)
obs
# Out:
#    satisfaction  last_evaluation  number_project  average_montly_hours  \
# 0         0.600            0.700               4                   180
# 1         0.100            0.800               7                   300
#
#    experience  work_accident  promotion_last_5years department  salary
# 0           3              0                      1      sales     low
# 1           4              0                      0  marketing  medium

# %%
final_model.predict(obs)
# Out:
# array([0, 1])

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
