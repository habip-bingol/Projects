# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import cufflinks as cf

#Enabling the offline mode for interactive plotting locally
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
import plotly.io as pio
pio.renderers.default = "notebook"



#%matplotlib inline
#%matplotlib notebook
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_columns', 110)
pd.set_option('display.max_rows', 110)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df_male = pd.read_csv("ANSUR II MALE Public.csv", encoding="'ISO-8859-1" )
df_male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# 2                        408               261               544
# 3                        359               262               518
# 4                        356               263               524
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  71               319                        291
# 1                  67               344                        320
# 2                  75               345                        330
# 3                  73               328                        309
# 4                  80               340                        310
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 142                   979           240            882
# 1                 135                   944           232            870
# 2                 135                  1054           258            901
# 3                 143                   991           242            821
# 4                 138                  1029           275           1080
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                619                     509                373
# 1                584                     468                357
# 2                623                     506                412
# 3                560                     437                395
# 4                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1535           291                1074         259         1292
# 1             1471           269                1021         253         1244
# 2             1501           288                1120         267         1288
# 3             1423           296                1114         262         1205
# 4             1684           304                1048         232         1452
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           877                    607                             351
# 1           851                    615                             376
# 2           854                    636                             359
# 3           769                    590                             341
# 4          1014                    682                             382
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          36         71             19              247               802
# 1          33         62             18              232               781
# 2          40         61             23              237               810
# 3          39         66             25              272               794
# 4          32         56             19              188               814
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                    101         273                        349
# 1                     98         263                        348
# 2                    103         270                        355
# 3                    106         267                        352
# 4                    111         305                        399
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         299                    575                477
# 1                         289                    523                476
# 2                         357                    575                491
# 3                         318                    593                467
# 4                         324                    605                550
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1136           90                214         193
# 1                 1096           86                203         195
# 2                 1115           93                220         203
# 3                 1034           91                217         194
# 4                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          150                583         206                     326
# 1          146                568         201                     334
# 2          148                573         202                     356
# 3          158                576         199                     341
# 4          153                566         197                     374
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           70         332                366                1071
# 1           72         312                356                1046
# 2           70         349                393                1053
# 3           68         338                367                 986
# 4           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    685         422          441                   502
# 1                    620         441          447                   490
# 2                    665         462          475                   496
# 3                    640         458          461                   460
# 4                    675         481          505                   612
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                560                             500                      77
# 1                540                             488                      73
# 2                556                             482                      72
# 3                511                             452                      76
# 4                666                             585                      85
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      391                  118                400
# 1                      371                  131                380
# 2                      409                  123                403
# 3                      393                  106                407
# 4                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    436                           1447         113
# 1                    420                           1380         118
# 2                    434                           1447         121
# 3                    446                           1357         118
# 4                    430                           1572         132
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              437                   273                   1151
# 1              417                   254                   1119
# 2              431                   268                   1276
# 3              393                   249                   1155
# 4              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight Gender       Date Installation  \
# 0                 175          853   Male   4-Oct-10    Fort Hood
# 1                 167          815   Male   4-Oct-10    Fort Hood
# 2                 180          831   Male   4-Oct-10    Fort Hood
# 3                 176          793   Male  12-Oct-10    Fort Hood
# 4                 188          954   Male  12-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#    SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   1       NaN        1   41        71        180
# 1                   1       NaN        1   35        68        160
# 2                   2       NaN        2   42        68        205
# 3                   1       NaN        1   31        66        175
# 4                   2       NaN        2   21        77        213
#
#   WritingPreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand

# %%
df_female = pd.read_csv("ANSUR II FEMALE Public.csv", encoding="'ISO-8859-1" )
df_female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        315               263               466
# 1                        272               250               430
# 2                        300               276               450
# 3                        364               276               484
# 4                        320               336               525
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  65               338                        301
# 1                  64               294                        270
# 2                  69               309                        270
# 3                  68               340                        294
# 4                  67               300                        295
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 141                  1011           223            836
# 1                 126                   893           186            900
# 2                 128                   987           204            861
# 3                 144                  1012           253            897
# 4                 135                  1281           284            811
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                587                     476                360
# 1                583                     483                350
# 2                583                     466                384
# 3                599                     471                372
# 4                607                     467                433
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1336           274                 922         245         1095
# 1             1440           261                 839         206         1234
# 2             1451           287                 874         223         1226
# 3             1430           269                1008         285         1170
# 4             1362           305                1089         290         1112
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           759                    557                             310
# 1           835                    549                             329
# 2           821                    643                             374
# 3           804                    640                             351
# 4           726                    686                             356
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          35         65             16              220               713
# 1          32         60             23              208               726
# 2          36         65             26              204               790
# 3          38         62             22              244               775
# 4          34         65             18              233               732
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                     91         246                        316
# 1                     91         249                        341
# 2                    100         265                        343
# 3                     97         265                        331
# 4                     88         247                        339
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         265                    517                432
# 1                         247                    468                463
# 2                         262                    488                469
# 3                         309                    529                455
# 4                         260                    596                447
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1028           75                182         184
# 1                 1117           78                187         189
# 2                 1060           84                198         195
# 3                 1069           80                192         186
# 4                 1039           78                183         187
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          141                548         191                     314
# 1          138                535         180                     307
# 2          146                588         207                     331
# 3          153                593         206                     332
# 4          140                522         181                     308
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           69         345                388                 966
# 1           60         315                335                1048
# 2           70         356                399                1043
# 3           68         337                402                1029
# 4           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    645         363          399                   435
# 1                    595         340          375                   483
# 2                    655         345          399                   470
# 3                    655         392          435                   469
# 4                    635         428          435                   440
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                496                             447                      55
# 1                532                             492                      69
# 2                530                             469                      64
# 3                520                             478                      67
# 4                491                             441                      63
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      404                  118                335
# 1                      334                  115                302
# 2                      401                  135                325
# 3                      402                  118                357
# 4                      479                  114                340
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    368                           1268         113
# 1                    345                           1389         110
# 2                    369                           1414         122
# 3                    386                           1329         115
# 4                    358                           1350         116
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              362                   235                   1062
# 1              426                   259                   1014
# 2              398                   258                   1049
# 3              394                   250                   1121
# 4              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender      Date Installation  \
# 0                 152          756  Female  5-Oct-10    Fort Hood
# 1                 155          815  Female  5-Oct-10    Fort Hood
# 2                 162          799  Female  5-Oct-10    Fort Hood
# 3                 173          818  Female  5-Oct-10    Fort Hood
# 4                 152          762  Female  5-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army          Combat Support        92Y               Germany
# 1  Regular Army  Combat Service Support        25U            California
# 2  Regular Army  Combat Service Support        35D                 Texas
# 3  Regular Army  Combat Service Support        25U  District of Columbia
# 4  Regular Army             Combat Arms        42A                 Texas
#
#    SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   2                 NaN        2   26        61        142
# 1                   3             Mexican        3   21        64        120
# 2                   1                 NaN        1   23        68        147
# 3                   8  Caribbean Islander        2   22        66        175
# 4                   1                 NaN        1   45        63        195
#
#   WritingPreference
# 0        Right hand
# 1        Right hand
# 2        Right hand
# 3        Right hand
# 4        Right hand

# %% [markdown]
# ## Explore Data

# %%
#  SubjectNumericRace and DODRace features can be the same ??

# %%
df_male.shape
# Out:
# (4082, 108)

# %%
df_female.shape
# Out:
# (1986, 108)

# %%
df_male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# 2                        408               261               544
# 3                        359               262               518
# 4                        356               263               524
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  71               319                        291
# 1                  67               344                        320
# 2                  75               345                        330
# 3                  73               328                        309
# 4                  80               340                        310
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 142                   979           240            882
# 1                 135                   944           232            870
# 2                 135                  1054           258            901
# 3                 143                   991           242            821
# 4                 138                  1029           275           1080
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                619                     509                373
# 1                584                     468                357
# 2                623                     506                412
# 3                560                     437                395
# 4                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1535           291                1074         259         1292
# 1             1471           269                1021         253         1244
# 2             1501           288                1120         267         1288
# 3             1423           296                1114         262         1205
# 4             1684           304                1048         232         1452
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           877                    607                             351
# 1           851                    615                             376
# 2           854                    636                             359
# 3           769                    590                             341
# 4          1014                    682                             382
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          36         71             19              247               802
# 1          33         62             18              232               781
# 2          40         61             23              237               810
# 3          39         66             25              272               794
# 4          32         56             19              188               814
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                    101         273                        349
# 1                     98         263                        348
# 2                    103         270                        355
# 3                    106         267                        352
# 4                    111         305                        399
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         299                    575                477
# 1                         289                    523                476
# 2                         357                    575                491
# 3                         318                    593                467
# 4                         324                    605                550
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1136           90                214         193
# 1                 1096           86                203         195
# 2                 1115           93                220         203
# 3                 1034           91                217         194
# 4                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          150                583         206                     326
# 1          146                568         201                     334
# 2          148                573         202                     356
# 3          158                576         199                     341
# 4          153                566         197                     374
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           70         332                366                1071
# 1           72         312                356                1046
# 2           70         349                393                1053
# 3           68         338                367                 986
# 4           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    685         422          441                   502
# 1                    620         441          447                   490
# 2                    665         462          475                   496
# 3                    640         458          461                   460
# 4                    675         481          505                   612
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                560                             500                      77
# 1                540                             488                      73
# 2                556                             482                      72
# 3                511                             452                      76
# 4                666                             585                      85
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      391                  118                400
# 1                      371                  131                380
# 2                      409                  123                403
# 3                      393                  106                407
# 4                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    436                           1447         113
# 1                    420                           1380         118
# 2                    434                           1447         121
# 3                    446                           1357         118
# 4                    430                           1572         132
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              437                   273                   1151
# 1              417                   254                   1119
# 2              431                   268                   1276
# 3              393                   249                   1155
# 4              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight Gender       Date Installation  \
# 0                 175          853   Male   4-Oct-10    Fort Hood
# 1                 167          815   Male   4-Oct-10    Fort Hood
# 2                 180          831   Male   4-Oct-10    Fort Hood
# 3                 176          793   Male  12-Oct-10    Fort Hood
# 4                 188          954   Male  12-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#    SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   1       NaN        1   41        71        180
# 1                   1       NaN        1   35        68        160
# 2                   2       NaN        2   42        68        205
# 3                   1       NaN        1   31        66        175
# 4                   2       NaN        2   21        77        213
#
#   WritingPreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand

# %%
df_female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        315               263               466
# 1                        272               250               430
# 2                        300               276               450
# 3                        364               276               484
# 4                        320               336               525
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  65               338                        301
# 1                  64               294                        270
# 2                  69               309                        270
# 3                  68               340                        294
# 4                  67               300                        295
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 141                  1011           223            836
# 1                 126                   893           186            900
# 2                 128                   987           204            861
# 3                 144                  1012           253            897
# 4                 135                  1281           284            811
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                587                     476                360
# 1                583                     483                350
# 2                583                     466                384
# 3                599                     471                372
# 4                607                     467                433
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1336           274                 922         245         1095
# 1             1440           261                 839         206         1234
# 2             1451           287                 874         223         1226
# 3             1430           269                1008         285         1170
# 4             1362           305                1089         290         1112
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           759                    557                             310
# 1           835                    549                             329
# 2           821                    643                             374
# 3           804                    640                             351
# 4           726                    686                             356
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          35         65             16              220               713
# 1          32         60             23              208               726
# 2          36         65             26              204               790
# 3          38         62             22              244               775
# 4          34         65             18              233               732
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                     91         246                        316
# 1                     91         249                        341
# 2                    100         265                        343
# 3                     97         265                        331
# 4                     88         247                        339
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         265                    517                432
# 1                         247                    468                463
# 2                         262                    488                469
# 3                         309                    529                455
# 4                         260                    596                447
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1028           75                182         184
# 1                 1117           78                187         189
# 2                 1060           84                198         195
# 3                 1069           80                192         186
# 4                 1039           78                183         187
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          141                548         191                     314
# 1          138                535         180                     307
# 2          146                588         207                     331
# 3          153                593         206                     332
# 4          140                522         181                     308
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           69         345                388                 966
# 1           60         315                335                1048
# 2           70         356                399                1043
# 3           68         337                402                1029
# 4           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    645         363          399                   435
# 1                    595         340          375                   483
# 2                    655         345          399                   470
# 3                    655         392          435                   469
# 4                    635         428          435                   440
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                496                             447                      55
# 1                532                             492                      69
# 2                530                             469                      64
# 3                520                             478                      67
# 4                491                             441                      63
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      404                  118                335
# 1                      334                  115                302
# 2                      401                  135                325
# 3                      402                  118                357
# 4                      479                  114                340
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    368                           1268         113
# 1                    345                           1389         110
# 2                    369                           1414         122
# 3                    386                           1329         115
# 4                    358                           1350         116
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              362                   235                   1062
# 1              426                   259                   1014
# 2              398                   258                   1049
# 3              394                   250                   1121
# 4              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender      Date Installation  \
# 0                 152          756  Female  5-Oct-10    Fort Hood
# 1                 155          815  Female  5-Oct-10    Fort Hood
# 2                 162          799  Female  5-Oct-10    Fort Hood
# 3                 173          818  Female  5-Oct-10    Fort Hood
# 4                 152          762  Female  5-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army          Combat Support        92Y               Germany
# 1  Regular Army  Combat Service Support        25U            California
# 2  Regular Army  Combat Service Support        35D                 Texas
# 3  Regular Army  Combat Service Support        25U  District of Columbia
# 4  Regular Army             Combat Arms        42A                 Texas
#
#    SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   2                 NaN        2   26        61        142
# 1                   3             Mexican        3   21        64        120
# 2                   1                 NaN        1   23        68        147
# 3                   8  Caribbean Islander        2   22        66        175
# 4                   1                 NaN        1   45        63        195
#
#   WritingPreference
# 0        Right hand
# 1        Right hand
# 2        Right hand
# 3        Right hand
# 4        Right hand

# %%
columns = pd.DataFrame({"df_male_columns": df_male.columns,
              "df_female_columns" : df_female.columns})
columns
# Out:
#                     df_male_columns               df_female_columns
# 0                         subjectid                       SubjectId
# 1    abdominalextensiondepthsitting  abdominalextensiondepthsitting
# 2                    acromialheight                  acromialheight
# 3             acromionradialelength           acromionradialelength
# 4                anklecircumference              anklecircumference
# 5                      axillaheight                    axillaheight
# 6           balloffootcircumference         balloffootcircumference
# 7                  balloffootlength                balloffootlength
# 8                 biacromialbreadth               biacromialbreadth
# 9         bicepscircumferenceflexed       bicepscircumferenceflexed
# 10                 bicristalbreadth                bicristalbreadth
# 11                 bideltoidbreadth                bideltoidbreadth
# 12               bimalleolarbreadth              bimalleolarbreadth
# 13                 bitragionchinarc                bitragionchinarc
# 14        bitragionsubmandibulararc       bitragionsubmandibulararc
# 15               bizygomaticbreadth              bizygomaticbreadth
# 16             buttockcircumference            buttockcircumference
# 17                     buttockdepth                    buttockdepth
# 18                    buttockheight                   buttockheight
# 19                buttockkneelength               buttockkneelength
# 20           buttockpopliteallength          buttockpopliteallength
# 21                calfcircumference               calfcircumference
# 22                  cervicaleheight                 cervicaleheight
# 23                     chestbreadth                    chestbreadth
# 24               chestcircumference              chestcircumference
# 25                       chestdepth                      chestdepth
# 26                      chestheight                     chestheight
# 27                     crotchheight                    crotchheight
# 28            crotchlengthomphalion           crotchlengthomphalion
# 29   crotchlengthposterioromphalion  crotchlengthposterioromphalion
# 30                       earbreadth                      earbreadth
# 31                        earlength                       earlength
# 32                    earprotrusion                   earprotrusion
# 33                  elbowrestheight                 elbowrestheight
# 34                 eyeheightsitting                eyeheightsitting
# 35            footbreadthhorizontal           footbreadthhorizontal
# 36                       footlength                      footlength
# 37        forearmcenterofgriplength       forearmcenterofgriplength
# 38       forearmcircumferenceflexed      forearmcircumferenceflexed
# 39            forearmforearmbreadth           forearmforearmbreadth
# 40                forearmhandlength               forearmhandlength
# 41              functionalleglength             functionalleglength
# 42                      handbreadth                     handbreadth
# 43                handcircumference               handcircumference
# 44                       handlength                      handlength
# 45                      headbreadth                     headbreadth
# 46                headcircumference               headcircumference
# 47                       headlength                      headlength
# 48           heelanklecircumference          heelanklecircumference
# 49                      heelbreadth                     heelbreadth
# 50                       hipbreadth                      hipbreadth
# 51                hipbreadthsitting               hipbreadthsitting
# 52               iliocristaleheight              iliocristaleheight
# 53            interpupillarybreadth           interpupillarybreadth
# 54                       interscyei                      interscyei
# 55                      interscyeii                     interscyeii
# 56             kneeheightmidpatella            kneeheightmidpatella
# 57                kneeheightsitting               kneeheightsitting
# 58   lateralfemoralepicondyleheight  lateralfemoralepicondyleheight
# 59           lateralmalleolusheight          lateralmalleolusheight
# 60          lowerthighcircumference         lowerthighcircumference
# 61              mentonsellionlength             mentonsellionlength
# 62                neckcircumference               neckcircumference
# 63            neckcircumferencebase           neckcircumferencebase
# 64    overheadfingertipreachsitting   overheadfingertipreachsitting
# 65                       palmlength                      palmlength
# 66                  poplitealheight                 poplitealheight
# 67             radialestylionlength            radialestylionlength
# 68            shouldercircumference           shouldercircumference
# 69              shoulderelbowlength             shoulderelbowlength
# 70                   shoulderlength                  shoulderlength
# 71                    sittingheight                   sittingheight
# 72           sleevelengthspinewrist          sleevelengthspinewrist
# 73                    sleeveoutseam                   sleeveoutseam
# 74                             span                            span
# 75                          stature                         stature
# 76              suprasternaleheight             suprasternaleheight
# 77                   tenthribheight                  tenthribheight
# 78               thighcircumference              thighcircumference
# 79                   thighclearance                  thighclearance
# 80                    thumbtipreach                   thumbtipreach
# 81                     tibialheight                    tibialheight
# 82                 tragiontopofhead                tragiontopofhead
# 83              trochanterionheight             trochanterionheight
# 84    verticaltrunkcircumferenceusa   verticaltrunkcircumferenceusa
# 85                  waistbacklength                 waistbacklength
# 86                     waistbreadth                    waistbreadth
# 87               waistcircumference              waistcircumference
# 88                       waistdepth                      waistdepth
# 89          waistfrontlengthsitting         waistfrontlengthsitting
# 90             waistheightomphalion            waistheightomphalion
# 91                         weightkg                        weightkg
# 92               wristcircumference              wristcircumference
# 93                      wristheight                     wristheight
# 94                           Gender                          Gender
# 95                             Date                            Date
# 96                     Installation                    Installation
# 97                        Component                       Component
# 98                           Branch                          Branch
# 99                       PrimaryMOS                      PrimaryMOS
# 100           SubjectsBirthLocation           SubjectsBirthLocation
# 101              SubjectNumericRace              SubjectNumericRace
# 102                       Ethnicity                       Ethnicity
# 103                         DODRace                         DODRace
# 104                             Age                             Age
# 105                        Heightin                        Heightin
# 106                       Weightlbs                       Weightlbs
# 107               WritingPreference               WritingPreference

# %%
df_male.rename(columns={"subjectid":"SubjectId"}, inplace=True)

# %%
df = pd.concat([df_male, df_female], ignore_index=True)
df
# Out:
#       SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0         10027                             266            1467
# 1         10032                             233            1395
# 2         10033                             287            1430
# 3         10092                             234            1347
# 4         10093                             250            1585
# ...         ...                             ...             ...
# 6063      29501                             285            1392
# 6064      29502                             262            1324
# 6065      29503                             260            1334
# 6066      29511                             205            1293
# 6067     920103                             238            1346
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 0                       337                 222          1347
# 1                       326                 220          1293
# 2                       341                 230          1327
# 3                       310                 230          1239
# 4                       372                 247          1478
# ...                     ...                 ...           ...
# 6063                    335                 223          1297
# 6064                    301                 202          1204
# 6065                    318                 213          1259
# 6066                    302                 199          1207
# 6067                    308                 210          1256
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                         253               202                401
# 1                         245               193                394
# 2                         256               196                427
# 3                         262               199                401
# 4                         267               224                435
# ...                       ...               ...                ...
# 6063                      252               196                368
# 6064                      236               181                378
# 6065                      234               183                363
# 6066                      213               163                376
# 6067                      236               188                361
#
#       bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                           369               274               493
# 1                           338               257               479
# 2                           408               261               544
# 3                           359               262               518
# 4                           356               263               524
# ...                         ...               ...               ...
# 6063                        299               312               477
# 6064                        294               287               468
# 6065                        332               299               460
# 6066                        276               280               426
# 6067                        285               279               433
#
#       bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                     71               319                        291
# 1                     67               344                        320
# 2                     75               345                        330
# 3                     73               328                        309
# 4                     80               340                        310
# ...                  ...               ...                        ...
# 6063                  72               306                        282
# 6064                  66               309                        311
# 6065                  70               317                        311
# 6066                  62               282                        267
# 6067                  71               304                        278
#
#       bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                    142                   979           240            882
# 1                    135                   944           232            870
# 2                    135                  1054           258            901
# 3                    143                   991           242            821
# 4                    138                  1029           275           1080
# ...                  ...                   ...           ...            ...
# 6063                 136                  1089           255            856
# 6064                 145                  1016           246            818
# 6065                 139                  1063           262            846
# 6066                 137                  1051           225            786
# 6067                 129                   974           217            820
#
#       buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                   619                     509                373
# 1                   584                     468                357
# 2                   623                     506                412
# 3                   560                     437                395
# 4                   706                     567                425
# ...                 ...                     ...                ...
# 6063                652                     541                373
# 6064                572                     464                375
# 6065                637                     525                370
# 6066                582                     480                370
# 6067                586                     479                343
#
#       cervicaleheight  chestbreadth  chestcircumference  chestdepth  \
# 0                1535           291                1074         259
# 1                1471           269                1021         253
# 2                1501           288                1120         267
# 3                1423           296                1114         262
# 4                1684           304                1048         232
# ...               ...           ...                 ...         ...
# 6063             1457           290                1082         293
# 6064             1390           291                1016         269
# 6065             1412           285                1093         286
# 6066             1377           270                 922         243
# 6067             1401           272                 902         219
#
#       chestheight  crotchheight  crotchlengthomphalion  \
# 0            1292           877                    607
# 1            1244           851                    615
# 2            1288           854                    636
# 3            1205           769                    590
# 4            1452          1014                    682
# ...           ...           ...                    ...
# 6063         1258           779                    732
# 6064         1151           732                    647
# 6065         1166           793                    609
# 6066         1137           763                    575
# 6067         1186           783                    536
#
#       crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                                351          36         71             19
# 1                                376          33         62             18
# 2                                359          40         61             23
# 3                                341          39         66             25
# 4                                382          32         56             19
# ...                              ...         ...        ...            ...
# 6063                             382          36         60             19
# 6064                             331          36         65             23
# 6065                             326          39         62             18
# 6066                             310          35         62             21
# 6067                             307          35         58             23
#
#       elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0                 247               802                    101         273
# 1                 232               781                     98         263
# 2                 237               810                    103         270
# 3                 272               794                    106         267
# 4                 188               814                    111         305
# ...               ...               ...                    ...         ...
# 6063              210               746                    103         259
# 6064              274               770                    101         245
# 6065              204               739                     97         249
# 6066              222               738                     91         226
# 6067              243               754                    100         239
#
#       forearmcenterofgriplength  forearmcircumferenceflexed  \
# 0                           349                         299
# 1                           348                         289
# 2                           355                         357
# 3                           352                         318
# 4                           399                         324
# ...                         ...                         ...
# 6063                        328                         262
# 6064                        319                         261
# 6065                        338                         288
# 6066                        306                         258
# 6067                        314                         259
#
#       forearmforearmbreadth  forearmhandlength  functionalleglength  \
# 0                       575                477                 1136
# 1                       523                476                 1096
# 2                       575                491                 1115
# 3                       593                467                 1034
# 4                       605                550                 1279
# ...                     ...                ...                  ...
# 6063                    514                456                 1085
# 6064                    514                440                  985
# 6065                    530                459                 1050
# 6066                    430                425                  995
# 6067                    464                439                 1053
#
#       handbreadth  handcircumference  handlength  headbreadth  \
# 0              90                214         193          150
# 1              86                203         195          146
# 2              93                220         203          148
# 3              91                217         194          158
# 4              94                222         218          153
# ...           ...                ...         ...          ...
# 6063           81                197         193          151
# 6064           81                196         183          160
# 6065           82                192         191          144
# 6066           74                177         176          149
# 6067           78                187         177          148
#
#       headcircumference  headlength  heelanklecircumference  heelbreadth  \
# 0                   583         206                     326           70
# 1                   568         201                     334           72
# 2                   573         202                     356           70
# 3                   576         199                     341           68
# 4                   566         197                     374           69
# ...                 ...         ...                     ...          ...
# 6063                582         205                     321           75
# 6064                570         186                     296           61
# 6065                559         190                     318           72
# 6066                558         186                     280           59
# 6067                561         189                     310           78
#
#       hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0            332                366                1071
# 1            312                356                1046
# 2            349                393                1053
# 3            338                367                 986
# 4            332                372                1251
# ...          ...                ...                 ...
# 6063         381                413                1048
# 6064         347                377                 974
# 6065         364                400                 986
# 6066         369                411                 971
# 6067         332                376                 994
#
#       interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                       685         422          441                   502
# 1                       620         441          447                   490
# 2                       665         462          475                   496
# 3                       640         458          461                   460
# 4                       675         481          505                   612
# ...                     ...         ...          ...                   ...
# 6063                    615         373          390                   462
# 6064                    650         400          411                   433
# 6065                    640         400          412                   450
# 6066                    640         383          418                   432
# 6067                    595         333          373                   444
#
#       kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   560                             500
# 1                   540                             488
# 2                   556                             482
# 3                   511                             452
# 4                   666                             585
# ...                 ...                             ...
# 6063                535                             486
# 6064                483                             457
# 6065                517                             476
# 6066                491                             445
# 6067                504                             445
#
#       lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                         77                      391                  118
# 1                         73                      371                  131
# 2                         72                      409                  123
# 3                         76                      393                  106
# 4                         85                      458                  135
# ...                      ...                      ...                  ...
# 6063                      61                      423                  121
# 6064                      58                      383                  130
# 6065                      57                      412                  111
# 6066                      58                      400                  119
# 6067                      66                      372                  114
#
#       neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                   400                    436                           1447
# 1                   380                    420                           1380
# 2                   403                    434                           1447
# 3                   407                    446                           1357
# 4                   398                    430                           1572
# ...                 ...                    ...                            ...
# 6063                369                    391                           1307
# 6064                359                    399                           1323
# 6065                352                    402                           1318
# 6066                326                    380                           1286
# 6067                325                    381                           1372
#
#       palmlength  poplitealheight  radialestylionlength  \
# 0            113              437                   273
# 1            118              417                   254
# 2            121              431                   268
# 3            118              393                   249
# 4            132              523                   302
# ...          ...              ...                   ...
# 6063         118              414                   237
# 6064          99              377                   237
# 6065         116              392                   259
# 6066         111              375                   230
# 6067         112              390                   249
#
#       shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                      1151                  368             145
# 1                      1119                  353             141
# 2                      1276                  367             167
# 3                      1155                  330             148
# 4                      1231                  400             180
# ...                     ...                  ...             ...
# 6063                   1036                  354             145
# 6064                   1051                  318             142
# 6065                   1054                  338             136
# 6066                    996                  321             136
# 6067                    997                  339             135
#
#       sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  \
# 0               928                     883            600  1782     1776
# 1               884                     868            564  1745     1702
# 2               917                     910            604  1867     1735
# 3               903                     848            550  1708     1655
# 4               919                     995            641  2035     1914
# ...             ...                     ...            ...   ...      ...
# 6063            865                     840            555  1716     1687
# 6064            881                     794            525  1620     1613
# 6065            841                     848            566  1740     1644
# 6066            854                     791            530  1628     1616
# 6067            861                     821            542  1685     1641
#
#       suprasternaleheight  tenthribheight  thighcircumference  thighclearance  \
# 0                    1449            1092                 610             164
# 1                    1387            1076                 572             169
# 2                    1438            1105                 685             198
# 3                    1346            1021                 604             180
# 4                    1596            1292                 672             194
# ...                   ...             ...                 ...             ...
# 6063                 1391            1119                 660             155
# 6064                 1316            1043                 616             157
# 6065                 1337            1054                 640             159
# 6066                 1288            1028                 623             163
# 6067                 1334            1089                 592             162
#
#       thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  \
# 0               786           491               140                  919
# 1               822           476               120                  918
# 2               807           477               125                  918
# 3               803           445               127                  847
# 4               962           584               122                 1090
# ...             ...           ...               ...                  ...
# 6063            749           446               136                  872
# 6064            721           422               131                  838
# 6065            758           449               127                  862
# 6066            725           419               135                  802
# 6067            762           436               130                  849
#
#       verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  \
# 0                              1700              501           329
# 1                              1627              432           316
# 2                              1678              472           329
# 3                              1625              461           315
# 4                              1679              467           303
# ...                             ...              ...           ...
# 6063                           1706              447           334
# 6064                           1648              446           334
# 6065                           1590              444           335
# 6066                           1525              450           298
# 6067                           1547              462           299
#
#       waistcircumference  waistdepth  waistfrontlengthsitting  \
# 0                    933         240                      440
# 1                    870         225                      371
# 2                    964         255                      411
# 3                    857         205                      399
# 4                    868         214                      379
# ...                  ...         ...                      ...
# 6063                1043         265                      370
# 6064                 971         243                      374
# 6065                 982         254                      351
# 6066                 837         208                      335
# 6067                 891         223                      394
#
#       waistheightomphalion  weightkg  wristcircumference  wristheight  Gender  \
# 0                     1054       815                 175          853    Male
# 1                     1054       726                 167          815    Male
# 2                     1041       929                 180          831    Male
# 3                      968       794                 176          793    Male
# 4                     1245       946                 188          954    Male
# ...                    ...       ...                 ...          ...     ...
# 6063                  1002       832                 162          836  Female
# 6064                   958       717                 157          804  Female
# 6065                   970       762                 159          774  Female
# 6066                   952       632                 146          769  Female
# 6067                   943       610                 154          797  Female
#
#            Date Installation            Component                  Branch  \
# 0      4-Oct-10    Fort Hood         Regular Army             Combat Arms
# 1      4-Oct-10    Fort Hood         Regular Army          Combat Support
# 2      4-Oct-10    Fort Hood         Regular Army          Combat Support
# 3     12-Oct-10    Fort Hood         Regular Army  Combat Service Support
# 4     12-Oct-10    Fort Hood         Regular Army  Combat Service Support
# ...         ...          ...                  ...                     ...
# 6063   5-Apr-12  Camp Shelby  Army National Guard          Combat Support
# 6064   5-Apr-12  Camp Shelby  Army National Guard          Combat Support
# 6065   5-Apr-12  Camp Shelby  Army National Guard          Combat Support
# 6066   5-Apr-12  Camp Shelby  Army National Guard          Combat Support
# 6067  28-May-11   Fort McCoy  Army National Guard          Combat Support
#
#      PrimaryMOS SubjectsBirthLocation  SubjectNumericRace Ethnicity  DODRace  \
# 0           19D          North Dakota                   1       NaN        1
# 1           68W              New York                   1       NaN        1
# 2           68W              New York                   2       NaN        2
# 3           88M             Wisconsin                   1       NaN        1
# 4           92G        North Carolina                   2       NaN        2
# ...         ...                   ...                 ...       ...      ...
# 6063        42A                 Texas                   3   Mexican        3
# 6064        25U                 Texas                   3   Mexican        3
# 6065        42A                 Texas                   2       NaN        2
# 6066        92Y                 Texas                   3   Mexican        3
# 6067        92F                 Texas                   3   Mexican        3
#
#       Age  Heightin  Weightlbs WritingPreference
# 0      41        71        180        Right hand
# 1      35        68        160         Left hand
# 2      42        68        205         Left hand
# 3      31        66        175        Right hand
# 4      21        77        213        Right hand
# ...   ...       ...        ...               ...
# 6063   51        67        180        Right hand
# 6064   40        63        150        Right hand
# 6065   40        66        168        Right hand
# 6066   31        63        133        Right hand
# 6067   27        66        132        Right hand
#
# [6068 rows x 108 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 108 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    SubjectId                       int64
#  1    abdominalextensiondepthsitting  int64
#  2    acromialheight                  int64
#  3    acromionradialelength           int64
#  4    anklecircumference              int64
#  5    axillaheight                    int64
#  6    balloffootcircumference         int64
#  7    balloffootlength                int64
#  8    biacromialbreadth               int64
#  9    bicepscircumferenceflexed       int64
#  10   bicristalbreadth                int64
#  11   bideltoidbreadth                int64
#  12   bimalleolarbreadth              int64
#  13   bitragionchinarc                int64
#  14   bitragionsubmandibulararc       int64
#  15   bizygomaticbreadth              int64
#  16   buttockcircumference            int64
#  17   buttockdepth                    int64
#  18   buttockheight                   int64
#  19   buttockkneelength               int64
#  20   buttockpopliteallength          int64
#  21   calfcircumference               int64
#  22   cervicaleheight                 int64
#  23   chestbreadth                    int64
#  24   chestcircumference              int64
#  25   chestdepth                      int64
#  26   chestheight                     int64
#  27   crotchheight                    int64
#  28   crotchlengthomphalion           int64
#  29   crotchlengthposterioromphalion  int64
#  30   earbreadth                      int64
#  31   earlength                       int64
#  32   earprotrusion                   int64
#  33   elbowrestheight                 int64
#  34   eyeheightsitting                int64
#  35   footbreadthhorizontal           int64
#  36   footlength                      int64
#  37   forearmcenterofgriplength       int64
#  38   forearmcircumferenceflexed      int64
#  39   forearmforearmbreadth           int64
#  40   forearmhandlength               int64
#  41   functionalleglength             int64
#  42   handbreadth                     int64
#  43   handcircumference               int64
#  44   handlength                      int64
#  45   headbreadth                     int64
#  46   headcircumference               int64
#  47   headlength                      int64
#  48   heelanklecircumference          int64
#  49   heelbreadth                     int64
#  50   hipbreadth                      int64
#  51   hipbreadthsitting               int64
#  52   iliocristaleheight              int64
#  53   interpupillarybreadth           int64
#  54   interscyei                      int64
#  55   interscyeii                     int64
#  56   kneeheightmidpatella            int64
#  57   kneeheightsitting               int64
#  58   lateralfemoralepicondyleheight  int64
#  59   lateralmalleolusheight          int64
#  60   lowerthighcircumference         int64
#  61   mentonsellionlength             int64
#  62   neckcircumference               int64
#  63   neckcircumferencebase           int64
#  64   overheadfingertipreachsitting   int64
#  65   palmlength                      int64
#  66   poplitealheight                 int64
#  67   radialestylionlength            int64
#  68   shouldercircumference           int64
#  69   shoulderelbowlength             int64
#  70   shoulderlength                  int64
#  71   sittingheight                   int64
#  72   sleevelengthspinewrist          int64
#  73   sleeveoutseam                   int64
#  74   span                            int64
#  75   stature                         int64
#  76   suprasternaleheight             int64
#  77   tenthribheight                  int64
#  78   thighcircumference              int64
#  79   thighclearance                  int64
#  80   thumbtipreach                   int64
#  81   tibialheight                    int64
#  82   tragiontopofhead                int64
#  83   trochanterionheight             int64
#  84   verticaltrunkcircumferenceusa   int64
#  85   waistbacklength                 int64
#  86   waistbreadth                    int64
#  87   waistcircumference              int64
#  88   waistdepth                      int64
#  89   waistfrontlengthsitting         int64
#  90   waistheightomphalion            int64
#  91   weightkg                        int64
#  92   wristcircumference              int64
#  93   wristheight                     int64
#  94   Gender                          object
#  95   Date                            object
#  96   Installation                    object
#  97   Component                       object
#  98   Branch                          object
#  99   PrimaryMOS                      object
#  100  SubjectsBirthLocation           object
#  101  SubjectNumericRace              int64
#  102  Ethnicity                       object
#  103  DODRace                         int64
#  104  Age                             int64
#  105  Heightin                        int64
#  106  Weightlbs                       int64
#  107  WritingPreference               object
# dtypes: int64(99), object(9)
# memory usage: 5.0+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Ethnicity                         4647
# SubjectId                            0
# radialestylionlength                 0
# thighcircumference                   0
# tenthribheight                       0
# suprasternaleheight                  0
# stature                              0
# span                                 0
# sleeveoutseam                        0
# sleevelengthspinewrist               0
# sittingheight                        0
# shoulderlength                       0
# shoulderelbowlength                  0
# shouldercircumference                0
# poplitealheight                      0
# thumbtipreach                        0
# palmlength                           0
# overheadfingertipreachsitting        0
# neckcircumferencebase                0
# neckcircumference                    0
# mentonsellionlength                  0
# lowerthighcircumference              0
# lateralmalleolusheight               0
# lateralfemoralepicondyleheight       0
# kneeheightsitting                    0
# kneeheightmidpatella                 0
# thighclearance                       0
# tibialheight                         0
# abdominalextensiondepthsitting       0
# tragiontopofhead                     0
# Weightlbs                            0
# Heightin                             0
# Age                                  0
# DODRace                              0
# SubjectNumericRace                   0
# SubjectsBirthLocation                0
# PrimaryMOS                           0
# Branch                               0
# Component                            0
# Installation                         0
# Date                                 0
# Gender                               0
# wristheight                          0
# wristcircumference                   0
# weightkg                             0
# waistheightomphalion                 0
# waistfrontlengthsitting              0
# waistdepth                           0
# waistcircumference                   0
# waistbreadth                         0
# waistbacklength                      0
# verticaltrunkcircumferenceusa        0
# trochanterionheight                  0
# interscyeii                          0
# interscyei                           0
# interpupillarybreadth                0
# chestheight                          0
# chestcircumference                   0
# chestbreadth                         0
# cervicaleheight                      0
# calfcircumference                    0
# buttockpopliteallength               0
# buttockkneelength                    0
# buttockheight                        0
# buttockdepth                         0
# buttockcircumference                 0
# bizygomaticbreadth                   0
# bitragionsubmandibulararc            0
# bitragionchinarc                     0
# bimalleolarbreadth                   0
# bideltoidbreadth                     0
# bicristalbreadth                     0
# bicepscircumferenceflexed            0
# biacromialbreadth                    0
# balloffootlength                     0
# balloffootcircumference              0
# axillaheight                         0
# anklecircumference                   0
# acromionradialelength                0
# acromialheight                       0
# chestdepth                           0
# crotchheight                         0
# iliocristaleheight                   0
# crotchlengthomphalion                0
# hipbreadthsitting                    0
# hipbreadth                           0
# heelbreadth                          0
# heelanklecircumference               0
# headlength                           0
# headcircumference                    0
# headbreadth                          0
# handlength                           0
# handcircumference                    0
# handbreadth                          0
# functionalleglength                  0
# forearmhandlength                    0
# forearmforearmbreadth                0
# forearmcircumferenceflexed           0
# forearmcenterofgriplength            0
# footlength                           0
# footbreadthhorizontal                0
# eyeheightsitting                     0
# elbowrestheight                      0
# earprotrusion                        0
# earlength                            0
# earbreadth                           0
# crotchlengthposterioromphalion       0
# WritingPreference                    0
# dtype: int64

# %%
# we drop etnicity column bcs there are lots of null values

# %%
df["DODRace"].value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: DODRace, dtype: int64

# %%
df["DODRace"].value_counts(normalize=True)
# Out:
# 1   0.625
# 2   0.214
# 3   0.112
# 4   0.031
# 6   0.010
# 5   0.008
# 8   0.000
# Name: DODRace, dtype: float64

# %%
plt.figure(figsize=(10,10))
df["DODRace"].value_counts(normalize=True).plot(kind="pie", autopct="%%%.1f",pctdistance=0.9 );

# %%
df = df[(df["DODRace"] == 1)| (df["DODRace"] == 2) | (df["DODRace"] == 3)]
df.shape
# Out:
# (5769, 108)

# %%
df["DODRace"].value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# Name: DODRace, dtype: int64

# %%
columns
# Out:
#                     df_male_columns               df_female_columns
# 0                         subjectid                       SubjectId
# 1    abdominalextensiondepthsitting  abdominalextensiondepthsitting
# 2                    acromialheight                  acromialheight
# 3             acromionradialelength           acromionradialelength
# 4                anklecircumference              anklecircumference
# 5                      axillaheight                    axillaheight
# 6           balloffootcircumference         balloffootcircumference
# 7                  balloffootlength                balloffootlength
# 8                 biacromialbreadth               biacromialbreadth
# 9         bicepscircumferenceflexed       bicepscircumferenceflexed
# 10                 bicristalbreadth                bicristalbreadth
# 11                 bideltoidbreadth                bideltoidbreadth
# 12               bimalleolarbreadth              bimalleolarbreadth
# 13                 bitragionchinarc                bitragionchinarc
# 14        bitragionsubmandibulararc       bitragionsubmandibulararc
# 15               bizygomaticbreadth              bizygomaticbreadth
# 16             buttockcircumference            buttockcircumference
# 17                     buttockdepth                    buttockdepth
# 18                    buttockheight                   buttockheight
# 19                buttockkneelength               buttockkneelength
# 20           buttockpopliteallength          buttockpopliteallength
# 21                calfcircumference               calfcircumference
# 22                  cervicaleheight                 cervicaleheight
# 23                     chestbreadth                    chestbreadth
# 24               chestcircumference              chestcircumference
# 25                       chestdepth                      chestdepth
# 26                      chestheight                     chestheight
# 27                     crotchheight                    crotchheight
# 28            crotchlengthomphalion           crotchlengthomphalion
# 29   crotchlengthposterioromphalion  crotchlengthposterioromphalion
# 30                       earbreadth                      earbreadth
# 31                        earlength                       earlength
# 32                    earprotrusion                   earprotrusion
# 33                  elbowrestheight                 elbowrestheight
# 34                 eyeheightsitting                eyeheightsitting
# 35            footbreadthhorizontal           footbreadthhorizontal
# 36                       footlength                      footlength
# 37        forearmcenterofgriplength       forearmcenterofgriplength
# 38       forearmcircumferenceflexed      forearmcircumferenceflexed
# 39            forearmforearmbreadth           forearmforearmbreadth
# 40                forearmhandlength               forearmhandlength
# 41              functionalleglength             functionalleglength
# 42                      handbreadth                     handbreadth
# 43                handcircumference               handcircumference
# 44                       handlength                      handlength
# 45                      headbreadth                     headbreadth
# 46                headcircumference               headcircumference
# 47                       headlength                      headlength
# 48           heelanklecircumference          heelanklecircumference
# 49                      heelbreadth                     heelbreadth
# 50                       hipbreadth                      hipbreadth
# 51                hipbreadthsitting               hipbreadthsitting
# 52               iliocristaleheight              iliocristaleheight
# 53            interpupillarybreadth           interpupillarybreadth
# 54                       interscyei                      interscyei
# 55                      interscyeii                     interscyeii
# 56             kneeheightmidpatella            kneeheightmidpatella
# 57                kneeheightsitting               kneeheightsitting
# 58   lateralfemoralepicondyleheight  lateralfemoralepicondyleheight
# 59           lateralmalleolusheight          lateralmalleolusheight
# 60          lowerthighcircumference         lowerthighcircumference
# 61              mentonsellionlength             mentonsellionlength
# 62                neckcircumference               neckcircumference
# 63            neckcircumferencebase           neckcircumferencebase
# 64    overheadfingertipreachsitting   overheadfingertipreachsitting
# 65                       palmlength                      palmlength
# 66                  poplitealheight                 poplitealheight
# 67             radialestylionlength            radialestylionlength
# 68            shouldercircumference           shouldercircumference
# 69              shoulderelbowlength             shoulderelbowlength
# 70                   shoulderlength                  shoulderlength
# 71                    sittingheight                   sittingheight
# 72           sleevelengthspinewrist          sleevelengthspinewrist
# 73                    sleeveoutseam                   sleeveoutseam
# 74                             span                            span
# 75                          stature                         stature
# 76              suprasternaleheight             suprasternaleheight
# 77                   tenthribheight                  tenthribheight
# 78               thighcircumference              thighcircumference
# 79                   thighclearance                  thighclearance
# 80                    thumbtipreach                   thumbtipreach
# 81                     tibialheight                    tibialheight
# 82                 tragiontopofhead                tragiontopofhead
# 83              trochanterionheight             trochanterionheight
# 84    verticaltrunkcircumferenceusa   verticaltrunkcircumferenceusa
# 85                  waistbacklength                 waistbacklength
# 86                     waistbreadth                    waistbreadth
# 87               waistcircumference              waistcircumference
# 88                       waistdepth                      waistdepth
# 89          waistfrontlengthsitting         waistfrontlengthsitting
# 90             waistheightomphalion            waistheightomphalion
# 91                         weightkg                        weightkg
# 92               wristcircumference              wristcircumference
# 93                      wristheight                     wristheight
# 94                           Gender                          Gender
# 95                             Date                            Date
# 96                     Installation                    Installation
# 97                        Component                       Component
# 98                           Branch                          Branch
# 99                       PrimaryMOS                      PrimaryMOS
# 100           SubjectsBirthLocation           SubjectsBirthLocation
# 101              SubjectNumericRace              SubjectNumericRace
# 102                       Ethnicity                       Ethnicity
# 103                         DODRace                         DODRace
# 104                             Age                             Age
# 105                        Heightin                        Heightin
# 106                       Weightlbs                       Weightlbs
# 107               WritingPreference               WritingPreference

# %%
drop_columns = ["SubjectId", "Date", "Installation", "WritingPreference", "Ethnicity",
               "Component", "Branch", "PrimaryMOS", "Weightlbs", "stature"]

# %%
df.drop(columns=drop_columns, inplace=True)

# %%
df.shape
# Out:
# (5769, 98)

# %%
len(df.select_dtypes("number").columns)
# Out:
# 96

# %%
plt.figure(figsize=(20,200))
index=0
for col in df.select_dtypes("number"):
    index+=1
    plt.subplot(49,2,index)
    sns.boxplot(x=df[col])
    
    
# plt.figure(figsize=(10, 400))
# for i in range(len(df.select_dtypes("number").drop(columns="DODRace").columns)):
#     plt.subplot(97, 1, i+1)
#     sns.boxplot(data=df, x=df.select_dtypes("number").drop(columns="DODRace").columns[i])
#     plt.tight_layout()

# %%
df.SubjectNumericRace.value_counts()
# Out:
# 1        3559
# 2        1025
# 3         541
# 31        159
# 8         106
# 51        102
# 21         60
# 23         34
# 28         26
# 251        20
# 41         19
# 18         16
# 61         15
# 25         13
# 38          9
# 351         9
# 231         6
# 42          6
# 62          6
# 35          5
# 235         4
# 43          3
# 63          3
# 218         3
# 431         2
# 2351        2
# 423         2
# 2518        2
# 4251        1
# 238         1
# 318         1
# 451         1
# 4           1
# 425         1
# 428         1
# 651         1
# 6           1
# 631         1
# 358         1
# 42351       1
# Name: SubjectNumericRace, dtype: int64

# %%
df.drop(columns=["SubjectNumericRace"], inplace=True)

# %%
df= df[df.weightkg < 1400]

# %%
df.weightkg = df.weightkg / 10

# %%
df.shape
# Out:
# (5765, 97)

# %%
for i in df.select_dtypes("O"):
    print(f"There are {df[i].nunique()} unique values in {i} column")
# Out:
# There are 2 unique values in Gender column
# There are 136 unique values in SubjectsBirthLocation column

# %%
df.Gender = df.Gender.map({"Male": 1, "Female": 0})

# %%
df.Gender.value_counts()
# Out:
# 1    3895
# 0    1870
# Name: Gender, dtype: int64

# %%
df["DODRace"] = df.DODRace.map({1: "White", 2: "Black", 3: "Hispanic"})

# %%
df.reset_index(drop=True,inplace=True)

# %%
def color_red(val):
    if val > 0.90 and val < 0.99:
        color = 'red'
    else:
        color = 'black'
    return f'color: {color}'


pd.DataFrame(df.corr()).style.applymap(color_red)
# Out:
# <style type="text/css">
# #T_35a8b_row0_col0, #T_35a8b_row0_col1, #T_35a8b_row0_col2, #T_35a8b_row0_col3, #T_35a8b_row0_col4, #T_35a8b_row0_col5, #T_35a8b_row0_col6, #T_35a8b_row0_col7, #T_35a8b_row0_col8, #T_35a8b_row0_col9, #T_35a8b_row0_col10, #T_35a8b_row0_col11, #T_35a8b_row0_col12, #T_35a8b_row0_col13, #T_35a8b_row0_col14, #T_35a8b_row0_col15, #T_35a8b_row0_col16, #T_35a8b_row0_col17, #T_35a8b_row0_col18, #T_35a8b_row0_col19, #T_35a8b_row0_col20, #T_35a8b_row0_col21, #T_35a8b_row0_col22, #T_35a8b_row0_col23, #T_35a8b_row0_col24, #T_35a8b_row0_col25, #T_35a8b_row0_col26, #T_35a8b_row0_col27, #T_35a8b_row0_col28, #T_35a8b_row0_col29, #T_35a8b_row0_col30, #T_35a8b_row0_col31, #T_35a8b_row0_col32, #T_35a8b_row0_col33, #T_35a8b_row0_col34, #T_35a8b_row0_col35, #T_35a8b_row0_col36, #T_35a8b_row0_col37, #T_35a8b_row0_col38, #T_35a8b_row0_col39, #T_35a8b_row0_col40, #T_35a8b_row0_col41, #T_35a8b_row0_col42, #T_35a8b_row0_col43, #T_35a8b_row0_col44, #T_35a8b_row0_col45, #T_35a8b_row0_col46, #T_35a8b_row0_col47, #T_35a8b_row0_col48, #T_35a8b_row0_col49, #T_35a8b_row0_col50, #T_35a8b_row0_col51, #T_35a8b_row0_col52, #T_35a8b_row0_col53, #T_35a8b_row0_col54, #T_35a8b_row0_col55, #T_35a8b_row0_col56, #T_35a8b_row0_col57, #T_35a8b_row0_col58, #T_35a8b_row0_col59, #T_35a8b_row0_col60, #T_35a8b_row0_col61, #T_35a8b_row0_col62, #T_35a8b_row0_col63, #T_35a8b_row0_col64, #T_35a8b_row0_col65, #T_35a8b_row0_col66, #T_35a8b_row0_col67, #T_35a8b_row0_col68, #T_35a8b_row0_col69, #T_35a8b_row0_col70, #T_35a8b_row0_col71, #T_35a8b_row0_col72, #T_35a8b_row0_col73, #T_35a8b_row0_col74, #T_35a8b_row0_col75, #T_35a8b_row0_col76, #T_35a8b_row0_col77, #T_35a8b_row0_col78, #T_35a8b_row0_col79, #T_35a8b_row0_col80, #T_35a8b_row0_col81, #T_35a8b_row0_col82, #T_35a8b_row0_col83, #T_35a8b_row0_col84, #T_35a8b_row0_col87, #T_35a8b_row0_col88, #T_35a8b_row0_col89, #T_35a8b_row0_col90, #T_35a8b_row0_col91, #T_35a8b_row0_col92, #T_35a8b_row0_col93, #T_35a8b_row0_col94, #T_35a8b_row1_col0, #T_35a8b_row1_col1, #T_35a8b_row1_col2, #T_35a8b_row1_col3, #T_35a8b_row1_col5, #T_35a8b_row1_col6, #T_35a8b_row1_col7, #T_35a8b_row1_col8, #T_35a8b_row1_col9, #T_35a8b_row1_col10, #T_35a8b_row1_col11, #T_35a8b_row1_col12, #T_35a8b_row1_col13, #T_35a8b_row1_col14, #T_35a8b_row1_col15, #T_35a8b_row1_col16, #T_35a8b_row1_col17, #T_35a8b_row1_col18, #T_35a8b_row1_col19, #T_35a8b_row1_col20, #T_35a8b_row1_col22, #T_35a8b_row1_col23, #T_35a8b_row1_col24, #T_35a8b_row1_col26, #T_35a8b_row1_col27, #T_35a8b_row1_col28, #T_35a8b_row1_col29, #T_35a8b_row1_col30, #T_35a8b_row1_col31, #T_35a8b_row1_col32, #T_35a8b_row1_col33, #T_35a8b_row1_col34, #T_35a8b_row1_col35, #T_35a8b_row1_col36, #T_35a8b_row1_col37, #T_35a8b_row1_col38, #T_35a8b_row1_col39, #T_35a8b_row1_col40, #T_35a8b_row1_col41, #T_35a8b_row1_col42, #T_35a8b_row1_col43, #T_35a8b_row1_col44, #T_35a8b_row1_col45, #T_35a8b_row1_col46, #T_35a8b_row1_col47, #T_35a8b_row1_col48, #T_35a8b_row1_col49, #T_35a8b_row1_col50, #T_35a8b_row1_col52, #T_35a8b_row1_col53, #T_35a8b_row1_col54, #T_35a8b_row1_col55, #T_35a8b_row1_col57, #T_35a8b_row1_col58, #T_35a8b_row1_col59, #T_35a8b_row1_col60, #T_35a8b_row1_col61, #T_35a8b_row1_col62, #T_35a8b_row1_col63, #T_35a8b_row1_col64, #T_35a8b_row1_col65, #T_35a8b_row1_col66, #T_35a8b_row1_col67, #T_35a8b_row1_col68, #T_35a8b_row1_col69, #T_35a8b_row1_col70, #T_35a8b_row1_col71, #T_35a8b_row1_col72, #T_35a8b_row1_col73, #T_35a8b_row1_col76, #T_35a8b_row1_col77, #T_35a8b_row1_col78, #T_35a8b_row1_col79, #T_35a8b_row1_col80, #T_35a8b_row1_col81, #T_35a8b_row1_col82, #T_35a8b_row1_col83, #T_35a8b_row1_col84, #T_35a8b_row1_col85, #T_35a8b_row1_col86, #T_35a8b_row1_col87, #T_35a8b_row1_col89, #T_35a8b_row1_col90, #T_35a8b_row1_col92, #T_35a8b_row1_col93, #T_35a8b_row2_col0, #T_35a8b_row2_col1, #T_35a8b_row2_col2, #T_35a8b_row2_col3, #T_35a8b_row2_col4, #T_35a8b_row2_col5, #T_35a8b_row2_col6, #T_35a8b_row2_col7, #T_35a8b_row2_col8, #T_35a8b_row2_col9, #T_35a8b_row2_col10, #T_35a8b_row2_col11, #T_35a8b_row2_col12, #T_35a8b_row2_col1 ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
X = df.drop(columns="DODRace")
y = df["DODRace"]

# %%
cat = X.select_dtypes("O").columns
cat
# Out:
# Index(['SubjectsBirthLocation'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=101)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4612, 96)
# Train target shape   :  (4612,)
# Test features shape  :  (1153, 96)
# Test target shape    :  (1153,)

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, MinMaxScaler
from sklearn.compose import make_column_transformer

encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
column_trans = make_column_transformer((encoder, cat), remainder=MinMaxScaler())

# %%
df["DODRace"].value_counts()
# Out:
# White       3789
# Black       1298
# Hispanic     678
# Name: DODRace, dtype: int64

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
from sklearn.linear_model import  LogisticRegression
from sklearn.pipeline import Pipeline

log_model = LogisticRegression()

pipe_log_model = Pipeline([("OneHotEncoder", column_trans),("log_pipe", LogisticRegression(random_state=101))])

# %%
pipe_log_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['SubjectsBirthLocation'], dtype='object'))])),
#                 ('log_pipe', LogisticRegression(random_state=101))])

# %%
y_pred = pipe_log_model.predict(X_test)
y_train_pred = pipe_log_model.predict(X_train)

# %%
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix, plot_roc_curve, plot_precision_recall_curve
from sklearn.metrics import make_scorer, recall_score, precision_score, accuracy_score, f1_score

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[242   3  15]
#  [ 10  68  57]
#  [ 10  16 732]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.93      0.93       260
#     Hispanic       0.78      0.50      0.61       135
#        White       0.91      0.97      0.94       758
#
#     accuracy                           0.90      1153
#    macro avg       0.87      0.80      0.83      1153
# weighted avg       0.90      0.90      0.90      1153
#
#
# Train_Set
# [[ 953   11   74]
#  [  26  316  201]
#  [  25   60 2946]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.92      0.93      1038
#     Hispanic       0.82      0.58      0.68       543
#        White       0.91      0.97      0.94      3031
#
#     accuracy                           0.91      4612
#    macro avg       0.89      0.82      0.85      4612
# weighted avg       0.91      0.91      0.91      4612

# %%
from sklearn.model_selection import cross_validate, cross_val_score
from sklearn.model_selection import  GridSearchCV
model = Pipeline([("OneHotEncoder", column_trans),("log_pipe", LogisticRegression(class_weight="balanced",random_state=101))])

scores = cross_validate(model, X_train, y_train, cv = 10, scoring = ["accuracy", "precision_weighted", "recall_weighted", "f1_weighted"])
df_scores = pd.DataFrame(scores, index= range(1,11))
df_scores.mean()[2:]
# Out:
# test_accuracy             0.858
# test_precision_weighted   0.889
# test_recall_weighted      0.858
# test_f1_weighted          0.868
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
model = Pipeline([("OneHotEncoder", column_trans),("log_pipe", LogisticRegression(class_weight="balanced", random_state=101))])
param_grid = {"log_pipe__C" : [0.1,1],
              "log_pipe__penalty": ["l1", "l2"],
              "log_pipe__solver": ["lbfgs", "liblinear"]}


log_model_grid = GridSearchCV(model, param_grid, cv=5,verbose=2, scoring="accuracy", n_jobs=-1)

# %%
log_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          Index(['SubjectsBirthLocation'], dtype='object'))])),
#                                        ('log_pipe',
#                                         LogisticRegression(class_weight='balanced',
#                                                            random_state=101))]),
#              n_jobs=-1,
#              param_grid={'log_pipe__C': [0.1, 1, 5],
#                          'log_pipe__penalty': ['l1', 'l2'],
#                          'log_pipe__solver': ['lbfgs', 'liblinear']},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=2)

# %%
log_model_grid.best_score_
# Out:
# 0.6299524294937139

# %%
log_model_grid.best_params_
# Out:
# {'log_pipe__C': 0.1, 'log_pipe__penalty': 'l2', 'log_pipe__solver': 'lbfgs'}

# %%
log_model_grid.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['SubjectsBirthLocation'], dtype='object'))])),
#                 ('log_pipe',
#                  LogisticRegression(C=0.1, class_weight='balanced',
#                                     random_state=101))])

# %%
y_pred = log_model_grid.predict(X_test)
y_train_pred = log_model_grid.predict(X_train)

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[225  20  15]
#  [ 17  86  32]
#  [ 28 180 550]]
#               precision    recall  f1-score   support
#
#        Black       0.83      0.87      0.85       260
#     Hispanic       0.30      0.64      0.41       135
#        White       0.92      0.73      0.81       758
#
#     accuracy                           0.75      1153
#    macro avg       0.69      0.74      0.69      1153
# weighted avg       0.83      0.75      0.77      1153
#
#
# Train_Set
# [[ 908   81   49]
#  [  56  363  124]
#  [ 103  685 2243]]
#               precision    recall  f1-score   support
#
#        Black       0.85      0.87      0.86      1038
#     Hispanic       0.32      0.67      0.43       543
#        White       0.93      0.74      0.82      3031
#
#     accuracy                           0.76      4612
#    macro avg       0.70      0.76      0.71      4612
# weighted avg       0.84      0.76      0.79      4612

# %% [markdown]
# ###  Evaluating ROC Curves and AUC

# %%
from yellowbrick.classifier import ROCAUC
model = log_model_grid
visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show();

# %%
from yellowbrick.classifier import PrecisionRecallCurve

model = Pipeline([("OneHotEncoder", column_trans),("log_pipe", LogisticRegression(random_state=101))])

viz = PrecisionRecallCurve(model, per_class=True, cmap="Set1" )
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
log_accuracy_test = accuracy_score(y_test, y_pred_test)
log_accuracy_train = accuracy_score(y_train, y_pred_train)

log_f1_test = f1_score(y_test, y_pred_test, average='weighted')
log_f1_train = f1_score(y_train, y_pred_train, average='weighted')

log_accuracy_test, log_accuracy_train, log_f1_test, log_f1_train

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %%
from sklearn.svm import SVC

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       remainder=MinMaxScaler())

# %%
pipe_svc_model = Pipeline([("OneHotEncoder", column_trans),("svc_pipe", SVC(class_weight="balanced", random_state=101))])
pipe_svc_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['SubjectsBirthLocation'], dtype='object'))])),
#                 ('svc_pipe', SVC(class_weight='balanced', random_state=101))])

# %%
eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[241   9  10]
#  [  8  98  29]
#  [ 18 110 630]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.93      0.91       260
#     Hispanic       0.45      0.73      0.56       135
#        White       0.94      0.83      0.88       758
#
#     accuracy                           0.84      1153
#    macro avg       0.77      0.83      0.78      1153
# weighted avg       0.88      0.84      0.85      1153
#
#
# Train_Set
# [[ 959   40   39]
#  [  19  461   63]
#  [  49  415 2567]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.92      0.93      1038
#     Hispanic       0.50      0.85      0.63       543
#        White       0.96      0.85      0.90      3031
#
#     accuracy                           0.86      4612
#    macro avg       0.80      0.87      0.82      4612
# weighted avg       0.90      0.86      0.88      4612

# %%
model = Pipeline([("OneHotEncoder", column_trans),("svc_pipe", SVC(class_weight="balanced", random_state=101))])

scores = cross_validate(model, X_train, y_train, cv=10, scoring=["precision_weighted", "recall_weighted", "f1_weighted"])
df_scores = pd.DataFrame(scores, index=range(1,11))
df_scores.mean()[2:]
# Out:
# test_precision_weighted   0.883
# test_recall_weighted      0.844
# test_f1_weighted          0.856
# dtype: float64

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
model = Pipeline([("OneHotEncoder", column_trans),("svc_pipe", SVC(class_weight="balanced", random_state=101))])

param_grid = {"svc_pipe__C" : [1,2, 3],
              "svc_pipe__gamma": ["scale", "auto", 1, 0.1]}

svc_model_grid = GridSearchCV(model, param_grid, verbose=3, scoring="accuracy", n_jobs=-1)

# %%
svc_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['SubjectsBirthLocation'], dtype='object'))])),
#                                        ('svc_pipe',
#                                         SVC(class_weight='balanced',
#                                             random_state=101))]),
#              n_jobs=-1,
#              param_grid={'svc_pipe__C': [1, 2, 3],
#                          'svc_pipe__gamma': ['scale', 'auto', 1, 0.1]},
#              scoring='accuracy', verbose=3)

# %%
svc_model_grid.best_estimator_
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['SubjectsBirthLocation'], dtype='object'))])),
#                 ('svc_pipe',
#                  SVC(C=3, class_weight='balanced', gamma=1, random_state=101))])

# %%
svc_model_grid.best_params_
# Out:
# {'svc_pipe__C': 3, 'svc_pipe__gamma': 1}

# %%
svc_model_grid.best_score_
# Out:
# 0.8677351276019205

# %%
y_pred_test = svc_model_grid.predict(X_test)
y_pred_train = svc_model_grid.predict(X_train)

# %%
eval_metric(svc_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[227   4  29]
#  [  9  62  64]
#  [ 11  22 725]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.87      0.90       260
#     Hispanic       0.70      0.46      0.56       135
#        White       0.89      0.96      0.92       758
#
#     accuracy                           0.88      1153
#    macro avg       0.84      0.76      0.79      1153
# weighted avg       0.87      0.88      0.87      1153
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    2 3029]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3031
#
#     accuracy                           1.00      4612
#    macro avg       1.00      1.00      1.00      4612
# weighted avg       1.00      1.00      1.00      4612

# %% [markdown]
# ### Evaluating ROC Curves and AUC

# %%
from yellowbrick.classifier import ROCAUC
model = svc_model_grid
visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %%
model = Pipeline([("OneHotEncoder", column_trans),("svc_pipe", SVC(C=3, gamma=1, class_weight="balanced", random_state=101))])

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
SVC_accuracy_test = accuracy_score(y_test, y_pred_test)
SVC_accuracy_train = accuracy_score(y_train, y_pred_train)

SVC_f1_test = f1_score(y_test, y_pred_test, average='weighted')
SVC_f1_train = f1_score(y_train, y_pred_train, average='weighted')

SVC_accuracy_test, SVC_accuracy_train, SVC_f1_test, SVC_f1_train

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %%
# Since we applied ordinal encoder on splitted data before implementing Logistic model, we should reset train, test split operation. 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
cat = X_train.select_dtypes("object").columns
cat

# %%
encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
column_trans = make_column_transformer((encoder, cat), remainder='passthrough')

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(class_weight="balanced", random_state=101)

pipe_rf_model = Pipeline([("OneHotEncoder", column_trans),("RF_model", rf_model)])

pipe_rf_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['SubjectsBirthLocation'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced',
#                                         random_state=101))])

# %%
eval_metric(pipe_rf_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[184   1  75]
#  [  7   5 123]
#  [  3   1 754]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.71      0.81       260
#     Hispanic       0.71      0.04      0.07       135
#        White       0.79      0.99      0.88       758
#
#     accuracy                           0.82      1153
#    macro avg       0.82      0.58      0.59      1153
# weighted avg       0.82      0.82      0.77      1153
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    0 3031]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3031
#
#     accuracy                           1.00      4612
#    macro avg       1.00      1.00      1.00      4612
# weighted avg       1.00      1.00      1.00      4612

# %%
model = Pipeline([("OneHotEncoder", column_trans),("RF_model", RandomForestClassifier(class_weight="balanced", random_state=101) )])


scores = cross_validate(model, X_train, y_train, cv=10, scoring = ["accuracy", "precision_weighted", "recall_weighted", "f1_weighted"], error_score="raise",)
df_scores = pd.DataFrame(scores, index=range(1,11))
df_scores.mean()[2:]
# Out:
# test_accuracy             0.804
# test_precision_weighted   0.826
# test_recall_weighted      0.804
# test_f1_weighted          0.756
# dtype: float64

# %% [markdown]
# ### RF Model GridsearchCV

# %%
model = Pipeline([("OrdinalEncoder", column_trans),("RF_model", rf_model)])

param_grid = {"RF_model__criterion" : ["gini", "entropy"],
              "RF_model__max_depth": [8, 9, 10], 
              "RF_model__n_estimators": [300, 400]}

rf_model_grid = GridSearchCV(model, param_grid, verbose=3, scoring="accuracy", n_jobs=-1, )

# %%
rf_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['SubjectsBirthLocation'], dtype='object'))])),
#                                        ('RF_model',
#                                         RandomForestClassifier(class_weight='balanced',
#                                                                random_state=101))]),
#              n_jobs=-1,
#              param_grid={'RF_model__criterion': ['gini', 'entropy'],
#                          'RF_model__max_depth': [8, 9, 10],
#                          'RF_model__n_estimators': [300, 400]},
#              scoring='accuracy', verbose=3)

# %%
rf_model_grid.best_score_
# Out:
# 0.8180842438243678

# %%
rf_model_grid.best_estimator_
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['SubjectsBirthLocation'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced',
#                                         criterion='entropy', max_depth=10,
#                                         n_estimators=300, random_state=101))])

# %%
rf_model_grid.best_params_
# Out:
# {'RF_model__criterion': 'entropy',
#  'RF_model__max_depth': 10,
#  'RF_model__n_estimators': 300}

# %%
y_pred_test = rf_model_grid.predict(X_test)
y_pred_train = rf_model_grid.predict(X_train)

# %%
eval_metric(rf_model_grid, X_train, y_train, X_test, y_test)

# %%
model = Pipeline([("OrdinalEncoder", column_trans),("RF_model", rf_model)])

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
RF_accuracy_test = accuracy_score(y_test, y_pred_test)
RF_accuracy_train = accuracy_score(y_train, y_pred_train)

RF_f1_test = f1_score(y_test, y_pred_test, average='weighted')
RF_f1_train = f1_score(y_train, y_pred_train, average='weighted')

RF_accuracy_test, RF_accuracy_train, RF_f1_test, RF_f1_train

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
from xgboost import XGBClassifier

# %%
pipe_xgb_model = Pipeline([("OrdinalEncoder", column_trans),("xgb_model", XGBClassifier(random_state=101))])

pipe_xgb_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['SubjectsBirthLocation'], dtype='object'))])),
#                 ('xgb_model',
#                  XGBClassifier(objective='multi:softprob', random_state=101))])

# %%
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train)
classes_weights
# Out:
# array([0.50720334, 0.50720334, 0.50720334, ..., 0.50720334, 0.50720334,
#        0.50720334])

# %%
comp = pd.DataFrame(classes_weights)

comp["label"] = y_train.reset_index(drop=True)
comp.groupby("label")[0].value_counts()
# Out:
# label     0
# Black     1.481    1038
# Hispanic  2.831     543
# White     0.507    3031
# Name: 0, dtype: int64

# %%
pipe_xgb_model.fit(X_train,y_train, xgb_model__sample_weight=classes_weights)
# weight parameter in XGBoost is per instance not per class. Therefore, we need to assign the weight of each class to its instances, which is the same thing.
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['SubjectsBirthLocation'], dtype='object'))])),
#                 ('xgb_model',
#                  XGBClassifier(objective='multi:softprob', random_state=101))])

# %%
eval_metric(pipe_xgb_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[231   8  21]
#  [ 12  87  36]
#  [ 39  87 632]]
#               precision    recall  f1-score   support
#
#        Black       0.82      0.89      0.85       260
#     Hispanic       0.48      0.64      0.55       135
#        White       0.92      0.83      0.87       758
#
#     accuracy                           0.82      1153
#    macro avg       0.74      0.79      0.76      1153
# weighted avg       0.84      0.82      0.83      1153
#
#
# Train_Set
# [[ 977   22   39]
#  [  20  452   71]
#  [ 100  323 2608]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.94      0.92      1038
#     Hispanic       0.57      0.83      0.67       543
#        White       0.96      0.86      0.91      3031
#
#     accuracy                           0.88      4612
#    macro avg       0.81      0.88      0.83      4612
# weighted avg       0.90      0.88      0.88      4612

# %%
model = Pipeline([("OrdinalEncoder", column_trans),("xgb_model", XGBClassifier(random_state=101))])

scores = cross_validate(model, X_train, y_train, cv=10, scoring=["accuracy", "precision_micro", "recall_micro", "f1_micro"], n_jobs=-1 )

df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
#     fit_time  score_time  test_accuracy  test_precision_micro  \
# 1     13.524       0.022          0.844                 0.844
# 2     12.472       0.025          0.853                 0.853
# 3     12.628       0.036          0.861                 0.861
# 4     13.164       0.024          0.866                 0.866
# 5     13.568       0.018          0.868                 0.868
# 6     13.341       0.030          0.866                 0.866
# 7     12.863       0.024          0.868                 0.868
# 8     13.294       0.027          0.859                 0.859
# 9      7.630       0.016          0.861                 0.861
# 10     7.741       0.014          0.852                 0.852
#
#     test_recall_micro  test_f1_micro
# 1               0.844          0.844
# 2               0.853          0.853
# 3               0.861          0.861
# 4               0.866          0.866
# 5               0.868          0.868
# 6               0.866          0.866
# 7               0.868          0.868
# 8               0.859          0.859
# 9               0.861          0.861
# 10              0.852          0.852

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
model = Pipeline([("OrdinalEncoder", column_trans),("xgb_model", XGBClassifier(random_state=101))])

param_grid = {"xgb_model__learning_rate" :[0.1, 0.5],
              "xgb_model__max_depth": [3,4,5],
              "xgb_model__n_estimators": [100, 200],
               "xgb_model__subsample":[0.8, 1]}

xgb_model_grid = GridSearchCV(model, param_grid, cv=5, scoring="accuracy", verbose=2, n_jobs=-1)

# %%
xgb_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['SubjectsBirthLocation'], dtype='object'))])),
#                                        ('xgb_model',
#                                         XGBClassifier(random_state=101))]),
#              n_jobs=-1,
#              param_grid={'xgb_model__learning_rate': [0.1, 0.5],
#                          'xgb_model__max_depth': [3, 4, 5],
#                          'xgb_model__n_estimators': [100, 200],
#                          'xgb_model__subsample': [0.8, 1]},
#              scoring='accuracy', verbose=2)

# %%
xgb_model_grid.best_score_
# Out:
# 0.8783632547831625

# %%
xgb_model_grid.best_params_
# Out:
# {'xgb_model__learning_rate': 0.1,
#  'xgb_model__max_depth': 4,
#  'xgb_model__n_estimators': 200,
#  'xgb_model__subsample': 0.8}

# %%
xgb_model_grid.best_estimator_
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['SubjectsBirthLocation'], dtype='object'))])),
#                 ('xgb_model',
#                  XGBClassifier(max_depth=4, n_estimators=200,
#                                objective='multi:softprob', random_state=101,
#                                subsample=0.8))])

# %%
y_pred_test = xgb_model_grid.predict(X_test)
y_pred_train = xgb_model_grid.predict(X_train)

# %%
eval_metric(model,X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[227   0  33]
#  [  9  58  68]
#  [ 10   9 739]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.87      0.90       260
#     Hispanic       0.87      0.43      0.57       135
#        White       0.88      0.97      0.92       758
#
#     accuracy                           0.89      1153
#    macro avg       0.89      0.76      0.80      1153
# weighted avg       0.89      0.89      0.88      1153
#
#
# Train_Set
# [[1028    0   10]
#  [   4  485   54]
#  [   2    1 3028]]
#               precision    recall  f1-score   support
#
#        Black       0.99      0.99      0.99      1038
#     Hispanic       1.00      0.89      0.94       543
#        White       0.98      1.00      0.99      3031
#
#     accuracy                           0.98      4612
#    macro avg       0.99      0.96      0.97      4612
# weighted avg       0.98      0.98      0.98      4612

# %%
model = Pipeline([("OrdinalEncoder", column_trans),("xgb_model", XGBClassifier(max_depth=4, n_estimators=200, subsample=0.8))])

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
xgb_accuracy_test = accuracy_score(y_test, y_pred_test)
xgb_accuracy_train = accuracy_score(y_train, y_pred_train)

xgb_f1_test = f1_score(y_test, y_pred_test, average='weighted')
xgb_f1_train = f1_score(y_train, y_pred_train, average='weighted')

xgb_accuracy_test, xgb_accuracy_train, xgb_f1_test, xgb_f1_train

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %% [markdown]
# ## SVC Over/Under Sampling

# %% [markdown]
# ## Xgboost Over/ Under Sampling

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7380728719663084

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7376215262514891

# %% [markdown]
# #  SHAP
#
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.40.0-cp38-cp38-win_amd64.whl (431 kB)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\madcat\anaconda3\lib\site-packages (from shap) (4.59.0)
# Requirement already satisfied: numba in c:\users\madcat\anaconda3\lib\site-packages (from shap) (0.53.1)
# Collecting packaging>20.9
#   Downloading packaging-21.2-py3-none-any.whl (40 kB)
# Requirement already satisfied: scikit-learn in c:\users\madcat\anaconda3\lib\site-packages (from shap) (0.24.1)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.6.2)
# Requirement already satisfied: cloudpickle in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.6.0)
# Requirement already satisfied: pandas in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.3.4)
# Requirement already satisfied: numpy in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.20.1)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\madcat\anaconda3\lib\site-packages (from packaging>20.9->shap) (2.4.7)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\madcat\anaconda3\lib\site-packages (from numba->shap) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\madcat\anaconda3\lib\site-packages (from numba->shap) (52.0.0.post20210125)
# Requirement already satisfied: pytz>=2017.3 in c:\users\madcat\anaconda3\lib\site-packages (from pandas->shap) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\madcat\anaconda3\lib\site-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\madcat\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\madcat\anaconda3\lib\site-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\madcat\anaconda3\lib\site-packages (from scikit-learn->shap) (2.1.0)
# Installing collected packages: slicer, packaging, shap
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
# Successfully installed packaging-21.2 shap-0.40.0 slicer-0.0.7

# %%
import shap
explainer = shap.Explainer(log_model,X_train)
start_index = 203
end_index = 204
shap_values = explainer.shap_values(X_test[start_index:end_index])

# %%
shap_values

# %%
print(shap_values[0].shape)
# Out:
# (1, 232)

# %%
# %% >> Visualize local predictions
shap.initjs()
# Force plot
prediction = log_model.predict(X_test[start_index:end_index])[0]
print(f"The log_model predicted: {prediction}")
shap.force_plot(explainer.expected_value[1],
                shap_values[1],
                X_test[start_index:end_index], # for values
                feature_names= X.columns,)

# %%
shap.summary_plot(shap_values, X_train,max_display=300,feature_names = X.columns)

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
